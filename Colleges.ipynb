# %%
import requests as req
import pandas as pd
# Google developer API key
from config_local import gkey

# %%
# read sites 
xls = pd.ExcelFile('Project1_AmazonSites.xlsx') 
sites_df=xls.parse('AmazonSites', dtype=str)

# %%
components= sites_df[['Site Name','State','Zip Code','Amazon City','Latitude','Longitude']]
components.head()
# Out:
#                             Site Name State Zip Code             Amazon City  \
# 0    Center for Innovation Technology    VA    20170  Northern Virginia Area
# 1       Crystal City and Potomac Yard    VA    22202  Northern Virginia Area
# 2  Nationals Park/ D.C United Stadium    DC    20024           Washington DC
# 3                       Union Station    DC    20002           Washington DC
# 4              Hill-East Neighborhood    DC    20003           Washington DC
#
#   Latitude Longitude
# 0    38.96    -77.42
# 1    38.84    -77.05
# 2    38.86    -77.01
# 3    38.89       -77
# 4    38.88    -76.97

# %%
# Use google search to get nearby schools and their ratings

# %%
# geocoordinates
target_coordinates = ''
target_search = "College"
target_radius = 8000
target_type = "School"
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
schools =[]

for index, row in components.iterrows():
    lat = row['Latitude']
    lng = row['Longitude']
    site = row['Site Name']
    coordinates = str(lat)+','+ str(lng)
    params['location'] = coordinates
    # run a request using our params dictionary
    response = req.get(base_url, params=params)
    print(response.url)
    # convert response to json
    school_data = response.json()
    number_schools = len(school_data["results"])
    print(number_schools)
    # Print the name and address of the first restaurant that appears
    for x in range(number_schools):
        if "rating" in school_data["results"][x].keys():
            rating = school_data["results"][x]["rating"]
        else:
            rating = 'NAN'
        schools.append({"Site Name":site,
                        "Number of schools":number_schools,
                        "Latitude":lat,
                       "Longitude":lng,
                       "Schools":school_data["results"][x]["name"],
                        "Rating":rating})
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.96%2C-77.42&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 12
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.84%2C-77.05&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.86%2C-77.01&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.89%2C-77&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.88%2C-76.97&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.91%2C-77.02&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.1802%2C-118.6028&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.4318%2C-118.5584&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 12
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.0885%2C-117.7702&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.39%2C-71&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.34%2C-71.03&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.35%2C-71.05&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.34%2C-71.06&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.75%2C-74&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.74%2C-73.94&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7%2C-73.98&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7%2C-74.01&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.91%2C-87.64&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.89%2C-87.64&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.88%2C-87.65&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.87%2C-87.63&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.87%2C-87.62&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.86%2C-87.67&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.85%2C-87.66&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.83%2C-87.6&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.9%2C-78.87&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 14
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.85%2C-79.08&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 19
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.77%2C-78.64&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7615%2C-84.3856&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.5129%2C-93.0431&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 7
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.904%2C-84.2843&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 18
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.9133%2C-84.3888&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 15
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.2586%2C-97.7444&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.2714%2C-97.6647&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.199%2C-97.8276&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 13
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4015%2C-97.7268&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 15
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4014%2C-97.7147&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 15
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4704%2C-97.7701&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 14
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.1338%2C-97.6411&keyword=College&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 0

# %%
schools_df = pd.DataFrame(schools)
schools_df.to_csv("Colleges.csv")
schools_df
# Out:
#     Latitude Longitude  Number of schools Rating  \
# 0      38.96    -77.42                 12      5
# 1      38.96    -77.42                 12    3.9
# 2      38.96    -77.42                 12    NAN
# 3      38.96    -77.42                 12    NAN
# 4      38.96    -77.42                 12    4.6
# 5      38.96    -77.42                 12    NAN
# 6      38.96    -77.42                 12    2.4
# 7      38.96    -77.42                 12    NAN
# 8      38.96    -77.42                 12      3
# 9      38.96    -77.42                 12    NAN
# 10     38.96    -77.42                 12    NAN
# 11     38.96    -77.42                 12    NAN
# 12     38.84    -77.05                 20    NAN
# 13     38.84    -77.05                 20    4.6
# 14     38.84    -77.05                 20      5
# 15     38.84    -77.05                 20    NAN
# 16     38.84    -77.05                 20    NAN
# 17     38.84    -77.05                 20    NAN
# 18     38.84    -77.05                 20    4.7
# 19     38.84    -77.05                 20      1
# 20     38.84    -77.05                 20    NAN
# 21     38.84    -77.05                 20    NAN
# 22     38.84    -77.05                 20    NAN
# 23     38.84    -77.05                 20    NAN
# 24     38.84    -77.05                 20    3.9
# 25     38.84    -77.05                 20    NAN
# 26     38.84    -77.05                 20      3
# 27     38.84    -77.05                 20    NAN
# 28     38.84    -77.05                 20    4.1
# 29     38.84    -77.05                 20    3.8
# ..       ...       ...                ...    ...
# 664  30.4015  -97.7268                 15    4.3
# 665  30.4014  -97.7147                 15    NAN
# 666  30.4014  -97.7147                 15    NAN
# 667  30.4014  -97.7147                 15    4.1
# 668  30.4014  -97.7147                 15      4
# 669  30.4014  -97.7147                 15    2.7
# 670  30.4014  -97.7147                 15    3.8
# 671  30.4014  -97.7147                 15    NAN
# 672  30.4014  -97.7147                 15    NAN
# 673  30.4014  -97.7147                 15    3.2
# 674  30.4014  -97.7147                 15    NAN
# 675  30.4014  -97.7147                 15    3.9
# 676  30.4014  -97.7147                 15      5
# 677  30.4014  -97.7147                 15      3
# 678  30.4014  -97.7147                 15      5
# 679  30.4014  -97.7147                 15    4.3
# 680  30.4704  -97.7701                 14    NAN
# 681  30.4704  -97.7701                 14    4.1
# 682  30.4704  -97.7701                 14    3.7
# 683  30.4704  -97.7701                 14      5
# 684  30.4704  -97.7701                 14    NAN
# 685  30.4704  -97.7701                 14    NAN
# 686  30.4704  -97.7701                 14    3.9
# 687  30.4704  -97.7701                 14    NAN
# 688  30.4704  -97.7701                 14      3
# 689  30.4704  -97.7701                 14    3.1
# 690  30.4704  -97.7701                 14    4.4
# 691  30.4704  -97.7701                 14    4.5
# 692  30.4704  -97.7701                 14      4
# 693  30.4704  -97.7701                 14    3.2
#
#                                                Schools  \
# 0                        College Entertainment Network
# 1    Northern Virginia Community College - Loudoun ...
# 2                Waddell Building, NVCC Loudoun Campus
# 3         Higher Education Center, NVCC Loudoun Campus
# 4    Northern Virginia Community College - Reston C...
# 5                             College Admission Agency
# 6                         NOVA Workforce - Signal Hill
# 7                          Veterans Affairs Admissions
# 8           George Mason University Executive Programs
# 9                           Superior Aircraft Services
# 10                           Eagle Ridge Middle School
# 11                      Certified Project Managers LLC
# 12                        American College of Surgeons
# 13   Colegio Interamericano de Defensa / Inter-Amer...
# 14                 National Bible College and Seminary
# 15                        Va Tech College-Architecture
# 16                         Independent Colleges Office
# 17                          American College of Greece
# 18            Association of American Medical Colleges
# 19                                   Excelsior College
# 20                      Palmer College Of Chiropractic
# 21   College of Energy, Environment & Sustainabilit...
# 22                Columbian College of Arts & Sciences
# 23     Indiana Chapter, American College of Cardiology
# 24                                  Strayer University
# 25                   The College for Public Leadership
# 26                                  Georgetown College
# 27    American University of Beirut Government Affairs
# 28                               UDC Community College
# 29             Corcoran School of the Arts & Design GW
# ..                                                 ...
# 664                 Austin Graduate School of Theology
# 665                         College Funding Specialist
# 666                              College Choice Austin
# 667        Austin Community College: Northridge Campus
# 668           Austin Community College: Service Center
# 669                           Altierus Career Colleges
# 670                             Vantage College Austin
# 671                                      Austin Campus
# 672  Austin Community College: Stonehollow Photogra...
# 673                           KIPP Austin College Prep
# 674                             Le Tourneau University
# 675                         Virginia College in Austin
# 676                          College Living Experience
# 677              University of Phoenix - Austin Campus
# 678  National American University Roueche Graduate ...
# 679                 Austin Graduate School of Theology
# 680                         College Funding Specialist
# 681        Austin Community College: Northridge Campus
# 682                           Austin Community College
# 683                          College Living Experience
# 684                            Austin College of Music
# 685  hi-iq academic college prospect camps upcoming...
# 686                         Concordia University Texas
# 687           Dallas Theological Seminary (DTS Austin)
# 688              University of Phoenix - Austin Campus
# 689                           South University, Austin
# 690              Star of Texas Dental Assisting School
# 691              Austin Dental Assistant School -North
# 692        Austin Dental Assistant School (Round Rock)
# 693                       National American University
#
#                             Site Name
# 0    Center for Innovation Technology
# 1    Center for Innovation Technology
# 2    Center for Innovation Technology
# 3    Center for Innovation Technology
# 4    Center for Innovation Technology
# 5    Center for Innovation Technology
# 6    Center for Innovation Technology
# 7    Center for Innovation Technology
# 8    Center for Innovation Technology
# 9    Center for Innovation Technology
# 10   Center for Innovation Technology
# 11   Center for Innovation Technology
# 12      Crystal City and Potomac Yard
# 13      Crystal City and Potomac Yard
# 14      Crystal City and Potomac Yard
# 15      Crystal City and Potomac Yard
# 16      Crystal City and Potomac Yard
# 17      Crystal City and Potomac Yard
# 18      Crystal City and Potomac Yard
# 19      Crystal City and Potomac Yard
# 20      Crystal City and Potomac Yard
# 21      Crystal City and Potomac Yard
# 22      Crystal City and Potomac Yard
# 23      Crystal City and Potomac Yard
# 24      Crystal City and Potomac Yard
# 25      Crystal City and Potomac Yard
# 26      Crystal City and Potomac Yard
# 27      Crystal City and Potomac Yard
# 28      Crystal City and Potomac Yard
# 29      Crystal City and Potomac Yard
# ..                                ...
# 664                        The Domain
# 665                   Bardmoor Campus
# 666                   Bardmoor Campus
# 667                   Bardmoor Campus
# 668                   Bardmoor Campus
# 669                   Bardmoor Campus
# 670                   Bardmoor Campus
# 671                   Bardmoor Campus
# 672                   Bardmoor Campus
# 673                   Bardmoor Campus
# 674                   Bardmoor Campus
# 675                   Bardmoor Campus
# 676                   Bardmoor Campus
# 677                   Bardmoor Campus
# 678                   Bardmoor Campus
# 679                   Bardmoor Campus
# 680                    Robinson Ranch
# 681                    Robinson Ranch
# 682                    Robinson Ranch
# 683                    Robinson Ranch
# 684                    Robinson Ranch
# 685                    Robinson Ranch
# 686                    Robinson Ranch
# 687                    Robinson Ranch
# 688                    Robinson Ranch
# 689                    Robinson Ranch
# 690                    Robinson Ranch
# 691                    Robinson Ranch
# 692                    Robinson Ranch
# 693                    Robinson Ranch
#
# [694 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

num_colleges= schools_df.groupby('Site Name')['Schools'].count()
nc= pd.DataFrame(num_colleges)
nc = nc.reset_index()
nc = nc.sort_values('Schools')
plt.figure(figsize=(5,10))
sns.barplot(x='Schools',y='Site Name',data=nc)
plt.title("Number of Nearby Colleges")
plt.show()

# %%
schools_df['Rating'] = schools_df['Rating'].astype(float)
m = schools_df.groupby('Site Name')['Rating'].mean()
am = pd.DataFrame(m)
am = am.reset_index()
am = am.sort_values('Rating', ascending=False)
plt.figure(figsize=(5,10))
sns.barplot(x='Rating',y='Site Name',data=am)
plt.title("Average rating of nearby colleges")
plt.show()
