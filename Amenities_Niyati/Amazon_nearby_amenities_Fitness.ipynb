# %% [markdown]
# ## Search for nearby Amenities for all site locations of each city
#     List of Amenities by Categories:
#     Categories:
#     A. Emergency Facilities
#        '''How accesible are these facilities in case of mass emergency on/around
#           sites for containing the situation and resuming business asap'''
#
#        1. Hospital
#        2. Fire Station
#        3. Doctor
#
#     B. Accomodation
#        '''Many executive employees travel from outside the city for fews days a week and might need lodging
#           facility as close to the company as possible. Also lot of local/not-local employees use vehicle
#           for commute and will need parking nearby'''
#
#        1. Lodging
#        2. Parking
#
#     C. Recreation
#         '''MNC(s) often arrange for team building activities on and near site. Also employees might look for group
#            recreational activities close  to work'''
#
#        1. Movies Theatres
#        2. Parks
#        3. Malls
#        4. Amusement park
#        5. Cafe/Restaurants
#
#     D. Basic Errands/appointments
#         '''By large employees tend to take care of daily errands and appoinments in lunch breaks or before/after
#            work hours and prefer it to be as close to work as possible for obvious reasons'''
#
#        1. Super markets
#        2. Post Office
#        3. Doctor
#
#     E. Fitness
#         '''Fitness is top on priority list for a significant amount of employees now a days may be in gym or a
#            jog/walk in park.'''
#
#        1. Gym
#        2. Parks

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import time

# Google developer API key
from config import g_key

# %%
# read places 
xls = pd.ExcelFile('BC_Project1/Project1_AmazonSites.xlsx') 
places_df=xls.parse('AmazonSites', dtype=str)
places_df = places_df[['Amazon City','Site','Site Name','Latitude','Longitude']]
places_df.head()
#len(places_df)
# Out:
#               Amazon City   Site                           Site Name Latitude  \
# 0  Northern Virginia Area  Site1    Center for Innovation Technology    38.96
# 1  Northern Virginia Area  Site2       Crystal City and Potomac Yard    38.84
# 2           Washington DC  Site1  Nationals Park/ D.C United Stadium    38.86
# 3           Washington DC  Site2                       Union Station    38.89
# 4           Washington DC  Site3              Hill-East Neighborhood    38.88
#
#   Longitude
# 0    -77.42
# 1    -77.05
# 2    -77.01
# 3       -77
# 4    -76.97

# %%
fitness_places = {'gym':'gym'}
all_fitness_rating = []

for key in fitness_places.keys():
    fitness_rating = []
    for site in places_df.values:

        # geocoordinates
        target_coordinates = str(site[3]) + ',' + str(site[4])
        target_search = fitness_places[key]
        target_radius = 2500
        target_type = key
        print("For {} at {}: {}, {}".format(key, site[0], site[1], target_coordinates))
        print("----------")
        # set up a parameters dictionary
        params = {
            "location": target_coordinates,
            "keyword": target_search,
            "radius": target_radius,
            "type": target_type,
            "key": g_key
        }

        # base url
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params).json()
        results = response.get('results')
        total_counts = len(results)
        print(total_counts)

        # Print the name and address of the first restaurant that appears
        for x in range(total_counts):
            if "rating" in results[x].keys():
                rating = results[x]["rating"]
            else:
                rating = 'NAN'
            fitness_rating.append({"Site Name":site[2],
                                       "Total Count":total_counts,
                                       "Latitude":site[3],
                                       "Longitude":site[4],
                                       "Facility "+key:results[x]["name"],
                                       "Rating":rating})
            time.sleep(3)
        time.sleep(3)
    all_fitness_rating.append(fitness_rating)
    print("ALL Done!!!!!")
#all_fitness_rating
# Out:
# For gym at Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 3
# For gym at Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 8
# For gym at Washington DC: Site1, 38.86,-77.01
# ----------
# 8
# For gym at Washington DC: Site2, 38.89,-77
# ----------
# 19
# For gym at Washington DC: Site3, 38.88,-76.97
# ----------
# 4
# For gym at Washington DC: Site4, 38.91,-77.02
# ----------
# 20
# For gym at Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 13
# For gym at Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 13
# For gym at Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 3
# For gym at Boston: Site1, 42.39,-71
# ----------
# 5
# For gym at Boston: Site2, 42.34,-71.03
# ----------
# 14
# For gym at Boston: Site3, 42.35,-71.05
# ----------
# 20
# For gym at Boston: Site4, 42.34,-71.06
# ----------
# 20
# For gym at New York: Site1, 40.75,-74
# ----------
# 20
# For gym at New York: Site2, 40.74,-73.94
# ----------
# 20
# For gym at New York: Site3, 40.7,-73.98
# ----------
# 20
# For gym at New York: Site4, 40.7,-74.01
# ----------
# 20
# For gym at Chicago: Site1, 41.91,-87.64
# ----------
# 20
# For gym at Chicago: Site2, 41.89,-87.64
# ----------
# 20
# For gym at Chicago: Site3, 41.88,-87.65
# ----------
# 20
# For gym at Chicago: Site4, 41.87,-87.63
# ----------
# 20
# For gym at Chicago: Site5, 41.87,-87.62
# ----------
# 20
# For gym at Chicago: Site6, 41.86,-87.67
# ----------
# 14
# For gym at Chicago: Site7, 41.85,-87.66
# ----------
# 11
# For gym at Chicago: Site8, 41.83,-87.6
# ----------
# 1
# For gym at Raleigh: Site1, 35.9,-78.87
# ----------
# 5
# For gym at Raleigh: Site2, 35.85,-79.08
# ----------
# 1
# For gym at Raleigh: Site3, 35.77,-78.64
# ----------
# 6
# For gym at Atlanta: Site1, 33.7615,-84.3856
# ----------
# 12
# For gym at Atlanta: Site2, 34.5129,-93.0431
# ----------
# 3
# For gym at Atlanta: Site3, 33.904,-84.2843
# ----------
# 6
# For gym at Atlanta: Site4, 33.9133,-84.3888
# ----------
# 4
# For gym at Austin: Site1, 30.2586,-97.7444
# ----------
# 9
# For gym at Austin: Site2, 30.2714,-97.6647
# ----------
# 2
# For gym at Austin: Site3, 30.199,-97.8276
# ----------
# 9
# For gym at Austin: Site4, 30.4015,-97.7268
# ----------
# 7
# For gym at Austin: Site5, 30.4014,-97.7147
# ----------
# 5
# For gym at Austin: Site6, 30.4704,-97.7701
# ----------
# 8
# For gym at Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!

# %%
all_fitness_rating
# Out:
# [[{'Facility gym': "Gold's Gym",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 2.7,
#    'Site Name': 'Center for Innovation Technology',
#    'Total Count': 3},
#   {'Facility gym': 'UFC Gym Reston/Herndon',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 5,
#    'Site Name': 'Center for Innovation Technology',
#    'Total Count': 3},
#   {'Facility gym': 'Worldgate Sport&Health',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4,
#    'Site Name': 'Center for Innovation Technology',
#    'Total Count': 3},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.4,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.1,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'Earth Treks',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.8,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'Foundation Fitness of Alexandria',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'Crystal Park Sport&Health',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.7,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'CrossFit South Arlington',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.6,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'F45 Training - Pentagon Row',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.9,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'Total Count': 8},
#   {'Facility gym': 'Headbangers Boxing Gym',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.8,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'VIDA Fitness The Yards',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'District CrossFit',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 5,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.5,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'Fitness Center I',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'Atlas Fitness',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.8,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'Washington Navy Yard Fitness Center',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.1,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': 'Capitol Hill Sport&Health',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.6,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'Total Count': 8},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Headbangers Boxing Gym',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.8,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Balance Gym',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.3,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Crunch - Metro Center',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.4,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'VIDA Fitness The Yards',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.4,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'VIDA Fitness Gallery Place',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'VIDA Fitness Renaissance and Aura Spa',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.7,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'District CrossFit',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 5,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Model Secondary School Gym',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 'NAN',
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.7,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'CrossFit DC Northeast',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.9,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.5,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Primal Fitness',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.6,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'American Parkour',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'VIDA Fitness City Vista',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Total Source Fitness',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.5,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'NUBOXX',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Capitol Hill Sport&Health',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.6,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Balance Gym',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.6,
#    'Site Name': 'Union Station',
#    'Total Count': 19},
#   {'Facility gym': 'Headbangers Boxing Gym',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.8,
#    'Site Name': 'Hill-East Neighborhood',
#    'Total Count': 4},
#   {'Facility gym': 'CrossFit DC Northeast',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.9,
#    'Site Name': 'Hill-East Neighborhood',
#    'Total Count': 4},
#   {'Facility gym': 'Atlas Fitness',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.8,
#    'Site Name': 'Hill-East Neighborhood',
#    'Total Count': 4},
#   {'Facility gym': 'VIDA Fitness The Yards',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'Total Count': 4},
#   {'Facility gym': 'Bodysmith Gym + Studios',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Sports Club Washington, D.C.',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.8,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Crunch - Metro Center',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'VIDA Fitness Logan Circle',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'VIDA Fitness Gallery Place',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Balance Gym',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'VIDA Fitness Renaissance and Aura Spa',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit MPH',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 5,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit DC',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.8,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit, Inc',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.8,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Model Secondary School Gym',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Primal Fitness',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'American Parkour',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'VIDA Fitness City Vista',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'Total Source Fitness',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'From the Core Studios',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': 'MINT health club & studio- Dupont',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'Total Count': 20},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.6,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'My Gym',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 5,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Total Woman Gym + Spa',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.2,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Equinox Woodland Hills',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': "We Rock the Spectrum Kid's Gym - Woodland Hills",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 5,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Team CrossFit - LYFE Athletics Woodland Hills',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.6,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'North Gym - 5600',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Woodland Hills Athletic Club',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.3,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'South Gym - 5400',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'ZOO CULTURE',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.7,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Group Interval Training',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 5,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'Total Count': 13},
#   {'Facility gym': "My Gym Children's Fitness Center",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.5,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 2.8,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Rye Canyon CrossFit',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.8,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Ekata Training Center - Gym Santa Clarita',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Gymnastics Unlimited',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Total Woman',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Henry Mayo Fitness and Health',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.7,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Ignition Fitness',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 5,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Face Your Fears Athletics',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Anytime Fitness',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.6,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': "Jordan's Virtual Fit Club",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'SCV All-Stars',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 5,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'Total Count': 13},
#   {'Facility gym': 'Arrow CrossFit',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4,
#    'Site Name': 'Pomona Fairplex',
#    'Total Count': 3},
#   {'Facility gym': 'Ace of Spades Boxing Club',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4,
#    'Site Name': 'Pomona Fairplex',
#    'Total Count': 3},
#   {'Facility gym': "My Gym Children's Fitness Center",
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 5,
#    'Site Name': 'Pomona Fairplex',
#    'Total Count': 3},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'Total Count': 5},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.1,
#    'Site Name': 'Suffolk Downs',
#    'Total Count': 5},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.2,
#    'Site Name': 'Suffolk Downs',
#    'Total Count': 5},
#   {'Facility gym': 'Winthrop Gymnastics Academy',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.6,
#    'Site Name': 'Suffolk Downs',
#    'Total Count': 5},
#   {'Facility gym': 'RPM Fitness',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.7,
#    'Site Name': 'Suffolk Downs',
#    'Total Count': 5},
#   {'Facility gym': 'UFC Gym Boston Financial District',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.2,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': "Peter Welch's Gym",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.9,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 2.1,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Equinox Franklin Street',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.8,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Equinox Seaport',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.5,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Rock Spot Climbing',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.6,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'BRICK CrossFit DTX / BRICK Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Lifted Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Fisique Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.4,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': "FitCorp - Boston's Fitness and Wellness Centers",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 'NAN',
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.1,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'EverybodyFights',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'EverybodyFights',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': "Regan's Motivated Fitness",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.6,
#    'Site Name': 'South Boston Waterfront',
#    'Total Count': 14},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.1,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': "Peter Welch's Gym",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.9,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym Boston Financial District',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.2,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 2.1,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Sports Club Boston',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.9,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Dartmouth',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.9,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Franklin Street',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.8,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Seaport',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.5,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Kendall Square CrossFit - Kendall Square',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Rock Spot Climbing',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.6,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'BRICK CrossFit DTX / BRICK Boston',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.7,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'South End Fitness Center',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Lifted Fitness',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Fisique Boston',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.4,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'ZONE5 Fitness',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.9,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': "FitCorp - Boston's Fitness and Wellness Centers",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.9,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'EverybodyFights',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Sweat Box-Boxing Hip Hop Martial Arts for Women',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.8,
#    'Site Name': 'Downtown',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.1,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': "Peter Welch's Gym",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.9,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym Boston Financial District',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.2,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 2.1,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Sports Club Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3.9,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Dartmouth',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3.9,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Franklin Street',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3.8,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Seaport',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.5,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Back Bay Boxing Gym and Fitness, Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 5,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Rock Spot Climbing',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.6,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'BRICK CrossFit DTX / BRICK Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 5,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Title Boxing Club Newbury Street',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.7,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.7,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'South End Fitness Center',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Republic Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.7,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'Fisique Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.4,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'ZONE5 Fitness',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3.9,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'MIT Recreation - Alumni Pool and Wang Fitness Center',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.4,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': "FitCorp - Boston's Fitness and Wellness Centers",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': 'BodyScapes Fitness Kendall Square',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.5,
#    'Site Name': 'South End',
#    'Total Count': 20},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.6,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.4,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.1,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Crunch - Bowery',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.1,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.6,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'My Gym Lincoln Center',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Gotham Gym',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.4,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Ultimate Gym NYC',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.3,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Rockefeller Center',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.8,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Columbus Circle',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.4,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Park Avenue',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Highline',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': '19th Street Gym',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.7,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Life Time Athletic at Sky',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.4,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Fitness Classes - Gym Studio - Belleon NYC',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 5,
#    'Site Name': 'Hudson Yards',
#    'Total Count': 20},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.4,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'My Gym Upper East 60th',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.8,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Chalk Gyms',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.2,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Lift Gym Inc',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.3,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox East 54th Street',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 2.8,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Complete Body & Spa',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.9,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Bell Fitness | CrossFit Bell',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 5,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Retro Fitness',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.9,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 5,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': '301 East 57th Street Gym LLC',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 'NAN',
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit Gantry',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.9,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit Outbreak East Williamsburg',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 5,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Phyzique',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.7,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Crunch - 59th Street',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.2,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.7,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Williamsburg',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.9,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Blink Fitness Woodside',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.5,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Greenpoint Gymnastics',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.8,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Trooper Fitness',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 5,
#    'Site Name': 'Long Island City',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.2,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.8,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.9,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'The Little Gym',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.2,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Little Gym of Brooklyn Heights',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.2,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': "Gleason's Gym",
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym NYC SoHo',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Chalk Gyms',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.2,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'GYM NYC',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.7,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Body Elite Gym',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.7,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Global Strongman Gym',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Dumbo',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.3,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Brooklyn Heights',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.8,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Williamsburg',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.9,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Blink Fitness FiDi',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.9,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Wall Street',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'GREYS GYM',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Complete Body Fitness, Physical Therapy, Juice Bar',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Oculus CrossFit',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.2,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.1,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.9,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'The Little Gym',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.2,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Little Gym of Brooklyn Heights',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.2,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': "Gleason's Gym",
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.5,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym NYC SoHo',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'GYM NYC',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.7,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Body Elite Gym',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.7,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Wall Street',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.1,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Dumbo',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.3,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Brooklyn Heights',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.8,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Brookfield Place',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.4,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Tribeca',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.8,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Blink Fitness FiDi',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.9,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Complete Body Fitness, Physical Therapy, Juice Bar',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.5,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Oculus CrossFit',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 5,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Park Slope CrossFit',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.8,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Mac Gym',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4,
#    'Site Name': 'Financial District',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.1,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym River North',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.8,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'River North Gym at the MART',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Lincoln Park',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.9,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Gold Coast',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.4,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Lakeshore Sport & Fitness Lincoln Park',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.8,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Wells Street CrossFit',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Solheim Gym',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit CE',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Symmetry Chicago',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Wicker Park Athletic Club',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.9,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Lincoln Park Athletic Club',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Lincoln Park Fitness Center',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'ENRGi Fitness',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.8,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'HiFi Personal Fitness',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.8,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Hustle Fitness™',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'River North CrossFit',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.8,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Atlas Performance and CrossFit',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.2,
#    'Site Name': 'Lincoln Yards',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.1,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym River North',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.8,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'River North Gym at the MART',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'POW! Gym Chicago',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Coöp Gym',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.8,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'FIT RESULTS - South Loop Gym',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox The Loop',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.9,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Gold Coast',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.4,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Lakeshore Sport & Fitness Illinois Center',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'TITLE Boxing Club Chicago West Loop',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'The Foundry - Union Station CrossFit',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Wells Street CrossFit',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Solheim Gym',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'FFC Gold Coast',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.2,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'South Loop Strength & Conditioning - Home of South Loop CrossFit',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.9,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'CrossFit CE',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Fitness Formula Clubs Corporate Headquarters',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.7,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Symmetry Chicago',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'Total Count': 20},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.1,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym River North',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.8,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'UFC Gym',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.2,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'River North Gym at the MART',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.7,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'POW! Gym Chicago',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 5,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'Coöp Gym',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.8,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox The Loop',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.9,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
#   {'Facility gym': 'Equinox Gold Coast',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.4,
#    'Site Name': 'Futton Market',
#    'Total Count': 20},
# ...
#    'Total Count': 14},
#   {'Facility gym': 'UIC Sports & Fitness Center',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.5,
#    'Site Name': 'The Illinois Medical District',
#    'Total Count': 14},
#   {'Facility gym': "Pilsen's Fitness Center",
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.9,
#    'Site Name': 'The Illinois Medical District',
#    'Total Count': 14},
#   {'Facility gym': 'Body Shot Boxing Club',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.4,
#    'Site Name': 'The Illinois Medical District',
#    'Total Count': 14},
#   {'Facility gym': 'FitPro West',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 5,
#    'Site Name': 'The Illinois Medical District',
#    'Total Count': 14},
#   {'Facility gym': 'CrossFit Commitment',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.7,
#    'Site Name': 'The Illinois Medical District',
#    'Total Count': 14},
#   {'Facility gym': 'Planet Fitness - Chicago (Little Village), IL',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.2,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': "Lance's Gym",
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.7,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'Energym Gym & Nutrition Bar',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.5,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'Charter Fitness',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 2.9,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'St Francis of Assisi Gym',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 'NAN',
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'UIC Sports & Fitness Center',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.5,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': "Pilsen's Fitness Center",
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.9,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'TITLE Boxing Club Chicago South Loop',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 5,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'Body Shot Boxing Club',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.4,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'CrossFit Commitment',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.7,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'South Loop Strength & Conditioning - Home of South Loop CrossFit',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.9,
#    'Site Name': 'The 78',
#    'Total Count': 11},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 3,
#    'Site Name': 'Burnham Lakefront',
#    'Total Count': 1},
#   {'Facility gym': 'Crossfit RTP',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 5,
#    'Site Name': 'Research Triangle Park',
#    'Total Count': 5},
#   {'Facility gym': 'RTP Fitness',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 4.1,
#    'Site Name': 'Research Triangle Park',
#    'Total Count': 5},
#   {'Facility gym': 'Back2Basics Boxing',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 4.6,
#    'Site Name': 'Research Triangle Park',
#    'Total Count': 5},
#   {'Facility gym': 'CrossFit 919',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 5,
#    'Site Name': 'Research Triangle Park',
#    'Total Count': 5},
#   {'Facility gym': 'United Thai Boxing & MMA',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 4.7,
#    'Site Name': 'Research Triangle Park',
#    'Total Count': 5},
#   {'Facility gym': 'O2 Fitness',
#    'Latitude': '35.85',
#    'Longitude': '-79.08',
#    'Rating': 4.1,
#    'Site Name': 'Chatham Park',
#    'Total Count': 1},
#   {'Facility gym': 'HEAT - Studio Gym',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 4.6,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'Spider Strength Gym',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 5,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'Jawbreaker Boxing',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 4.8,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'CrossFit Invoke',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 5,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'Second Round',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 4.3,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'MADabolic',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 5,
#    'Site Name': 'Warehouse District',
#    'Total Count': 6},
#   {'Facility gym': 'Orangetheory Fitness',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.6,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'The BRADY APTS GYM',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Unit 2 Fitness',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.3,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Universal Fitness',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.7,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'The Training Room ATL',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.9,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Vesta Movement',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.8,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'The Forum Athletic Club',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.4,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'CrossFit Downtown Atlanta',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.9,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Exhale Atlanta - Midtown',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.1,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Torq Cycle',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.9,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Lovely Bodies',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.6,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Snap Fitness',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.5,
#    'Site Name': 'Downtown Atlanta',
#    'Total Count': 12},
#   {'Facility gym': 'Personalized Fitness',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 5,
#    'Site Name': 'Midtown',
#    'Total Count': 3},
#   {'Facility gym': 'The Gypsy Love Ranch',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 3,
#    'Site Name': 'Midtown',
#    'Total Count': 3},
#   {'Facility gym': 'Lions Den',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 'NAN',
#    'Site Name': 'Midtown',
#    'Total Count': 3},
#   {'Facility gym': 'CrossFit Chamblee',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.7,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'Stone Summit Climbing and Fitness Center',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.6,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'SWEET SCIENCE FITNESS BOXING CLUB',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.8,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'Elite Edge Fitness',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.8,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'CrossFit HD',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.8,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'Team Octopus Chamblee',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.9,
#    'Site Name': 'Former GM plant',
#    'Total Count': 6},
#   {'Facility gym': 'Jump Start Gym',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4,
#    'Site Name': 'The High Street Site',
#    'Total Count': 4},
#   {'Facility gym': 'Anytime Fitness',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 5,
#    'Site Name': 'The High Street Site',
#    'Total Count': 4},
#   {'Facility gym': 'Life Time Athletic',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 3.6,
#    'Site Name': 'The High Street Site',
#    'Total Count': 4},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 3.2,
#    'Site Name': 'The High Street Site',
#    'Total Count': 4},
#   {'Facility gym': 'Mecca Gym & Spa',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.8,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'Castle Hill Fitness Gym & Spa',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.7,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.6,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'CrossFit 2024',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 5,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'Pure Austin Fitness',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.1,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'CrossFit Central Downtown',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.6,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'City Surf Fitness Austin',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 5,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'Tetra Fitness',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.9,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'Rumble ATX Boxing and Fitness',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.7,
#    'Site Name': 'American-Statesman ',
#    'Total Count': 9},
#   {'Facility gym': 'YMCA of Austin - East Communities Y',
#    'Latitude': '30.2714',
#    'Longitude': '-97.6647',
#    'Rating': 3.9,
#    'Site Name': 'Eightfold',
#    'Total Count': 2},
#   {'Facility gym': 'Fortitude Strength & Conditioning - Easy is Evil CrossFit',
#    'Latitude': '30.2714',
#    'Longitude': '-97.6647',
#    'Rating': 5,
#    'Site Name': 'Eightfold',
#    'Total Count': 2},
#   {'Facility gym': 'Planet Fitness',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.5,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'The Little Gym of Austin South',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.9,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'Star Center Gymnastics and Cheer',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 3.7,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'Life Time Fitness',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 2.5,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'Brodie Park CrossFit',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.8,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 3.8,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'South Austin Gym',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.1,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'LA Fitness',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': 'Impact Strong',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.8,
#    'Site Name': 'Former 3M site',
#    'Total Count': 9},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 3.5,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'Anytime Fitness',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.2,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'GYM ONE',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.6,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'illuminate Gym',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 5,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'Orangetheory Fitness- Arbor Town Square',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.8,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'CrossFit REP',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.9,
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'Charneski Fight Team TX',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 'NAN',
#    'Site Name': 'The Domain',
#    'Total Count': 7},
#   {'Facility gym': 'Anytime Fitness',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.2,
#    'Site Name': 'Bardmoor Campus',
#    'Total Count': 5},
#   {'Facility gym': 'Big Tex Gym',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.8,
#    'Site Name': 'Bardmoor Campus',
#    'Total Count': 5},
#   {'Facility gym': 'GYM ONE',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.6,
#    'Site Name': 'Bardmoor Campus',
#    'Total Count': 5},
#   {'Facility gym': 'CrossFit REP',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.9,
#    'Site Name': 'Bardmoor Campus',
#    'Total Count': 5},
#   {'Facility gym': 'Charneski Fight Team TX',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 'NAN',
#    'Site Name': 'Bardmoor Campus',
#    'Total Count': 5},
#   {'Facility gym': '24 Hour Fitness',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 3.4,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'Anytime Fitness',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4.3,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': "Gold's Gym",
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'Life Time Fitness',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 3.9,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'Woodward CrossFit',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4.5,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'Austin Gymnastics Club',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 5,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'Fitness Connection',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 2.8,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8},
#   {'Facility gym': 'TumblePro Austin',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4.3,
#    'Site Name': 'Robinson Ranch',
#    'Total Count': 8}]]

# %%
all_gym_rating_df = pd.DataFrame(all_fitness_rating[0])
all_gym_rating_df
# Out:
#                                           Facility gym Latitude Longitude  \
# 0                                           Gold's Gym    38.96    -77.42
# 1                               UFC Gym Reston/Herndon    38.96    -77.42
# 2                               Worldgate Sport&Health    38.96    -77.42
# 3                                           Gold's Gym    38.84    -77.05
# 4                                           LA Fitness    38.84    -77.05
# 5                                 Orangetheory Fitness    38.84    -77.05
# 6                                          Earth Treks    38.84    -77.05
# 7                     Foundation Fitness of Alexandria    38.84    -77.05
# 8                            Crystal Park Sport&Health    38.84    -77.05
# 9                             CrossFit South Arlington    38.84    -77.05
# 10                         F45 Training - Pentagon Row    38.84    -77.05
# 11                              Headbangers Boxing Gym    38.86    -77.01
# 12                              VIDA Fitness The Yards    38.86    -77.01
# 13                                   District CrossFit    38.86    -77.01
# 14                                Orangetheory Fitness    38.86    -77.01
# 15                                    Fitness Center I    38.86    -77.01
# 16                                       Atlas Fitness    38.86    -77.01
# 17                 Washington Navy Yard Fitness Center    38.86    -77.01
# 18                           Capitol Hill Sport&Health    38.86    -77.01
# 19                                          Gold's Gym    38.89       -77
# 20                              Headbangers Boxing Gym    38.89       -77
# 21                                         Balance Gym    38.89       -77
# 22                               Crunch - Metro Center    38.89       -77
# 23                              VIDA Fitness The Yards    38.89       -77
# 24                          VIDA Fitness Gallery Place    38.89       -77
# 25               VIDA Fitness Renaissance and Aura Spa    38.89       -77
# 26                                   District CrossFit    38.89       -77
# 27                          Model Secondary School Gym    38.89       -77
# 28                                Orangetheory Fitness    38.89       -77
# 29                               CrossFit DC Northeast    38.89       -77
# ..                                                 ...      ...       ...
# 403  Fortitude Strength & Conditioning - Easy is Ev...  30.2714  -97.6647
# 404                                     Planet Fitness   30.199  -97.8276
# 405                     The Little Gym of Austin South   30.199  -97.8276
# 406                   Star Center Gymnastics and Cheer   30.199  -97.8276
# 407                                  Life Time Fitness   30.199  -97.8276
# 408                               Brodie Park CrossFit   30.199  -97.8276
# 409                                    24 Hour Fitness   30.199  -97.8276
# 410                                   South Austin Gym   30.199  -97.8276
# 411                                         LA Fitness   30.199  -97.8276
# 412                                      Impact Strong   30.199  -97.8276
# 413                                    24 Hour Fitness  30.4015  -97.7268
# 414                                    Anytime Fitness  30.4015  -97.7268
# 415                                            GYM ONE  30.4015  -97.7268
# 416                                     illuminate Gym  30.4015  -97.7268
# 417            Orangetheory Fitness- Arbor Town Square  30.4015  -97.7268
# 418                                       CrossFit REP  30.4015  -97.7268
# 419                            Charneski Fight Team TX  30.4015  -97.7268
# 420                                    Anytime Fitness  30.4014  -97.7147
# 421                                        Big Tex Gym  30.4014  -97.7147
# 422                                            GYM ONE  30.4014  -97.7147
# 423                                       CrossFit REP  30.4014  -97.7147
# 424                            Charneski Fight Team TX  30.4014  -97.7147
# 425                                    24 Hour Fitness  30.4704  -97.7701
# 426                                    Anytime Fitness  30.4704  -97.7701
# 427                                         Gold's Gym  30.4704  -97.7701
# 428                                  Life Time Fitness  30.4704  -97.7701
# 429                                  Woodward CrossFit  30.4704  -97.7701
# 430                             Austin Gymnastics Club  30.4704  -97.7701
# 431                                 Fitness Connection  30.4704  -97.7701
# 432                                   TumblePro Austin  30.4704  -97.7701
#
#     Rating                           Site Name  Total Count
# 0      2.7    Center for Innovation Technology            3
# 1        5    Center for Innovation Technology            3
# 2        4    Center for Innovation Technology            3
# 3      3.4       Crystal City and Potomac Yard            8
# 4      3.1       Crystal City and Potomac Yard            8
# 5        5       Crystal City and Potomac Yard            8
# 6      4.8       Crystal City and Potomac Yard            8
# 7        5       Crystal City and Potomac Yard            8
# 8      4.7       Crystal City and Potomac Yard            8
# 9      4.6       Crystal City and Potomac Yard            8
# 10     4.9       Crystal City and Potomac Yard            8
# 11     4.8  Nationals Park/ D.C United Stadium            8
# 12     4.4  Nationals Park/ D.C United Stadium            8
# 13       5  Nationals Park/ D.C United Stadium            8
# 14     4.5  Nationals Park/ D.C United Stadium            8
# 15       4  Nationals Park/ D.C United Stadium            8
# 16     4.8  Nationals Park/ D.C United Stadium            8
# 17     4.1  Nationals Park/ D.C United Stadium            8
# 18     4.6  Nationals Park/ D.C United Stadium            8
# 19     4.1                       Union Station           19
# 20     4.8                       Union Station           19
# 21     4.3                       Union Station           19
# 22     4.4                       Union Station           19
# 23     4.4                       Union Station           19
# 24     4.2                       Union Station           19
# 25     4.7                       Union Station           19
# 26       5                       Union Station           19
# 27     NAN                       Union Station           19
# 28     4.7                       Union Station           19
# 29     4.9                       Union Station           19
# ..     ...                                 ...          ...
# 403      5                           Eightfold            2
# 404    4.5                      Former 3M site            9
# 405    4.9                      Former 3M site            9
# 406    3.7                      Former 3M site            9
# 407    2.5                      Former 3M site            9
# 408    4.8                      Former 3M site            9
# 409    3.8                      Former 3M site            9
# 410    4.1                      Former 3M site            9
# 411      4                      Former 3M site            9
# 412    4.8                      Former 3M site            9
# 413    3.5                          The Domain            7
# 414    4.2                          The Domain            7
# 415    4.6                          The Domain            7
# 416      5                          The Domain            7
# 417    4.8                          The Domain            7
# 418    4.9                          The Domain            7
# 419    NAN                          The Domain            7
# 420    4.2                     Bardmoor Campus            5
# 421    4.8                     Bardmoor Campus            5
# 422    4.6                     Bardmoor Campus            5
# 423    4.9                     Bardmoor Campus            5
# 424    NAN                     Bardmoor Campus            5
# 425    3.4                      Robinson Ranch            8
# 426    4.3                      Robinson Ranch            8
# 427      4                      Robinson Ranch            8
# 428    3.9                      Robinson Ranch            8
# 429    4.5                      Robinson Ranch            8
# 430      5                      Robinson Ranch            8
# 431    2.8                      Robinson Ranch            8
# 432    4.3                      Robinson Ranch            8
#
# [433 rows x 6 columns]

# %%
all_gym_rating_df.to_csv("Gym_Rating.csv")
