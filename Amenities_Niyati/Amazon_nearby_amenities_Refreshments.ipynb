# %% [markdown]
# ## Search for nearby Amenities for all site locations of each city
#     List of Amenities by Categories:
#     Categories:
#     A. Emergency Facilities
#        '''How accesible are these facilities in case of mass emergency on/around
#           sites for containing the situation and resuming business asap'''
#
#        1. Hospital
#        2. Fire Station
#        3. Doctor
#
#     B. Accomodation
#        '''Many executive employees travel from outside the city for fews days a week and might need lodging
#           facility as close to the company as possible. Also lot of local/not-local employees use vehicle
#           for commute and will need parking nearby'''
#
#        1. Lodging
#        2. Parking
#
#     C. Recreation
#         '''MNC(s) often arrange for team building activities on and near site. Also employees might look for group
#            recreational activities close  to work'''
#
#        1. Movies Theatres
#        2. Parks
#        3. Malls
#        4. Amusement park
#        5. Cafe/Restaurants
#
#     D. Basic Errands/appointments
#         '''By large employees tend to take care of daily errands and appoinments in lunch breaks or before/after
#            work hours and prefer it to be as close to work as possible for obvious reasons'''
#
#        1. Super markets
#        2. Post Office
#        3. Doctor
#
#     E. Fitness
#         '''Fitness is top on priority list for a significant amount of employees now a days may be in gym or a
#            jog/walk in park.'''
#
#        1. Gym
#        2. Parks

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import time
import matplotlib.pyplot as plt
import seaborn as sns

# Google developer API key
from config import g_key

# %%
# read places 
xls = pd.ExcelFile('BC_Project1/Project1_AmazonSites.xlsx') 
places_df=xls.parse('AmazonSites', dtype=str)
places_df = places_df[['Amazon City','Site','Site Name','Latitude','Longitude']]
places_df.head()
#len(places_df)
# Out:
#               Amazon City   Site                           Site Name Latitude  \
# 0  Northern Virginia Area  Site1    Center for Innovation Technology    38.96
# 1  Northern Virginia Area  Site2       Crystal City and Potomac Yard    38.84
# 2           Washington DC  Site1  Nationals Park/ D.C United Stadium    38.86
# 3           Washington DC  Site2                       Union Station    38.89
# 4           Washington DC  Site3              Hill-East Neighborhood    38.88
#
#   Longitude
# 0    -77.42
# 1    -77.05
# 2    -77.01
# 3       -77
# 4    -76.97

# %%
# eating_out = {'restaurant':'restaurant', 'cafe':'cafe'}
# all_eatingout_rating = []

# for key in eating_out.keys():
#     eatingout_rating = []
#     for site in places_df.values:

#         # geocoordinates
#         target_coordinates = str(site[3]) + ',' + str(site[4])
#         target_search = eating_out[key]
#         target_radius = 2500
#         target_type = key
#         print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
#         print("----------")
#         # set up a parameters dictionary
#         params = {
#             "location": target_coordinates,
#             "keyword": target_search,
#             "radius": target_radius,
#             "type": target_type,
#             "key": g_key
#         }

#         # base url
#         base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#         # run a request using our params dictionary
#         response = requests.get(base_url, params=params).json()
#         results = response.get('results')
#         total_counts = len(results)
#         print(total_counts)

#         # Print the name and address of the first restaurant that appears
#         for x in range(total_counts):
#             if "rating" in results[x].keys():
#                 rating = results[x]["rating"]
#             else:
#                 rating = 'NAN'
#             if "price_level" in results[x].keys():
#                 price_level = results[x]["price_level"]
#             else:
#                 price_level = 'NAN'
#             eatingout_rating.append({"Site Name":site[2],
#                                        key+" Total Count":total_counts,
#                                        "Latitude":site[3],
#                                        "Longitude":site[4],
#                                        "Facility "+key:results[x]["name"],
#                                        "Rating":rating,
#                                        "price_level":price_level})
            
#             time.sleep(2)
#         time.sleep(2)
#     all_eatingout_rating.append(eatingout_rating)
#     print("ALL Done!!!!!")
# #all_eatingout_rating
# Out:
# restaurant For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 20
# restaurant For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 20
# restaurant For Washington DC: Site1, 38.86,-77.01
# ----------
# 20
# restaurant For Washington DC: Site2, 38.89,-77
# ----------
# 20
# restaurant For Washington DC: Site3, 38.88,-76.97
# ----------
# 20
# restaurant For Washington DC: Site4, 38.91,-77.02
# ----------
# 20
# restaurant For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 20
# restaurant For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 20
# restaurant For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 20
# restaurant For Boston: Site1, 42.39,-71
# ----------
# 20
# restaurant For Boston: Site2, 42.34,-71.03
# ----------
# 20
# restaurant For Boston: Site3, 42.35,-71.05
# ----------
# 20
# restaurant For Boston: Site4, 42.34,-71.06
# ----------
# 20
# restaurant For New York: Site1, 40.75,-74
# ----------
# 20
# restaurant For New York: Site2, 40.74,-73.94
# ----------
# 20
# restaurant For New York: Site3, 40.7,-73.98
# ----------
# 20
# restaurant For New York: Site4, 40.7,-74.01
# ----------
# 20
# restaurant For Chicago: Site1, 41.91,-87.64
# ----------
# 20
# restaurant For Chicago: Site2, 41.89,-87.64
# ----------
# 20
# restaurant For Chicago: Site3, 41.88,-87.65
# ----------
# 20
# restaurant For Chicago: Site4, 41.87,-87.63
# ----------
# 20
# restaurant For Chicago: Site5, 41.87,-87.62
# ----------
# 20
# restaurant For Chicago: Site6, 41.86,-87.67
# ----------
# 20
# restaurant For Chicago: Site7, 41.85,-87.66
# ----------
# 20
# restaurant For Chicago: Site8, 41.83,-87.6
# ----------
# 18
# restaurant For Raleigh: Site1, 35.9,-78.87
# ----------
# 20
# restaurant For Raleigh: Site2, 35.85,-79.08
# ----------
# 6
# restaurant For Raleigh: Site3, 35.77,-78.64
# ----------
# 20
# restaurant For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 20
# restaurant For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 20
# restaurant For Atlanta: Site3, 33.904,-84.2843
# ----------
# 20
# restaurant For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 20
# restaurant For Austin: Site1, 30.2586,-97.7444
# ----------
# 20
# restaurant For Austin: Site2, 30.2714,-97.6647
# ----------
# 1
# restaurant For Austin: Site3, 30.199,-97.8276
# ----------
# 20
# restaurant For Austin: Site4, 30.4015,-97.7268
# ----------
# 20
# restaurant For Austin: Site5, 30.4014,-97.7147
# ----------
# 20
# restaurant For Austin: Site6, 30.4704,-97.7701
# ----------
# 18
# restaurant For Austin: Site7, 30.1338,-97.6411
# ----------
# 1
# ALL Done!!!!!
# cafe For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 13
# cafe For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 17
# cafe For Washington DC: Site1, 38.86,-77.01
# ----------
# 14
# cafe For Washington DC: Site2, 38.89,-77
# ----------
# 20
# cafe For Washington DC: Site3, 38.88,-76.97
# ----------
# 13
# cafe For Washington DC: Site4, 38.91,-77.02
# ----------
# 20
# cafe For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 18
# cafe For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 19
# cafe For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 6
# cafe For Boston: Site1, 42.39,-71
# ----------
# 9
# cafe For Boston: Site2, 42.34,-71.03
# ----------
# 20
# cafe For Boston: Site3, 42.35,-71.05
# ----------
# 20
# cafe For Boston: Site4, 42.34,-71.06
# ----------
# 20
# cafe For New York: Site1, 40.75,-74
# ----------
# 20
# cafe For New York: Site2, 40.74,-73.94
# ----------
# 20
# cafe For New York: Site3, 40.7,-73.98
# ----------
# 20
# cafe For New York: Site4, 40.7,-74.01
# ----------
# 20
# cafe For Chicago: Site1, 41.91,-87.64
# ----------
# 20
# cafe For Chicago: Site2, 41.89,-87.64
# ----------
# 20
# cafe For Chicago: Site3, 41.88,-87.65
# ----------
# 20
# cafe For Chicago: Site4, 41.87,-87.63
# ----------
# 20
# cafe For Chicago: Site5, 41.87,-87.62
# ----------
# 20
# cafe For Chicago: Site6, 41.86,-87.67
# ----------
# 20
# cafe For Chicago: Site7, 41.85,-87.66
# ----------
# 20
# cafe For Chicago: Site8, 41.83,-87.6
# ----------
# 2
# cafe For Raleigh: Site1, 35.9,-78.87
# ----------
# 4
# cafe For Raleigh: Site2, 35.85,-79.08
# ----------
# 1
# cafe For Raleigh: Site3, 35.77,-78.64
# ----------
# 20
# cafe For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 20
# cafe For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 8
# cafe For Atlanta: Site3, 33.904,-84.2843
# ----------
# 8
# cafe For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 10
# cafe For Austin: Site1, 30.2586,-97.7444
# ----------
# 20
# cafe For Austin: Site2, 30.2714,-97.6647
# ----------
# 0
# cafe For Austin: Site3, 30.199,-97.8276
# ----------
# 9
# cafe For Austin: Site4, 30.4015,-97.7268
# ----------
# 16
# cafe For Austin: Site5, 30.4014,-97.7147
# ----------
# 13
# cafe For Austin: Site6, 30.4704,-97.7701
# ----------
# 4
# cafe For Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!

# %%
all_eatingout_rating
# Out:
# [[{'Facility restaurant': "NED DEVINE'S IRISH SPORTS BAR & RESTAURANT",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.7,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Anatolian Bistro Turkish Restaurant',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.8,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'China King Restaurant',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.2,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Houlihan's",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.4,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Elements On Level One',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.2,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Carrabba's Italian Grill",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 2.2,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Moe's Southwest Grill",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.8,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.7,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.9,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.7,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.8,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Au Bon Pain',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.3,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Smashburger',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.3,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Bar Louie',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.1,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'TGI Fridays',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Cracker Barrel Old Country Store',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.1,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Noodles and Company',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.8,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Wendy's",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.7,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chao Phra YA Thai',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.5,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Chuck E. Cheese's",
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.8,
#    'Site Name': 'Center for Innovation Technology',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Fyve Restaurant Lounge',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.6,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Portofino Restaurant',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.1,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Young Chow Restaurant',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Live Oak Restaurant',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.4,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "RT's Restaurant",
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Rustico Restaurant & Bar - Alexandria',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.2,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'China Cafe restaurant',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jaleo',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.2,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "McCormick & Schmick's Seafood & Steaks",
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.1,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.7,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 2.8,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.9,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'California Pizza Kitchen at Pentagon Center',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Legal Sea Foods',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.2,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Popeyes Louisiana Kitchen',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.7,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Smashburger',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 2.1,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Smashburger',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 1,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Bar Louie',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3.9,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Ted's Bulletin",
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.5,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Shake Shack - Nationals Park',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.9,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'IHOP',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.5,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'California Tortilla',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.8,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.5,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Popeyes Louisiana Kitchen',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.6,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Shake Shack - Navy Yard',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.2,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Five Guys',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.2,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Ambar Capitol Hill',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.6,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Panda Express',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Willie's Brew & Que",
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.7,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Station 4',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.8,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Whaley's",
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.3,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Agua 301 Restaurant',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.7,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Scarlet Oak Restaurant & Bar',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.2,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'La Lomita Restaurant',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Lapidus Restaurant',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 2.3,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': '701 Restaurant',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Ethiopic Restaurant',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.4,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Carmine's Italian Restaurant - Washington DC",
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Sonoma Restaurant and Wine Bar',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chercher Ethiopian Restaurant & Mart',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.6,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Irish Channel Restaurant & Pub',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.3,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jaleo',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'The Source by Wolfgang Puck',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chick-Fil-A',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.4,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.1,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.3,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'The Smith',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.3,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Hooters',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.4,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.6,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.4,
#    'Site Name': 'Union Station',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Ted's Bulletin",
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.5,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Le Pain Quotidien',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.9,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Momofuku CCDC',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4,
#    'Site Name': 'Union Station',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Moe's Southwest Grill",
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.2,
#    'Site Name': 'Union Station',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Ted's Bulletin",
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.5,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Le Pain Quotidien',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chick-Fil-A',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Popeyes Louisiana Kitchen',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.3,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Subway',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Popeyes Louisiana Kitchen',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.5,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Popeyes Louisiana Kitchen',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.5,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Ambar Capitol Hill',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Acqua Al 2',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Panda Express',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Joselito Casa de Comidas',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.2,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Montmartre',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Addis Ethiopian Restaurant',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.3,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Mr. Henry's Restaurant",
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.3,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'La Lomita Restaurant',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Quara Ethiopian Restaurant',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.3,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Wah Sing Restaurant',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4,
#    'Site Name': 'Hill-East Neighborhood',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': '701 Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Ethiopic Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': '1905 Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': '14K Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Equinox Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'DECLARATION RESTAURANT',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.9,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Carmine's Italian Restaurant - Washington DC",
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Estadio',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Occidental Grill & Seafood Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chercher Ethiopian Restaurant & Mart',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Himalayan Heritage Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jojo Restaurant & Bar',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Madrid Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Meze Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Siroc Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Irish Channel Restaurant & Pub',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Thaitanic Restaurant',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jaleo',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'The Source by Wolfgang Puck',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'TGI Fridays',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Alborz Restaurant',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Bistro Ka Japanese Restaurant',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Mazar Mediterranean Restaurant / lounge',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.3,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Shirin Restaurant',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.1,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Henri's Restaurant",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Red Robin Gourmet Burgers',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "BJ's Restaurant & Brewhouse",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "P.F. Chang's",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Olive Garden Italian Restaurant',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.1,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.1,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Kabuki Japanese Restaurant',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Red Lobster',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Maggiano's Little Italy",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.3,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'California Pizza Kitchen at Topanga Mall',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle Mexican Grill',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.6,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Le Pain Quotidien',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.8,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'IHOP',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.2,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.9,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.2,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Wolf Creek Restaurant and Brewing Company',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Kisho Japanese Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Presidente Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Vines Restaurant & Bar',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.5,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Shogun Sushi Japanese Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Denny's",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Olive Garden Italian Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Buca di Beppo Italian Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.8,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Islands Restaurant Santa Clarita',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Red Robin Gourmet Burgers',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Cafe Rio Mexican Grill',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'New Moon Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'The Cheesecake Factory',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.8,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "BJ's Restaurant & Brewhouse",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.6,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'IHOP',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3.6,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Lazy Dog Restaurant & Bar',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Kabuki Japanese Restaurant',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Marston's Restaurant",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'California Pizza Kitchen at Valencia',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.2,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Coco Palm Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.4,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'La Paloma Mexican Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.3,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Denny's",
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.7,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Pomona Valley Mining Co',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.3,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Los Jarritos Restaurants',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.4,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.8,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Jack In The Box',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.6,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'El Pollo Loco',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 2.8,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Wienerschnitzel',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.9,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Carl's Jr.",
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.6,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Aladdin Jr',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.5,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "McKinley's Grille",
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.2,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Thai Orchid Garden',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.5,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'El Merendero Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.2,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Las Margaritas Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.4,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Aoki Japanese Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.9,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Jasmine's Restaurant & Hookah Lounge",
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.5,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Avalon Restaurant',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'iCuisine',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.3,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Pizza Hut',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.3,
#    'Site Name': 'Pomona Fairplex',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Mario's",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.6,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': '99 Restaurants',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.7,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Margarita's Mexican Restaurant",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.7,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Friendly's",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.5,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Chili's Grill & Bar",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.8,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'U Food Grill',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 2.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Dine Boston Bar & Grille',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.1,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Oliveira's Restaurant",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.2,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.2,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 2.4,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "D'Parma Restaurant",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.4,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Donna's Restaurant",
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'THMOR DA Restaurant',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.6,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Mama Blanca Restaurant',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'El Kiosco',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 3.9,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Little Asia Restaurant',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Antique Table Restaurant',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.7,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'El Palmar Restaurante',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.5,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'La Chiva Restaurant',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Adriatic Restaurant & Bar',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.3,
#    'Site Name': 'Suffolk Downs',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Meritage Restaurant',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.8,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Marliave',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.3,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Lincoln Tavern & Restaurant',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.3,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Empire',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.4,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "Parker's Restaurant",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Capo Restaurant',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.5,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'North 26 Restaurant & Bar',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.9,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Amrheins Restaurant',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.2,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Legal Harborside',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.3,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': "McCormick & Schmick's Seafood & Steaks",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.1,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'The Palm Boston',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.3,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 4,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.5,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.9,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.6,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'SUBWAY®Restaurants',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.8,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Legal Sea Foods',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.2,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 'NAN',
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chipotle',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 1,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Ocean Prime',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.6,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 3,
#    'restaurant Total Count': 20},
#   {'Facility restaurant': 'Chart House',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4,
#    'Site Name': 'South Boston Waterfront',
#    'price_level': 2,
# ...
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 3,
#    'Site Name': 'Midtown',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'White Windmill Bakery and Cafe',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.5,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Sweet Hut Bakery Cafe',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.5,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Mozart Bakery',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.5,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Moonbird Coffee',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.7,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Hello Gorgeous! Boutique',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.7,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Planet Hookah Cafe',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.8,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'ZenTea Tea House',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.6,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 'NAN'},
#   {'Facility cafe': "Dunkin' Donuts",
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 3.8,
#    'Site Name': 'Former GM plant',
#    'cafe Total Count': 8,
#    'price_level': 1},
#   {'Facility cafe': 'Cafe 290',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.2,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Chapmans Cafe and Catering',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 5,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Breadwinner Cafe and Bakery',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.4,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Soho Cafe and Bakery',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.7,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': "Clay's Sports Cafe",
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.5,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Flying Biscuit Cafe',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.2,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 2},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.4,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 2},
#   {'Facility cafe': 'Café Vendôme',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.5,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 1},
#   {'Facility cafe': 'Cafe Posh',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.1,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 3.6,
#    'Site Name': 'The High Street Site',
#    'cafe Total Count': 10,
#    'price_level': 2},
#   {'Facility cafe': 'Café No Sé',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.1,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': 'Bouldin Creek Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.6,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Zocalo Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.2,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': 'Elizabeth Street Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 3},
#   {'Facility cafe': "Alta's Cafe",
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Blue Cat Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Counter Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.4,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': 'Blanton Café',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': '1886 Cafe & Bakery',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.1,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': "Jo's Coffee",
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Slake Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': "Jo's Coffee",
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.1,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': 'Thistle Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.7,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 2},
#   {'Facility cafe': 'Mañana',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.6,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Flat Track Coffee',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.7,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Old Pecan Street Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.2,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Messhall Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Daily Juice Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'The Story of Texas Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.3,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Juan Pelota Cafe',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.4,
#    'Site Name': 'American-Statesman ',
#    'cafe Total Count': 20,
#    'price_level': 1},
#   {'Facility cafe': 'Cafe Malta',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.3,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 2},
#   {'Facility cafe': 'Tinos Greek Cafe',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Crema Bakery & Cafe',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 1},
#   {'Facility cafe': 'Evangeline Cafe',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.5,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 2},
#   {'Facility cafe': 'Galaxy Cafe',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.2,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 2},
#   {'Facility cafe': 'Summer Moon Coffee Bar',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.6,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 1},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 3.9,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 2},
#   {'Facility cafe': 'Allegro Coffee Company',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 'NAN',
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Kerbey Lane Cafe',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.3,
#    'Site Name': 'Former 3M site',
#    'cafe Total Count': 9,
#    'price_level': 1},
#   {'Facility cafe': 'Summermoon Coffee Bar',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.6,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 1},
#   {'Facility cafe': 'Cafe Java',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.7,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 1},
#   {'Facility cafe': "Kiefer's Cafe & Catering",
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.4,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': "Mimi's Cafe",
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 3.9,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Tinos Greek Cafe',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 3.9,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'la Madeleine French Bakery & Café Arboretum',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.1,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Tropical Smoothie Cafe',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 2.3,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Bee Cave Coffee Co.',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Apanas Coffee & Beer',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.5,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 1},
#   {'Facility cafe': 'barnes & Noble cafe featuring Starbucks',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 'NAN',
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Allegro Coffee Company',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 5,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Starbucks Reserve Bar',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.5,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.2,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 2},
#   {'Facility cafe': 'Garden Spot Cafe',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.7,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 'NAN'},
#   {'Facility cafe': "It's A Grind Coffee House",
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.3,
#    'Site Name': 'The Domain',
#    'cafe Total Count': 16,
#    'price_level': 1},
#   {'Facility cafe': 'Rice Bowl Cafe',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.2,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 2},
#   {'Facility cafe': 'Summermoon Coffee Bar',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.6,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 1},
#   {'Facility cafe': 'Cafe Java',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.7,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 1},
#   {'Facility cafe': "Mimi's Cafe",
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 3.9,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 2},
#   {'Facility cafe': "Kiefer's Cafe & Catering",
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.4,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 2},
#   {'Facility cafe': 'Tinos Greek Cafe',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 3.9,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 2},
#   {'Facility cafe': 'Tropical Smoothie Cafe',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 2.3,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Bee Cave Coffee Co.',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Apanas Coffee & Beer',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.5,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 1},
#   {'Facility cafe': 'Allegro Coffee Company',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 5,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 'NAN'},
#   {'Facility cafe': 'Starbucks Reserve Bar',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.5,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 2},
#   {'Facility cafe': 'Garden Spot Cafe',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.7,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 'NAN'},
#   {'Facility cafe': "It's A Grind Coffee House",
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.3,
#    'Site Name': 'Bardmoor Campus',
#    'cafe Total Count': 13,
#    'price_level': 1},
#   {'Facility cafe': 'Cuppa Austin',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4.6,
#    'Site Name': 'Robinson Ranch',
#    'cafe Total Count': 4,
#    'price_level': 1},
#   {'Facility cafe': 'Starbucks',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4,
#    'Site Name': 'Robinson Ranch',
#    'cafe Total Count': 4,
#    'price_level': 2},
#   {'Facility cafe': 'Kerbey Lane Cafe',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4.1,
#    'Site Name': 'Robinson Ranch',
#    'cafe Total Count': 4,
#    'price_level': 2},
#   {'Facility cafe': 'Tinos Greek Cafe',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 4,
#    'Site Name': 'Robinson Ranch',
#    'cafe Total Count': 4,
#    'price_level': 2}]]

# %%
all_restaurant_rating_df = pd.DataFrame(all_eatingout_rating[0])
all_restaurant_rating_df
# Out:
#                                Facility restaurant Latitude Longitude Rating  \
# 0       NED DEVINE'S IRISH SPORTS BAR & RESTAURANT    38.96    -77.42    3.7
# 1              Anatolian Bistro Turkish Restaurant    38.96    -77.42    4.8
# 2                            China King Restaurant    38.96    -77.42    3.2
# 3                                       Houlihan's    38.96    -77.42    3.4
# 4                            Elements On Level One    38.96    -77.42    3.2
# 5                         Carrabba's Italian Grill    38.96    -77.42    2.2
# 6                            Moe's Southwest Grill    38.96    -77.42    3.8
# 7                               SUBWAY®Restaurants    38.96    -77.42    3.7
# 8                               SUBWAY®Restaurants    38.96    -77.42    3.9
# 9                               SUBWAY®Restaurants    38.96    -77.42    3.7
# 10                          Chipotle Mexican Grill    38.96    -77.42    3.8
# 11                                     Au Bon Pain    38.96    -77.42    4.3
# 12                                     Smashburger    38.96    -77.42    3.3
# 13                                       Bar Louie    38.96    -77.42    4.1
# 14                                     TGI Fridays    38.96    -77.42      3
# 15                Cracker Barrel Old Country Store    38.96    -77.42    4.1
# 16                             Noodles and Company    38.96    -77.42    3.8
# 17                                         Wendy's    38.96    -77.42    3.7
# 18                               Chao Phra YA Thai    38.96    -77.42    4.5
# 19                               Chuck E. Cheese's    38.96    -77.42    3.8
# 20                          Fyve Restaurant Lounge    38.84    -77.05    4.6
# 21                            Portofino Restaurant    38.84    -77.05    4.1
# 22                           Young Chow Restaurant    38.84    -77.05      3
# 23                             Live Oak Restaurant    38.84    -77.05    4.4
# 24                                 RT's Restaurant    38.84    -77.05    4.5
# 25           Rustico Restaurant & Bar - Alexandria    38.84    -77.05    4.2
# 26                           China Cafe restaurant    38.84    -77.05    3.5
# 27                                           Jaleo    38.84    -77.05    4.2
# 28          McCormick & Schmick's Seafood & Steaks    38.84    -77.05    3.1
# 29                              SUBWAY®Restaurants    38.84    -77.05    3.7
# ..                                             ...      ...       ...    ...
# 694                                    Taco Cabana  30.4014  -97.7147    3.2
# 695                       Shake Shack - The Domain  30.4014  -97.7147    3.9
# 696                                   Flower Child  30.4014  -97.7147    4.6
# 697                         Gloria's Latin Cuisine  30.4014  -97.7147    4.2
# 698                                  Panda Express  30.4014  -97.7147    3.7
# 699                         Chipotle Mexican Grill  30.4014  -97.7147      4
# 700                                     Chi'lantro  30.4014  -97.7147    4.2
# 701                                 Sonic Drive-In  30.4014  -97.7147    3.6
# 702                                Wienerschnitzel  30.4014  -97.7147    4.1
# 703                                     Sam's Boat  30.4014  -97.7147    3.9
# 704                                    Chick-fil-A  30.4014  -97.7147    4.3
# 705  Pacific Star Restaurant & Oyster Bar - Austin  30.4704  -97.7701      4
# 706                             Vazquez Restaurant  30.4704  -97.7701      4
# 707                                   Jason's Deli  30.4704  -97.7701    4.1
# 708                                       Wingstop  30.4704  -97.7701    2.3
# 709                                         Arby's  30.4704  -97.7701    4.5
# 710                                           IHOP  30.4704  -97.7701    3.7
# 711                                    Whataburger  30.4704  -97.7701      4
# 712                                 Sonic Drive-In  30.4704  -97.7701    2.6
# 713                                            KFC  30.4704  -97.7701    3.2
# 714                               Church's Chicken  30.4704  -97.7701    2.6
# 715                                    Chick-fil-A  30.4704  -97.7701    4.4
# 716                        Osaka Mansun Restaurant  30.4704  -97.7701    4.5
# 717                                   Midori Sushi  30.4704  -97.7701    4.3
# 718                             SUBWAY®Restaurants  30.4704  -97.7701    2.8
# 719                             SUBWAY®Restaurants  30.4704  -97.7701    3.8
# 720                             Nanking Restaurant  30.4704  -97.7701    4.2
# 721                           First Watch - Walden  30.4704  -97.7701    3.5
# 722                                  Jardin Corona  30.4704  -97.7701    4.3
# 723                      Meches Mexican Restaurant  30.1338  -97.6411    4.5
#
#                             Site Name price_level  restaurant Total Count
# 0    Center for Innovation Technology           2                      20
# 1    Center for Innovation Technology         NAN                      20
# 2    Center for Innovation Technology           2                      20
# 3    Center for Innovation Technology         NAN                      20
# 4    Center for Innovation Technology         NAN                      20
# 5    Center for Innovation Technology         NAN                      20
# 6    Center for Innovation Technology           1                      20
# 7    Center for Innovation Technology           1                      20
# 8    Center for Innovation Technology           1                      20
# 9    Center for Innovation Technology           1                      20
# 10   Center for Innovation Technology           1                      20
# 11   Center for Innovation Technology           1                      20
# 12   Center for Innovation Technology           1                      20
# 13   Center for Innovation Technology         NAN                      20
# 14   Center for Innovation Technology           2                      20
# 15   Center for Innovation Technology           1                      20
# 16   Center for Innovation Technology           2                      20
# 17   Center for Innovation Technology           1                      20
# 18   Center for Innovation Technology           2                      20
# 19   Center for Innovation Technology           2                      20
# 20      Crystal City and Potomac Yard           3                      20
# 21      Crystal City and Potomac Yard           2                      20
# 22      Crystal City and Potomac Yard           2                      20
# 23      Crystal City and Potomac Yard           2                      20
# 24      Crystal City and Potomac Yard           2                      20
# 25      Crystal City and Potomac Yard           2                      20
# 26      Crystal City and Potomac Yard           2                      20
# 27      Crystal City and Potomac Yard           2                      20
# 28      Crystal City and Potomac Yard           2                      20
# 29      Crystal City and Potomac Yard           1                      20
# ..                                ...         ...                     ...
# 694                   Bardmoor Campus           1                      20
# 695                   Bardmoor Campus           1                      20
# 696                   Bardmoor Campus           2                      20
# 697                   Bardmoor Campus           2                      20
# 698                   Bardmoor Campus           1                      20
# 699                   Bardmoor Campus           1                      20
# 700                   Bardmoor Campus           1                      20
# 701                   Bardmoor Campus           1                      20
# 702                   Bardmoor Campus           1                      20
# 703                   Bardmoor Campus         NAN                      20
# 704                   Bardmoor Campus           1                      20
# 705                    Robinson Ranch           2                      18
# 706                    Robinson Ranch           2                      18
# 707                    Robinson Ranch           2                      18
# 708                    Robinson Ranch           1                      18
# 709                    Robinson Ranch         NAN                      18
# 710                    Robinson Ranch           1                      18
# 711                    Robinson Ranch           1                      18
# 712                    Robinson Ranch           1                      18
# 713                    Robinson Ranch           1                      18
# 714                    Robinson Ranch           1                      18
# 715                    Robinson Ranch           1                      18
# 716                    Robinson Ranch           2                      18
# 717                    Robinson Ranch           3                      18
# 718                    Robinson Ranch           1                      18
# 719                    Robinson Ranch           1                      18
# 720                    Robinson Ranch           2                      18
# 721                    Robinson Ranch         NAN                      18
# 722                    Robinson Ranch           1                      18
# 723                  Project Catalyst         NAN                       1
#
# [724 rows x 7 columns]

# %%
all_cafe_rating_df = pd.DataFrame(all_eatingout_rating[1])
all_cafe_rating_df
# Out:
#                                    Facility cafe Latitude Longitude Rating  \
# 0                                        Cafe 28    38.96    -77.42    3.6
# 1                            Epicurean Cafe Deli    38.96    -77.42    4.6
# 2                               Fresh Start Cafe    38.96    -77.42      5
# 3                              Central Park Cafe    38.96    -77.42    4.8
# 4                                  Cafe Woodland    38.96    -77.42    3.3
# 5                             Uptown@Dulles Cafe    38.96    -77.42    4.5
# 6                                    Uptown Cafe    38.96    -77.42      3
# 7                                      Starbucks    38.96    -77.42    3.8
# 8                         Tropical Smoothie Cafe    38.96    -77.42    3.8
# 9                                      Starbucks    38.96    -77.42      3
# 10                                     Starbucks    38.96    -77.42    4.5
# 11                                     Starbucks    38.96    -77.42    4.1
# 12                                   Uptown Cafe    38.96    -77.42    4.3
# 13                                  Del Ray Café    38.84    -77.05    4.4
# 14                              Ease Yoga & Cafe    38.84    -77.05    4.8
# 15                                    Cafe Manna    38.84    -77.05    3.3
# 16                                Swing's Coffee    38.84    -77.05    4.6
# 17                         St. Elmo's Coffee Pub    38.84    -77.05    4.2
# 18                 Bon Vivant Cafe + Farm Market    38.84    -77.05    4.2
# 19                                  Gallery Cafe    38.84    -77.05    2.5
# 20                                   Sahara Cafe    38.84    -77.05    4.2
# 21              Commonwealth Joe Coffee Roasters    38.84    -77.05    4.8
# 22                                Paramount Cafe    38.84    -77.05    4.8
# 23                            Espressamente Illy    38.84    -77.05    4.2
# 24                                   Uptown Cafe    38.84    -77.05    4.5
# 25                                Jefferson Cafe    38.84    -77.05    4.8
# 26                                 Buzz Bakeshop    38.84    -77.05    4.2
# 27                                   Au Bon Pain    38.84    -77.05    3.3
# 28                            Green Beans Coffee    38.84    -77.05    2.2
# 29                                  Espresso Bar    38.84    -77.05    NAN
# ..                                           ...      ...       ...    ...
# 534                                  Mimi's Cafe  30.4015  -97.7268    3.9
# 535                             Tinos Greek Cafe  30.4015  -97.7268    3.9
# 536  la Madeleine French Bakery & Café Arboretum  30.4015  -97.7268    4.1
# 537                       Tropical Smoothie Cafe  30.4015  -97.7268    2.3
# 538                          Bee Cave Coffee Co.  30.4015  -97.7268      4
# 539                         Apanas Coffee & Beer  30.4015  -97.7268    4.5
# 540      barnes & Noble cafe featuring Starbucks  30.4015  -97.7268    NAN
# 541                       Allegro Coffee Company  30.4015  -97.7268      5
# 542                        Starbucks Reserve Bar  30.4015  -97.7268    4.5
# 543                                    Starbucks  30.4015  -97.7268      4
# 544                                    Starbucks  30.4015  -97.7268    4.2
# 545                             Garden Spot Cafe  30.4015  -97.7268    4.7
# 546                    It's A Grind Coffee House  30.4015  -97.7268    4.3
# 547                               Rice Bowl Cafe  30.4014  -97.7147    4.2
# 548                        Summermoon Coffee Bar  30.4014  -97.7147    4.6
# 549                                    Cafe Java  30.4014  -97.7147    4.7
# 550                                  Mimi's Cafe  30.4014  -97.7147    3.9
# 551                     Kiefer's Cafe & Catering  30.4014  -97.7147    4.4
# 552                             Tinos Greek Cafe  30.4014  -97.7147    3.9
# 553                       Tropical Smoothie Cafe  30.4014  -97.7147    2.3
# 554                          Bee Cave Coffee Co.  30.4014  -97.7147      4
# 555                         Apanas Coffee & Beer  30.4014  -97.7147    4.5
# 556                       Allegro Coffee Company  30.4014  -97.7147      5
# 557                        Starbucks Reserve Bar  30.4014  -97.7147    4.5
# 558                             Garden Spot Cafe  30.4014  -97.7147    4.7
# 559                    It's A Grind Coffee House  30.4014  -97.7147    4.3
# 560                                 Cuppa Austin  30.4704  -97.7701    4.6
# 561                                    Starbucks  30.4704  -97.7701      4
# 562                             Kerbey Lane Cafe  30.4704  -97.7701    4.1
# 563                             Tinos Greek Cafe  30.4704  -97.7701      4
#
#                             Site Name  cafe Total Count price_level
# 0    Center for Innovation Technology                13         NAN
# 1    Center for Innovation Technology                13         NAN
# 2    Center for Innovation Technology                13         NAN
# 3    Center for Innovation Technology                13         NAN
# 4    Center for Innovation Technology                13         NAN
# 5    Center for Innovation Technology                13         NAN
# 6    Center for Innovation Technology                13         NAN
# 7    Center for Innovation Technology                13           2
# 8    Center for Innovation Technology                13         NAN
# 9    Center for Innovation Technology                13         NAN
# 10   Center for Innovation Technology                13         NAN
# 11   Center for Innovation Technology                13           2
# 12   Center for Innovation Technology                13         NAN
# 13      Crystal City and Potomac Yard                17           2
# 14      Crystal City and Potomac Yard                17         NAN
# 15      Crystal City and Potomac Yard                17         NAN
# 16      Crystal City and Potomac Yard                17         NAN
# 17      Crystal City and Potomac Yard                17         NAN
# 18      Crystal City and Potomac Yard                17         NAN
# 19      Crystal City and Potomac Yard                17         NAN
# 20      Crystal City and Potomac Yard                17         NAN
# 21      Crystal City and Potomac Yard                17           2
# 22      Crystal City and Potomac Yard                17         NAN
# 23      Crystal City and Potomac Yard                17         NAN
# 24      Crystal City and Potomac Yard                17         NAN
# 25      Crystal City and Potomac Yard                17         NAN
# 26      Crystal City and Potomac Yard                17           1
# 27      Crystal City and Potomac Yard                17           2
# 28      Crystal City and Potomac Yard                17         NAN
# 29      Crystal City and Potomac Yard                17         NAN
# ..                                ...               ...         ...
# 534                        The Domain                16           2
# 535                        The Domain                16           2
# 536                        The Domain                16           2
# 537                        The Domain                16         NAN
# 538                        The Domain                16         NAN
# 539                        The Domain                16           1
# 540                        The Domain                16           2
# 541                        The Domain                16         NAN
# 542                        The Domain                16           2
# 543                        The Domain                16           2
# 544                        The Domain                16           2
# 545                        The Domain                16         NAN
# 546                        The Domain                16           1
# 547                   Bardmoor Campus                13           2
# 548                   Bardmoor Campus                13           1
# 549                   Bardmoor Campus                13           1
# 550                   Bardmoor Campus                13           2
# 551                   Bardmoor Campus                13           2
# 552                   Bardmoor Campus                13           2
# 553                   Bardmoor Campus                13         NAN
# 554                   Bardmoor Campus                13         NAN
# 555                   Bardmoor Campus                13           1
# 556                   Bardmoor Campus                13         NAN
# 557                   Bardmoor Campus                13           2
# 558                   Bardmoor Campus                13         NAN
# 559                   Bardmoor Campus                13           1
# 560                    Robinson Ranch                 4           1
# 561                    Robinson Ranch                 4           2
# 562                    Robinson Ranch                 4           2
# 563                    Robinson Ranch                 4           2
#
# [564 rows x 7 columns]

# %%
all_cafe_rating_df.to_csv("Cafe_Rating.csv")

# %%
all_restaurant_rating_df.to_csv("Restaurant_Rating.csv")

# %%
# geocoordinates
target_coordinates = '38.96,-77.42'
target_search = 'restaurant'
target_radius = 2500
target_type = 'Restaurant'
#print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
print("----------")
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()
results = response.get('results')
# Out:
# ----------

# %%
results
# Out:
# [{'geometry': {'location': {'lat': 38.9516461, 'lng': -77.40930279999999},
#    'viewport': {'northeast': {'lat': 38.95289547989272,
#      'lng': -77.40782302010727},
#     'southwest': {'lat': 38.95019582010728, 'lng': -77.41052267989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'f5474a007bbf8aeda8ff931155aa674038635790',
#   'name': "Stone's Cove Kitbar",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1229,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104624375199943783692/photos">Stone&#39;s Cove Kitbar .</a>'],
#     'photo_reference': 'CmRaAAAASGaAGJlR1NVJ0K81ZxhaLRty1CQsVIozXhxQRNkbINZgaZWOXIDz30aYel0StuD5J3N2IO57VwuHFWMO6igfZWADo4AdCm3_G2B1vyT7XrtEY4_IfykSJBz5IepkvZ8yEhBSuUUUx-bfMqC1A2MjmXxsGhTsS4Kp2gJMk3Mj-ijkmuN-gjTwcQ',
#     'width': 2048}],
#   'place_id': 'ChIJ12VH3ZZHtokR-8N2xTFZAFI',
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'CmRbAAAA48Sw_plTWYXjYqcE0js1rgCVefdryONIDkY_9TZdwu9TnfKffiv2Gt1WMuOyZYRShVFWADMMA_HmWjS2GYYKl6yH_HNHmCfTn5dMJxctdoJsUYF7ipo-4bFCKg9SKrmrEhC2x91Fh8rUFymuA9ghPcC6GhTE65FDTIftUz1Z5BIAkV2-6VPH_g',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2403 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9616858, 'lng': -77.3985107},
#    'viewport': {'northeast': {'lat': 38.96316622989272,
#      'lng': -77.39691487010728},
#     'southwest': {'lat': 38.96046657010727, 'lng': -77.39961452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'cd7eb190d01776de1bf17e500b53a982c0105dea',
#   'name': 'Grill Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104090059274588000035/photos">Royal Sedan</a>'],
#     'photo_reference': 'CmRaAAAAJQ08fwfEAk0gZlzOkVZhwFDw45pMtxs4_8ocCgRjpNe9v6xAOdqPWvBYvuINMNUDj1QpiDUKzEmLb7i5Imb2g9G_QBpNdnUs0t9wDjCNj3Obddn3XkPOt8J_JlTHDGMHEhDCk9aHkRAbGsOQAvJX0JnUGhSoWF6T1bKCIPlMLF4Zn_rXVYkK3w',
#     'width': 4128}],
#   'place_id': 'ChIJu-16iPNHtokR97zBSb2gGBQ',
#   'rating': 4,
#   'reference': 'CmRbAAAA0Yb6jMlMMNmfmdXGYhcS59l-bRsVrDtKMWs8Sxl7FQyeEsjloDWwMeR5rYYwi4vonrS0NYxb7UMc73AZA3ftm0NzbMEZOgB_5vNJaw1PiL3ro8uVpf7T-b4Y4Wg_wsq0EhD5HeBk4dkjxrYJ4kTA3PsJGhT6CrecEOJ6sM3OoeQWTv3kFdhufw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '905 Herndon Pkwy # F, Herndon'},
#  {'geometry': {'location': {'lat': 38.9637234, 'lng': -77.3971565},
#    'viewport': {'northeast': {'lat': 38.96528557989272,
#      'lng': -77.39628927010727},
#     'southwest': {'lat': 38.96258592010727, 'lng': -77.39898892989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'ef2a33d1ad4e9511c03341de5e6a1ac60bf1abe1',
#   'name': 'Amphora Diner Deluxe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104016859568650225547/photos">A Google User</a>'],
#     'photo_reference': 'CmRaAAAAlS_AgujsFSub8i7HNVQjBAgEfh9aEaNlrPhrRoAfRQ-KXJhrKlgVba-2nwYQCjTFUyuFhTk4RRw4aOrQQmoOlagbqE9dKYCL_V11YMvlwJIAPzKJGE_cs-xnXkUCwCOjEhBZL1Jt82TbBgk8b8o0DDqXGhRySlcgxdOAwucdEc5bCkOgWXysKQ',
#     'width': 2048}],
#   'place_id': 'ChIJWVcERfRHtokRW9oscZS9Hyc',
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'CmRbAAAAxKo3XdtCD3_CPQGk_9b8JRcVfc7If23tnm7Ld0v-P850m_Dv2_zSj3rb3n20wVnGX2n5WheCfqRAK_CeYMdunYMjXz8jB5NzanYCu0r3-zbNyUkgV4lyYoXDpVSEgmaVEhBQuKEengwoVQbKkAw-yyK9GhSYTFFKoJKm-lf2mflXIXFBjM2jng',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1151 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9799278, 'lng': -77.43275589999999},
#    'viewport': {'northeast': {'lat': 38.9821982, 'lng': -77.43184287010727},
#     'southwest': {'lat': 38.97917099999999, 'lng': -77.43454252989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8291f6b3bba3e38c4a922b77a06d34d0c6b7bf76',
#   'name': 'Cracker Barrel Old Country Store',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115128327407342395621/photos">Darrell Brock</a>'],
#     'photo_reference': 'CmRaAAAA6DWSWKxMtS20uxDCI1oQOHCVptR576IX6giPoH66C0HVVjrExe5cEP9LB02p9Fx0r65liX1icr5dsljTrAGTzZOZY3bprOilgFST1L81_OwC1nSn20nEXKGdDz6c39oyEhDEQa_mQNoUYqXUTrzqJykwGhQIHT7c0pQxw0lgWb4P5ILGJhIDDw',
#     'width': 3984}],
#   'place_id': 'ChIJ3SY8YY84tokRQuEPIq1BlSc',
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'CmRbAAAAcQaeS5qKBlG4XJvLT1NhfhTMJbQXSdNWJXOOkBEKyaiiIfDK9ljRCGkANCRLXZkXh1MRnA-f-f5VmdoP3mTaCJqNtLOpH37t1Rt7reZmfVrGEWhz0h7mN4SbYFV4WWlfEhCBZjX_S6328qlH8c6JZ0vGGhSLXCJKfNWLDoworgxxsIhss047QQ',
#   'scope': 'GOOGLE',
#   'types': ['store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '23030 Indian Creek Dr, Sterling'},
#  {'geometry': {'location': {'lat': 38.9586216, 'lng': -77.403313},
#    'viewport': {'northeast': {'lat': 38.95984262989271,
#      'lng': -77.40174572010727},
#     'southwest': {'lat': 38.95714297010727, 'lng': -77.40444537989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2df21a3eef33456e061a049e742db552a6a7aa22',
#   'name': "Houlihan's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117979874678644930975/photos">Jose Gonzalez</a>'],
#     'photo_reference': 'CmRaAAAAjIWMFEdNVRDv0GiDgcW5CoVgkWSRODiPHKUWhFBsbR16OZWGnXZpdIWKmHapCBLRoewn4dzaf9L4WgXmpAnNQG02loIOLCHO1sZZGLe40Ekb6vRRKx2SMjXAhGBVYsHqEhAC2gdPYHB_kMrlatM7lFv7GhSlPUZgdiWH2PpMs6O7GYWF5Hj67g',
#     'width': 3840}],
#   'place_id': 'ChIJR9j6co1HtokRMan0ua8RMAI',
#   'rating': 3.4,
#   'reference': 'CmRbAAAATZVzON7aSPeDNWy4vu8F9dsXNOfeTfoipHMMNxFcZ87ulrVHOu28JcCKpFutINECcE_l-UOJX2_hyMcej7ycM5NrSlZH8oDAvbiOk83-R10fdeMG0MU0NccP4RK3AAN6EhBC8nbmfr9_ZQzujbiqQ559GhT7C0lvKZE0GcMVo2m9uOGOIScmsA',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2200 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9609335, 'lng': -77.4232561},
#    'viewport': {'northeast': {'lat': 38.96228332989271,
#      'lng': -77.42190627010729},
#     'southwest': {'lat': 38.95958367010726, 'lng': -77.42460592989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8763954c34046f3742a948fbef22f84466a142a8',
#   'name': 'Elements On Level One',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115497934970694920599/photos">Travis Baumgart</a>'],
#     'photo_reference': 'CmRaAAAAZvZg62pc05ZPtvgwDboxhVuaFGB5kaMyPRJvgU9ikIm0oKU9XpLymCsg2dAwVPmrgklEKjrxAWU0C9O9mX_x1NRGtM9uQjGgbI6samUCZbVmBqbyFJlbz0r8n2wmzK61EhAzAfGf3vJS1HEwaPo99WrVGhTvCESAsfTh3EW-mGSWwQrBH-t7_g',
#     'width': 1836}],
#   'place_id': 'ChIJQUumvYJHtokRqccDrDqJrWw',
#   'rating': 3.2,
#   'reference': 'CmRbAAAASzY9QoL34OsE0-bMwKkwqvSGESOFXAUbdSS_wCDyx32sGT4DqIovcdFSQAVlsP-6d7m9MVo1_ne3mwaJz-zQ7T5LWV7wr8uC-aaq_JMtdI2tSFkifwnqUJCSAtxmFN2AEhCqnng9dRN4UIn4_Sx-CHSxGhSinNGlBgVeE2NKLZ4dfYtxjoJemw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2300 Dulles Corner Blvd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9485969, 'lng': -77.4484299},
#    'viewport': {'northeast': {'lat': 38.94994672989272,
#      'lng': -77.44708007010728},
#     'southwest': {'lat': 38.94724707010727, 'lng': -77.44977972989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '06a163a0056f7b4dbcc5b81ccb963cbb41094368',
#   'name': "Carrabba's Italian Grill",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105320630398470954348/photos">Jose March-Leuba</a>'],
#     'photo_reference': 'CmRaAAAAM59oXNqRDOa6-VT5zfGa8i3SFIHwv927-FsnA7VLEfOoCON-fN5AxarrKpZDfAEysQ3b8Umnk6Mbtqm5N3aXskSvjoRpf0s9qeTMUxRbZfzxEi-LrCY07kYqsFWkdEBgEhAVcuTtwEixFwrIOXm8YmgOGhRyfjPeVvsTuYwWsRzgirfPnq3enA',
#     'width': 4160}],
#   'place_id': 'ChIJk-7gGkBHtokR3NGlod2wO_0',
#   'rating': 2.2,
#   'reference': 'CmRbAAAA2rNSviQO5mj3rsATRR_hBJg-EDPX4Y-gx09gLY3XbgbNyNYO5P5Cb8EK06znn-aBCbjllBx0uCyP6MoqTzht5nFY4HuVICPG6cURuZqwWiWwxTXFPaKmjB0n4b7GMFlUEhCZB3vGSvhcDS-9Pb4nDHAPGhQMyWiy8A8vSrVIHFv-1JPaGPFGOg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Washington Dulles International Airport, Concourse B, Gate B41, 1 Saarinen Cir, Dulles'},
#  {'geometry': {'location': {'lat': 38.9454736, 'lng': -77.4448961},
#    'viewport': {'northeast': {'lat': 38.94682342989272,
#      'lng': -77.44354627010728},
#     'southwest': {'lat': 38.94412377010728, 'lng': -77.44624592989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '457d0af235f15c4cd9c9371ebb022d92156b71d5',
#   'name': 'Au Bon Pain',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114229034596052359026/photos">Nouni USALG</a>'],
#     'photo_reference': 'CmRaAAAALTyzfY_upe1gx1ezgt06MjLjZxwVkXtsBss_8a8BXWn3DOtrQXTSnE7Zhbhoc0LxMwFPzchfbDJEWvkqwWY1on7CaDy02ryid5ITHFN4L4ej4hN-BYRTeYizDR-afrMmEhCBLtXkdBdWtv_qjuiGMD9sGhTkqw6uU2pvHOdVls7jWlAY8MIKNg',
#     'width': 4032}],
#   'place_id': 'ChIJebpXGkBHtokRgVuywowH18E',
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'CmRbAAAAnpBveKu86sW60irCMAdY-rE380VAdL6NR6kQN-Mj9QVDTqEItI1vSwqI52vsIMSv85azEvcOETJg2-6OTQiKn32zYA8XCuznWPscZgfcyUvaOvyo_jAoWN2-ah93Z8FqEhCPrR7katY0jrVuM8xZuGUGGhTBT2bh9nYByJ4jV3R8iWz1tqnp4g',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1 Saarinen Circle, Sterling'},
#  {'geometry': {'location': {'lat': 38.9643913, 'lng': -77.396605},
#    'viewport': {'northeast': {'lat': 38.96574112989272,
#      'lng': -77.39525517010728},
#     'southwest': {'lat': 38.96304147010727, 'lng': -77.39795482989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '47d42fe430bd7cf2e33080fde7c228a438fee688',
#   'name': "Paisano's Pizza",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2046,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111461259370706113420/photos">Paisano&#39;s Pizza</a>'],
#     'photo_reference': 'CmRaAAAA7MaB3lFJoPJzSfZUTP-0rYm6se5e04Z_-lNjOJLGbjUPntVV6PzoWUhtQLrsVvMYiHbTzdc54miKkbInh2dlCCApeZH4x-y86dW_dROyvMaH2aj4_2MraUEYyF7LqvnvEhA-Uc7BsrUOcOvyfDh0NKCWGhSrzKlQM1YwSzETCpw2lhfdIjOVgA',
#     'width': 2048}],
#   'place_id': 'ChIJn9qyTPRHtokRfNzSHf6kY7A',
#   'price_level': 2,
#   'rating': 3.5,
#   'reference': 'CmRbAAAA0ntoEP6FzwZrUraI3QocsCvJ-TzF1RLoWJcVjT7P3tRKH-rc3V46gsDeFgvZ3fxo3UNTwpvgHYGs6S7wGwVTXUdT5HEz2EwZBcZS9-1s-6Xw7G8DT2nmCVfZ4eXlf5J8EhCnsFUfBIrg1-4EiTVVH3JyGhRg5BSKLnKuX6XcCk3TN_pLfUdhvA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1141 Elden St #105, Herndon'},
#  {'geometry': {'location': {'lat': 38.9636296, 'lng': -77.3990669},
#    'viewport': {'northeast': {'lat': 38.96489667989272,
#      'lng': -77.39753292010728},
#     'southwest': {'lat': 38.96219702010728, 'lng': -77.40023257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'fa1dff8ffdb7c12f80f1a704198e9497ca474039',
#   'name': 'Chipotle Mexican Grill',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106158804692297980523/photos">Prem Nambi</a>'],
#     'photo_reference': 'CmRaAAAANfEv9g_p4PkJpWIW6NjKBqmc4OOLUw_EceNNkrVgxJHD8y1KhybFE0v7hmw9y-h08TXzvaht_TKKT089py_285rd2q-aCn9IXcJTqHcY6KAniUDC9eDKVFRANZjyJYUIEhCiErc-YgPFuQQBDssKgCzOGhTDfqeJ89pLsieuMFQ1-cmPDNGxfA',
#     'width': 1920}],
#   'place_id': 'ChIJJbJlVPRHtokR393UAAk2O0E',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAOkrPB0Ag39E5PyVTyOGG-xclQOuSDbBXkvKtlBCgHF_tdJTUg3blpk4kdtgT0tgEiD6E-m26lPE6TDGEyxyPbYcVuAe9E2MfP71x2DPX8mcEE7tsWVsamFyORy0QYFnlEhDsllzxJoWNixrHS9pQKMrvGhQTbbsD1gYIa3_XorN0JHgiK4KvYQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1144 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9491305, 'lng': -77.3957818},
#    'viewport': {'northeast': {'lat': 38.95046712989272,
#      'lng': -77.39437207010728},
#     'southwest': {'lat': 38.94776747010728, 'lng': -77.39707172989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'd7412cc8ad2598c8366009e2124d8f7d50338a19',
#   'name': 'Pei Wei',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103921559028635582224/photos">Laura I</a>'],
#     'photo_reference': 'CmRaAAAABrBRp3AIiXCTPjgMaiWvySvGYavYmqZVd2QwusqW3rjiuq4CsvkPIjDfgbxJ_Vf-9sOA_la5fXTiIY2txnI7tt0tU29o8uHNn17EZe0jlibtsaSGcKK0nu0J0TUHgYHREhASH5QQx7395hVQmMApQjUSGhQlrKZo31CXSWnEo4aURQyRVLRArg',
#     'width': 4048}],
#   'place_id': 'ChIJuxX0YulHtokROTeCrnmDx6k',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAARfIUD65GQ6YvWsJemvaUajQPNYPUrrzyQVqTq-Ded4ZY0eweVXPg4CtPF61CHyyzCQR-a9MYPlumUpK_jFB_yOs5Sd-GYboVCHDheFs3EMOS0UFLurdTaHxST8DroD9FEhCEVns-D4AeKkQdIctG8hWcGhTMNN4OEgSv_mSkovBKOvaeoyYIKA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2338 Woodland Crossing Dr Suite A, Herndon'},
#  {'geometry': {'location': {'lat': 38.9495279, 'lng': -77.39601019999999},
#    'viewport': {'northeast': {'lat': 38.95093377989272,
#      'lng': -77.39460157010727},
#     'southwest': {'lat': 38.94823412010727, 'lng': -77.39730122989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '45ada78434650665d6b95094e440377a0376dd38',
#   'name': 'Moby Dick House of Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3192,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115484345829336444608/photos">Jay Stearns</a>'],
#     'photo_reference': 'CmRaAAAA1EYQiG7yB7roxAcB3-LbPBQMNLYkPfn6Yzx94NNyiGTMCLb7d2IpXjVF-8Ta0oQlg0lpUzrsrrk7FOOU1wBPreEeXfQsH1q9RxBnXQLHwHpBCB5H7XuCSpPq0mY1rNkKEhCfu9do4duVEgkfSYAv2ywzGhRDgruvLghh4kYyHF-yRGEm8e_Blg',
#     'width': 4788}],
#   'place_id': 'ChIJywL52OtHtokRisWGJ7-RIaA',
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'CmRbAAAAcdjypZlLSsnQNLcstz0_fEXLuIv0olltwD91X7k4YpSVECJdCAEvPjG9MZ3L69ay4zf3994VP8Wr802aeaKZfJ1Llz-0omBhQy1ogZo7FrfedsyJ9FAoTNfjSqeT8GaqEhAYQvgMjDrpoTy5XZPbwteDGhSRc6jg5AjTeRKOnTOqQskZDQkJIw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '12975-A Highland Crossing Dr, Herndon'},
#  {'geometry': {'location': {'lat': 38.950228, 'lng': -77.409966},
#    'viewport': {'northeast': {'lat': 38.95173202989272,
#      'lng': -77.40874487010727},
#     'southwest': {'lat': 38.94903237010728, 'lng': -77.41144452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'e3e52fde9110807a4e1160e820da5e22ebaae51b',
#   'name': "Chuck E. Cheese's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114812587622428408666/photos">Rajiv Desai</a>'],
#     'photo_reference': 'CmRaAAAAYkfHIQ4rWMATFJFqMlq5BoL8b_W7bjWDG35GLSgqhkSoB9uEDfWiwpoD5EdUgRRoWdkKbnvxLGU6IIQsD9Nv8zeVZh4h2CuJgPcwDAK00uDmkAHN-L_NM5CDRc_2B_UyEhAoj9zr36E3AKkgjGKuYLKtGhT-0kKg0YWdI2gPY4SsCSBrIZDPMg',
#     'width': 1920}],
#   'place_id': 'ChIJ--fmB5dHtokRGXWPheoQWFk',
#   'price_level': 2,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAW16PTCBjJwW8yAf2rFrae6jjuKiPdenbM6ZbGicvwhA1U19YSTxmuwV_ufNsTI_CpgjwlrNwMrNYh5sQcyhrk_JQgwbuoDk63nqwBkCgU6ODIsKSbEgloE6F3z4ndt9yEhBK5Igf7MO5XhqS2pNy7SybGhSnYtJ4MxWUAO2KpV87VpJ3BjzaPw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2465 Centreville, Ste. J9, Herndon'},
#  {'geometry': {'location': {'lat': 38.9503091, 'lng': -77.4101694},
#    'viewport': {'northeast': {'lat': 38.95171102989272,
#      'lng': -77.40890717010728},
#     'southwest': {'lat': 38.94901137010728, 'lng': -77.41160682989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a306deb8f4f1680369ffa0d24715cba80b5cf6fd',
#   'name': 'Tropical Smoothie Cafe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 440,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105974514124910190354/photos">A Google User</a>'],
#     'photo_reference': 'CmRZAAAA0hEVeqMt3TUfVPRRYcm1LNQQO6NJcSc4khGEDtEML2PnO7TQiaBQZ9irxnyTfuZwWrAcroCvDh1NFFCGj4rQTh5sRUFdvmBtKFVVEhrN-qzcZD9eYjZy9HfpWvp8V6RMEhDny4bhI4c6dnicYoxVwF_pGhT4kNAKYs-zCJyW3wQer1PslgtWMg',
#     'width': 550}],
#   'place_id': 'ChIJ--fmB5dHtokRMr8-G7snM38',
#   'rating': 3.8,
#   'reference': 'CmRbAAAARnEq4v-2HN_nl70HuA2YGI5SndWJCdShzJ3HIO_wFT33Akprnk2YAc0R38gN3G7uXD26g3xLgf8KdXZFxPRSnaavOMTr80LMt6RMT3r3uX6X5iR4J1xNbMTX9PkqeTmTEhBvVXbUKhMmZsgO4wmuc0GxGhTZBDYFYO0OeUKu0vkZUg1aKl7uxg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant',
#    'cafe',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2465 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9662767, 'lng': -77.3960639},
#    'viewport': {'northeast': {'lat': 38.96771142989272,
#      'lng': -77.39491507010727},
#     'southwest': {'lat': 38.96501177010727, 'lng': -77.39761472989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'bed28b48fdb509bee6668f2a6f0f816d3ba15ce9',
#   'name': 'Pizza Hut',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAA-Q1wOuMEVyFRLDnFdWxpgipJaqGyh_zVWdmvouh3aF-9-JsiQgHp_OrWzrJJp72S0NNhLVewONWg5F9u8ZUwGRLZzdC_DMbZj4XVP7QC6aX9NweRgTNP_IDC0-8rXHKNEhAyepfknz1tBipqyuNCUxvgGhTy6sV1oawpHvrUIyMLE-LlDIWv9Q',
#     'width': 4032}],
#   'place_id': 'ChIJTyaR7PVHtokRYaAjBq0B7Pg',
#   'price_level': 1,
#   'rating': 3.4,
#   'reference': 'CmRbAAAAE4tkXPC4tUluts7FjesNZNTdoYOpOKyrHnikZHnlOobuP9zbDOTGEFTPe19fvQpoJdsjH1ThndazWsYshbu1I4es9gDtbXbqV0typvIhDu4NhLDhR3YgEbK64NUq-U00EhASHWDuDQJjT3d8wQJbpr1pGhQVqYCSmPS9pjF9hucFbrLBlB_XsA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1061 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.950467, 'lng': -77.4106},
#    'viewport': {'northeast': {'lat': 38.95194962989272,
#      'lng': -77.40943492010727},
#     'southwest': {'lat': 38.94924997010727, 'lng': -77.41213457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '4e2cdc9e112c98c5ea49811a7f3ddca14680d5b8',
#   'name': "McDonald's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115377404142808458009/photos">McDonald&#39;s</a>'],
#     'photo_reference': 'CmRaAAAAT7H0l_NfczSMXBJenIhiPy7fPbnHmeYBjwcAAcC0gqFuFwJA-4bkDKyOeW64OPLVHp_rR3eEV8jxw0pelwPmS0MReMF5LQIr5dFil6hb1ZzcgSloMkKy3g5IpTiTLv_gEhCsdJixNancmdDzMeDrbWHlGhTLMoa3CFIYE3oM-hRihXI1Jtd3pA',
#     'width': 1025}],
#   'place_id': 'ChIJ1SqJ4JZHtokRk3WClJRxEHQ',
#   'price_level': 1,
#   'rating': 3,
#   'reference': 'CmRbAAAAvXSHavQCGRIEnHaYsNWkGH7JO3_y-WzCFkt35H9H_xf9RHBozM-cJeBlCuusbUQuPl9fxlVR7OuD1e5jBoN4IRl1V5dIYBafSUVVNDpc1Cc7cIohYyVUn9xqgMhOY5JkEhCb0jgp5drOjAb7k4K_-Tz4GhSWFd5QcmNFLKtOtSj3qAxEgmra0Q',
#   'scope': 'GOOGLE',
#   'types': ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2475 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9618057, 'lng': -77.4010807},
#    'viewport': {'northeast': {'lat': 38.96311137989272,
#      'lng': -77.39962217010729},
#     'southwest': {'lat': 38.96041172010727, 'lng': -77.40232182989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2d6976da3f2801d986ce885fc8956efd6b5e0f81',
#   'name': 'Chicken Rico',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 494,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106534131682755427884/photos">Chicken Rico</a>'],
#     'photo_reference': 'CmRZAAAA5Zv-_AwsPLdIvKoZcSiOyVwO2LYSj_UMA-MyUbF_-cvdONcQ3U33ze9SW4FefHPKwsi0qOPl9nYvBgdZISHxTK1lHFLQS0470JFK-ew6ighnH0KNVxK3HmIpAt3LeOSQEhBnT_1_s3PL1mlywuBMOTi5GhTrz9OEn3kC1vS-iTjuqBxYBCLb4g',
#     'width': 750}],
#   'place_id': 'ChIJfW2CRvNHtokRgnRr8cpyLQ4',
#   'rating': 4.3,
#   'reference': 'CmRbAAAAx5vSBiGzvEt62H9jhsKfZNVNNiOSml-syRWYmysGFZzrhI0ci70RP4q9QmhRup_dgUMfhCudDMFmmT_UBc3H3sRAq7TESghPvEMJxqkdExFxyFL6OY_b33xWz8bqfgcOEhAyjkevJclPh5yyplGTuR4GGhRLEL3lcPTM5EixMCyz5nk0xmC9hg',
#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1254 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9576238, 'lng': -77.40167129999999},
#    'viewport': {'northeast': {'lat': 38.95908737989272,
#      'lng': -77.40011237010728},
#     'southwest': {'lat': 38.95638772010727, 'lng': -77.40281202989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '03eb84c3a2be1142f0255ee1c5d4df5d7c36f039',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAADoU_jeR8MG8Dh9MZr9AgFiABXDHIxEZ82eyYpgGzNG-lvMlupA0kL5CvWq1ErT8znddSVgZUStzx9Ard-QzNBXtAJVz728a7J1hbtH3o8Y3aqV1GqIX27bHfgqssZfEUEhAqXRsQViQytaprAD6qVTmCGhRshgNWGul63C82rQB7UBrbx39wYg',
#     'width': 1080}],
#   'place_id': 'ChIJP1eLx_JHtokRK7t9rA12MmU',
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'CmRbAAAA3U1wX2ov_3rTOt6yen2JL2xD0UkjDh5c1NPbRhJ1Ve7VoPVtZaSUcQalH4s6yi3tKqrv48RkGV1xGcTK-s2ibUfjfsayf59cfPbEKS_SDo4s6n5FS2uBHs7nHDxJB3INEhBKwSzrN5bORhTnEx8VyWMzGhTRxxXQ6Y2YSL92gT7hwSARztNpOA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Worldgate Centre, Worldgate Dr 13053 Unit 14, Herndon'},
#  {'geometry': {'location': {'lat': 38.9783756, 'lng': -77.43503419999999},
#    'viewport': {'northeast': {'lat': 38.97979977989272,
#      'lng': -77.43367467010727},
#     'southwest': {'lat': 38.97710012010728, 'lng': -77.43637432989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '30b4adf5dd86fdf713d5787c0db6dfa27034af59',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'place_id': 'ChIJcxXv2IQ4tokRhq9cKObpksc',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAAVFjuWJCIrjHhYewUM05Exnp88sy9cBb1za3XrZhdAZEbLIWQFJAto7vda7TN_1o6GCjGeet_e9ZnfNhNdoIoGWJL-r1NsK87VPTmIH8x7JlQkhlVkRpbZensOm4FSWzGEhBZTSfU2UL4GkIzDG37MzJNGhTsfkqmzJga6DvngOh90s0HepOKuw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23050 Pacific Blvd, Sterling'},
#  {'geometry': {'location': {'lat': 38.977509, 'lng': -77.4106335},
#    'viewport': {'northeast': {'lat': 38.97895962989272,
#      'lng': -77.40947492010729},
#     'southwest': {'lat': 38.97625997010728, 'lng': -77.41217457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a6ae6e5aaeee067aa578716bc8b4556f4999e687',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116856164624339471300/photos">karthik kaaaru</a>'],
#     'photo_reference': 'CmRaAAAAmABOQ8gxyCeYgLRdLQaI5l-IMFcgK61niOuOKVdk0hUnBg5UaZK_67BGzvlNeENDmPs6SnYn_9WVtUcAmKdyeJiwTKwUo4wYQ1nEVRe_EEYChvGb_iA48bX_ek0Ekh1JEhBa2RBtVI32WeY9CwOgp3p4GhS2CgxY-UJ8G66sq_tQilLGTKs4Xg',
#     'width': 4032}],
#   'place_id': 'ChIJH5PXe11HtokRKWDX7XJORxE',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAARAER7NHufv7IcP5ViI1quRubyHrs3ip0_mu3vsQI9EjFeffYpL6nD4rMgZBOmZtRGC4nlZ7U5NdYGdLUFia65jVoy3eMXTMpSg1neexL0Z76KzeO9znW8GLnb5I2iexsEhB2S7ot-oDTiqR29RK9l5eJGhTXEclsNScgySg1W933xUeD4l2p6A',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23070 Oakgrove Rd #155, Sterling'}]

# %%
restaurant = pd.read_csv('Restaurant_Rating.csv')
del restaurant['Unnamed: 0']
restaurant['Rating']=restaurant['Rating'].astype(float)
restaurant.replace('NAN', value=0, inplace=True)
restaurant.head()
# Out:
#                 City Name                         Facility restaurant  \
# 0  Northern Virginia Area  NED DEVINE'S IRISH SPORTS BAR & RESTAURANT
# 1  Northern Virginia Area         Anatolian Bistro Turkish Restaurant
# 2  Northern Virginia Area                       China King Restaurant
# 3  Northern Virginia Area                                  Houlihan's
# 4  Northern Virginia Area                       Elements On Level One
#
#    Latitude  Longitude  Rating                         Site Name price_level  \
# 0     38.96     -77.42     3.7  Center for Innovation Technology           2
# 1     38.96     -77.42     4.8  Center for Innovation Technology           0
# 2     38.96     -77.42     3.2  Center for Innovation Technology           2
# 3     38.96     -77.42     3.4  Center for Innovation Technology           0
# 4     38.96     -77.42     3.2  Center for Innovation Technology           0
#
#    restaurant Total Count
# 0                      20
# 1                      20
# 2                      20
# 3                      20
# 4                      20

# %%
restaurant_grouped = restaurant.groupby('City Name')
site_avg_count = restaurant_grouped['restaurant Total Count'].median()
site_avg_rating = restaurant_grouped['Rating'].median()
site_avg_count_df = pd.DataFrame(site_avg_rating)
# site_avg_rating_df =pd.DataFrame({'City Name': restaurant['City Name'],
#                                 'Median Rating':site_avg_rating})

site_avg_count_df['Restaurant Median Count']=site_avg_count
site_avg_count_df = site_avg_count_df.rename(columns={'Rating':'Median Rating'})
site_avg_count_df['Median Rating'] = site_avg_count_df['Median Rating'].astype(float)
site_avg_count_df = site_avg_count_df.reset_index()
site_avg_count_df['Restaurant Median Count'] = site_avg_count_df['Restaurant Median Count'].astype(int)
site_avg_count_df
# Out:
#                 City Name  Median Rating  Restaurant Median Count
# 0                 Atlanta           4.00                       20
# 1                  Austin           4.10                       20
# 2                  Boston           4.30                       20
# 3                 Chicago           4.20                       20
# 4             Los Angeles           4.10                       20
# 5                New York           4.10                       20
# 6  Northern Virginia Area           3.75                       20
# 7                 Raleigh           4.20                       20
# 8           Washington DC           4.00                       20

# %%
# Create legend for colors
colors = ['lightblue', 'green', 'red', 'blue', 'yellow']

# Use seaborn to make the scatter plot
ax = sns.lmplot(x='City Name', y='Median Rating', data=site_avg_count_df, fit_reg=False, aspect=2.5, 
                hue='City Name', legend=False, size=8,
                scatter_kws={"s":site_avg_count_df['Median Rating']*500,'alpha':1, 'edgecolors':'black', 'linewidths':1})

# Make the grid, set x-limit and y-limit
plt.grid()
plt.ylim(3.5,4.5)

# Set scale for all the fonts of the plot
sns.set(font_scale=1.4)

# Make x-axis, y-axis & title labels
# plt.title("SENTIMENT ANALYSIS OF MEDIA TWEETS (03/25/2018)")
# plt.xlabel("Tweets Ago")
# plt.ylabel("Tweets Polarity")

# Set the plot baclground color
sns.set_style("dark")

# Format the legend and plot
plt.legend(loc='upper right', title='City Types')
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
x=site_avg_count_df['City Name']
y=site_avg_count_df['Median Rating']
z=site_avg_count_df['Median Rating']
plt.scatter(x, y, s=z*1000, alpha=0.4, edgecolors="grey", linewidth=2, c=y, cmap="PuBuGn")
plt.grid()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:", fig_size)
 
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
plt.show()
# Out:
# Current size: [20.0, 9.0]

# %%
sns.boxplot(x='City Name', y='Rating', data=restaurant )
plt.grid()

plt.show()
