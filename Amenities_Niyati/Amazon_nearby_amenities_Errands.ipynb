# %% [markdown]
# ## Search for nearby Amenities for all site locations of each city
#     List of Amenities by Categories:
#     Categories:
#     A. Emergency Facilities
#        '''How accesible are these facilities in case of mass emergency on/around
#           sites for containing the situation and resuming business asap'''
#
#        1. Hospital
#        2. Fire Station
#        3. Doctor
#
#     B. Accomodation
#        '''Many executive employees travel from outside the city for fews days a week and might need lodging
#           facility as close to the company as possible. Also lot of local/not-local employees use vehicle
#           for commute and will need parking nearby'''
#
#        1. Lodging
#        2. Parking
#
#     C. Recreation
#         '''MNC(s) often arrange for team building activities on and near site. Also employees might look for group
#            recreational activities close  to work'''
#
#        1. Movies Theatres
#        2. Parks
#        3. Malls
#        4. Amusement park
#        5. Cafe/Restaurants
#
#     D. Basic Errands/appointments
#         '''By large employees tend to take care of daily errands and appoinments in lunch breaks or before/after
#            work hours and prefer it to be as close to work as possible for obvious reasons'''
#
#        1. Super markets
#        2. Post Office
#        3. Doctor
#
#     E. Fitness
#         '''Fitness is top on priority list for a significant amount of employees now a days may be in gym or a
#            jog/walk in park.'''
#
#        1. Gym
#        2. Parks

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import time

# Google developer API key
from config import g_key

# %%
# read places 
xls = pd.ExcelFile('BC_Project1/Project1_AmazonSites.xlsx') 
places_df=xls.parse('AmazonSites', dtype=str)
places_df = places_df[['Amazon City','Site','Site Name','Latitude','Longitude']]
places_df.head()
#len(places_df)
# Out:
#               Amazon City   Site                           Site Name Latitude  \
# 0  Northern Virginia Area  Site1    Center for Innovation Technology    38.96
# 1  Northern Virginia Area  Site2       Crystal City and Potomac Yard    38.84
# 2           Washington DC  Site1  Nationals Park/ D.C United Stadium    38.86
# 3           Washington DC  Site2                       Union Station    38.89
# 4           Washington DC  Site3              Hill-East Neighborhood    38.88
#
#   Longitude
# 0    -77.42
# 1    -77.05
# 2    -77.01
# 3       -77
# 4    -76.97

# %%
errands = {'supermarket':'supermarket', 'postoffice':'Post Office'}
all_errands_rating = []

for key in errands.keys():
    errands_rating = []
    for site in places_df.values:

        # geocoordinates
        target_coordinates = str(site[3]) + ',' + str(site[4])
        target_search = errands[key]
        target_radius = 2500
        target_type = key
        print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
        print("----------")
        # set up a parameters dictionary
        params = {
            "location": target_coordinates,
            "keyword": target_search,
            "radius": target_radius,
            "type": target_type,
            "key": g_key
        }

        # base url
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params).json()
        results = response.get('results')
        total_counts = len(results)
        print(total_counts)

        # Print the name and address of the first restaurant that appears
        for x in range(total_counts):
            if "rating" in results[x].keys():
                rating = results[x]["rating"]
            else:
                rating = 'NAN'
    
            errands_rating.append({"Site Name":site[2],
                                       key+" Total Count":total_counts,
                                       "Latitude":site[3],
                                       "Longitude":site[4],
                                       "Facility "+key:results[x]["name"],
                                       "Rating":rating})
            
            time.sleep(2)
        time.sleep(2)
    all_errands_rating.append(errands_rating)
    print("ALL Done!!!!!")
#all_eatingout_rating
# Out:
# supermarket For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 4
# supermarket For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 6
# supermarket For Washington DC: Site1, 38.86,-77.01
# ----------
# 2
# supermarket For Washington DC: Site2, 38.89,-77
# ----------
# 7
# supermarket For Washington DC: Site3, 38.88,-76.97
# ----------
# 4
# supermarket For Washington DC: Site4, 38.91,-77.02
# ----------
# 11
# supermarket For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 3
# supermarket For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 3
# supermarket For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 4
# supermarket For Boston: Site1, 42.39,-71
# ----------
# 0
# supermarket For Boston: Site2, 42.34,-71.03
# ----------
# 4
# supermarket For Boston: Site3, 42.35,-71.05
# ----------
# 7
# supermarket For Boston: Site4, 42.34,-71.06
# ----------
# 11
# supermarket For New York: Site1, 40.75,-74
# ----------
# 17
# supermarket For New York: Site2, 40.74,-73.94
# ----------
# 10
# supermarket For New York: Site3, 40.7,-73.98
# ----------
# 12
# supermarket For New York: Site4, 40.7,-74.01
# ----------
# 7
# supermarket For Chicago: Site1, 41.91,-87.64
# ----------
# 9
# supermarket For Chicago: Site2, 41.89,-87.64
# ----------
# 7
# supermarket For Chicago: Site3, 41.88,-87.65
# ----------
# 6
# supermarket For Chicago: Site4, 41.87,-87.63
# ----------
# 4
# supermarket For Chicago: Site5, 41.87,-87.62
# ----------
# 4
# supermarket For Chicago: Site6, 41.86,-87.67
# ----------
# 6
# supermarket For Chicago: Site7, 41.85,-87.66
# ----------
# 6
# supermarket For Chicago: Site8, 41.83,-87.6
# ----------
# 2
# supermarket For Raleigh: Site1, 35.9,-78.87
# ----------
# 0
# supermarket For Raleigh: Site2, 35.85,-79.08
# ----------
# 2
# supermarket For Raleigh: Site3, 35.77,-78.64
# ----------
# 4
# supermarket For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 3
# supermarket For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 2
# supermarket For Atlanta: Site3, 33.904,-84.2843
# ----------
# 4
# supermarket For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 5
# supermarket For Austin: Site1, 30.2586,-97.7444
# ----------
# 3
# supermarket For Austin: Site2, 30.2714,-97.6647
# ----------
# 0
# supermarket For Austin: Site3, 30.199,-97.8276
# ----------
# 2
# supermarket For Austin: Site4, 30.4015,-97.7268
# ----------
# 2
# supermarket For Austin: Site5, 30.4014,-97.7147
# ----------
# 4
# supermarket For Austin: Site6, 30.4704,-97.7701
# ----------
# 1
# supermarket For Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!
# postoffice For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 1
# postoffice For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 4
# postoffice For Washington DC: Site1, 38.86,-77.01
# ----------
# 5
# postoffice For Washington DC: Site2, 38.89,-77
# ----------
# 13
# postoffice For Washington DC: Site3, 38.88,-76.97
# ----------
# 6
# postoffice For Washington DC: Site4, 38.91,-77.02
# ----------
# 17
# postoffice For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 1
# postoffice For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 1
# postoffice For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 1
# postoffice For Boston: Site1, 42.39,-71
# ----------
# 3
# postoffice For Boston: Site2, 42.34,-71.03
# ----------
# 8
# postoffice For Boston: Site3, 42.35,-71.05
# ----------
# 15
# postoffice For Boston: Site4, 42.34,-71.06
# ----------
# 14
# postoffice For New York: Site1, 40.75,-74
# ----------
# 20
# postoffice For New York: Site2, 40.74,-73.94
# ----------
# 5
# postoffice For New York: Site3, 40.7,-73.98
# ----------
# 8
# postoffice For New York: Site4, 40.7,-74.01
# ----------
# 7
# postoffice For Chicago: Site1, 41.91,-87.64
# ----------
# 7
# postoffice For Chicago: Site2, 41.89,-87.64
# ----------
# 11
# postoffice For Chicago: Site3, 41.88,-87.65
# ----------
# 11
# postoffice For Chicago: Site4, 41.87,-87.63
# ----------
# 10
# postoffice For Chicago: Site5, 41.87,-87.62
# ----------
# 10
# postoffice For Chicago: Site6, 41.86,-87.67
# ----------
# 3
# postoffice For Chicago: Site7, 41.85,-87.66
# ----------
# 2
# postoffice For Chicago: Site8, 41.83,-87.6
# ----------
# 1
# postoffice For Raleigh: Site1, 35.9,-78.87
# ----------
# 1
# postoffice For Raleigh: Site2, 35.85,-79.08
# ----------
# 1
# postoffice For Raleigh: Site3, 35.77,-78.64
# ----------
# 3
# postoffice For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 11
# postoffice For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 1
# postoffice For Atlanta: Site3, 33.904,-84.2843
# ----------
# 2
# postoffice For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 2
# postoffice For Austin: Site1, 30.2586,-97.7444
# ----------
# 3
# postoffice For Austin: Site2, 30.2714,-97.6647
# ----------
# 0
# postoffice For Austin: Site3, 30.199,-97.8276
# ----------
# 1
# postoffice For Austin: Site4, 30.4015,-97.7268
# ----------
# 1
# postoffice For Austin: Site5, 30.4014,-97.7147
# ----------
# 2
# postoffice For Austin: Site6, 30.4704,-97.7701
# ----------
# 1
# postoffice For Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!

# %%
all_errands_rating
# Out:
# [[{'Facility supermarket': 'Fresh World Herndon',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.2,
#    'Site Name': 'Center for Innovation Technology',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4.4,
#    'Site Name': 'Center for Innovation Technology',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Shoppers',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 3.6,
#    'Site Name': 'Center for Innovation Technology',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Asian Halal Meat',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 4,
#    'Site Name': 'Center for Innovation Technology',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.5,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Shoppers',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.4,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Food Star',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 4.2,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.2,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Capitol Hill Supermarket',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Capitol Supermarket',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.9,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Compact Supermarket',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.3,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.4,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4,
#    'Site Name': 'Union Station',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.4,
#    'Site Name': 'Hill-East Neighborhood',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.5,
#    'Site Name': 'Hill-East Neighborhood',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4,
#    'Site Name': 'Hill-East Neighborhood',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 4.2,
#    'Site Name': 'Hill-East Neighborhood',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Capitol Hill Supermarket',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Capitol Supermarket',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.9,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Metro Supermarket',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'BestWorld Supermarket',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Metro K Supermarket',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Save-A-Lot',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.9,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 4.1,
#    'Site Name': 'Shaw-Howard University Area',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Vallarta Supermarkets',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.6,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 4.8,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Valley Marketplace Valencia',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.4,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 4.6,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Superior Grocers',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4,
#    'Site Name': 'Pomona Fairplex',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.5,
#    'Site Name': 'Pomona Fairplex',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Stater Bros. Markets',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.1,
#    'Site Name': 'Pomona Fairplex',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Stater Bros. Markets',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.4,
#    'Site Name': 'Pomona Fairplex',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'C-Mart Supermarket',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4,
#    'Site Name': 'South Boston Waterfront',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Roche Bros. Downtown Crossing',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.3,
#    'Site Name': 'South Boston Waterfront',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Euromart',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.7,
#    'Site Name': 'South Boston Waterfront',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.5,
#    'Site Name': 'South Boston Waterfront',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': "Ming's Supermarket",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.2,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'C-Mart Supermarket',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'C-Mart Supermarket',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.8,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Roche Bros. Downtown Crossing',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.3,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.5,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Jacqueline Grocery Store',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.3,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Tropical Foods',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.2,
#    'Site Name': 'Downtown',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': "Ming's Supermarket",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.2,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Brothers Supermarket',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.1,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'C-Mart Supermarket',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'C-Mart Supermarket',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3.8,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Roche Bros. Downtown Crossing',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.3,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.5,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.3,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.4,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Save-A-Lot',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.1,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Tropical Foods',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.2,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': "Foodie's Markets",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.1,
#    'Site Name': 'South End',
#    'supermarket Total Count': 11},
#   {'Facility supermarket': 'Morton Williams',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.8,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams Supermarkets',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.7,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams Supermarkets',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.6,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Western Beef',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': "D'Agostino",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.2,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': "D'agostino",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.1,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': "D'Agostino",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.5,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': "D'Agostino",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.4,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.3,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.4,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Kings Food Markets',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.8,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Kings Food Markets',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.7,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.2,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.1,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.6,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams Supermarkets',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Western Beef Supermarket',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 2.8,
#    'Site Name': 'Hudson Yards',
#    'supermarket Total Count': 17},
#   {'Facility supermarket': 'Morton Williams Supermarkets',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.9,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Morton Williams Supermarkets',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.9,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Food Bazaar Supermarket',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.4,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Trade Fair Supermarket',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.7,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Llamamu Grocery Corporation',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.5,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Associated Supermarket',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.6,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Associated Supermarket',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.6,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.2,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Bravo Supermarkets',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.5,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Trade Fair Supermarket',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3.7,
#    'Site Name': 'Long Island City',
#    'supermarket Total Count': 10},
#   {'Facility supermarket': 'Fine Fare Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Lee Gardens Supermarket Inc',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.8,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Chinatown Supermarket of Manhattan',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Hatzlacha Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Associated Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.8,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Chinese & Spanish Grocery',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Shop Fair Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.9,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Key Food Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Red Apple Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 2.5,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Tapps Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.7,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Associated Supermarkets',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.4,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'supermarket Total Count': 12},
#   {'Facility supermarket': 'Fine Fare Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.5,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Chinatown Supermarket of Manhattan',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.1,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Chinese & Spanish Grocery',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 5,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Key Food Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.1,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.4,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Red Apple Supermarket',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 2.5,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Associated Supermarkets',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.1,
#    'Site Name': 'Financial District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.5,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Treasure Island Foods',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.8,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Treasure Island Foods',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.7,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.6,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Potash Markets - State St',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.2,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Walmart Neighborhood Market',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.1,
#    'Site Name': 'Lincoln Yards',
#    'supermarket Total Count': 9},
#   {'Facility supermarket': 'Treasure Island Foods',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.8,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Treasure Island Foods',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.7,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.6,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.6,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Potash Markets - State St',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'The River District',
#    'supermarket Total Count': 7},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.6,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.6,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Potash Markets - State St',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.3,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.3,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Treasure Island Foods',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.8,
#    'Site Name': 'Futton Market',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 4.6,
#    'Site Name': 'City Center Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 4.4,
#    'Site Name': 'City Center Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 4.3,
#    'Site Name': 'City Center Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 4.6,
#    'Site Name': 'City Center Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 4.6,
#    'Site Name': 'The Downtown District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 4.4,
#    'Site Name': 'The Downtown District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 4.3,
#    'Site Name': 'The Downtown District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 4.6,
#    'Site Name': 'The Downtown District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.4,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': "Pete's Fresh Market #06 - Cermak & Rockwell",
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.4,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': "Pete's Fresh Market #10 - Madison & Western",
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.4,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Cermak Fresh Market',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.3,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Super Mercados El Guero',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.8,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.3,
#    'Site Name': 'The Illinois Medical District',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.4,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': "Pete's Fresh Market #06 - Cermak & Rockwell",
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.4,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Cermak Fresh Market',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.3,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Super Mercados El Guero',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.8,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Cermak Fresh Market',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.3,
#    'Site Name': 'The 78',
#    'supermarket Total Count': 6},
#   {'Facility supermarket': 'King Supermarket',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 3.7,
#    'Site Name': 'Burnham Lakefront',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Save-A-Lot',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 3.7,
#    'Site Name': 'Burnham Lakefront',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Lowes Foods of Chapel Hill',
#    'Latitude': '35.85',
#    'Longitude': '-79.08',
#    'Rating': 4.2,
#    'Site Name': 'Chatham Park',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '35.85',
#    'Longitude': '-79.08',
#    'Rating': 4.5,
#    'Site Name': 'Chatham Park',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Harris Teeter',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 4.2,
#    'Site Name': 'Warehouse District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'The Fresh Market',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 3.9,
#    'Site Name': 'Warehouse District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Save-A-Lot',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 3.8,
#    'Site Name': 'Warehouse District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Unlimited Produce Inc.',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 5,
#    'Site Name': 'Warehouse District',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Publix Super Market at The Plaza Midtown',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.2,
#    'Site Name': 'Downtown Atlanta',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Publix Super Market at Piedmont',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.2,
#    'Site Name': 'Downtown Atlanta',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.3,
#    'Site Name': 'Downtown Atlanta',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Walmart Neighborhood Market',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 4.3,
#    'Site Name': 'Midtown',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Cash Saver Food Outlet',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 4.1,
#    'Site Name': 'Midtown',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Supermarket Chicago',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.3,
#    'Site Name': 'Former GM plant',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Asian Supermarket',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.1,
#    'Site Name': 'Former GM plant',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Brito Supermarket',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.5,
#    'Site Name': 'Former GM plant',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Dinho Market of Atlanta',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 3.6,
#    'Site Name': 'Former GM plant',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'ALDI',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.3,
#    'Site Name': 'The High Street Site',
#    'supermarket Total Count': 5},
#   {'Facility supermarket': 'Publix Super Market at The Prado',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.7,
#    'Site Name': 'The High Street Site',
#    'supermarket Total Count': 5},
#   {'Facility supermarket': 'Publix Super Market at Abernathy Square Shopping Center',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.1,
#    'Site Name': 'The High Street Site',
#    'supermarket Total Count': 5},
#   {'Facility supermarket': 'Shahrzad',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 3.8,
#    'Site Name': 'The High Street Site',
#    'supermarket Total Count': 5},
#   {'Facility supermarket': 'Carniceria Los Pinos',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.3,
#    'Site Name': 'The High Street Site',
#    'supermarket Total Count': 5},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.6,
#    'Site Name': 'American-Statesman ',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': "Trader Joe's",
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.6,
#    'Site Name': 'American-Statesman ',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'One World Foods',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 'NAN',
#    'Site Name': 'American-Statesman ',
#    'supermarket Total Count': 3},
#   {'Facility supermarket': 'Gandhi Bazar',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.3,
#    'Site Name': 'Former 3M site',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 4.4,
#    'Site Name': 'Former 3M site',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.2,
#    'Site Name': 'The Domain',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.5,
#    'Site Name': 'The Domain',
#    'supermarket Total Count': 2},
#   {'Facility supermarket': 'Gandhi Bazar',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 3.8,
#    'Site Name': 'Bardmoor Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.2,
#    'Site Name': 'Bardmoor Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Hana World Market',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.1,
#    'Site Name': 'Bardmoor Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Whole Foods Market',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.5,
#    'Site Name': 'Bardmoor Campus',
#    'supermarket Total Count': 4},
#   {'Facility supermarket': 'Quick Corner',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 5,
#    'Site Name': 'Robinson Ranch',
#    'supermarket Total Count': 1}],
#  [{'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 1.4,
#    'Site Name': 'Center for Innovation Technology',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 2.3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'postoffice Total Count': 4},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'postoffice Total Count': 4},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 2.9,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'postoffice Total Count': 4},
#   {'Facility postoffice': 'US Post Office (underground)',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 3,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'postoffice Total Count': 4},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 'NAN',
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'postoffice Total Count': 5},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'postoffice Total Count': 5},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 1.6,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'postoffice Total Count': 5},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 'NAN',
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'postoffice Total Count': 5},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.7,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'postoffice Total Count': 5},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.8,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 5,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.8,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 'NAN',
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.5,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.8,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.5,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.7,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.1,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'Student Post Office',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.2,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.6,
#    'Site Name': 'Union Station',
#    'postoffice Total Count': 13},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 'NAN',
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 1.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 2.8,
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 1.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 2.8,
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 5,
#    'Site Name': 'Hill-East Neighborhood',
#    'postoffice Total Count': 6},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.8,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 1.4,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.5,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 5,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.8,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'Student Post Office',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'postoffice Total Count': 17},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 2.1,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 1.7,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 2,
#    'Site Name': 'Pomona Fairplex',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 1.6,
#    'Site Name': 'Suffolk Downs',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4,
#    'Site Name': 'Suffolk Downs',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 2.5,
#    'Site Name': 'Suffolk Downs',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 2.9,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 4.5,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.5,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 1.8,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 2.3,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'US Government Post Office Garage',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 'NAN',
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 3.8,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'John W. McCormack Post Office and Court House',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'postoffice Total Count': 8},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'postoffice Total Count': 15},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3.6,
# ...
#    'Site Name': 'Lincoln Yards',
#    'postoffice Total Count': 7},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 2.6,
#    'Site Name': 'Lincoln Yards',
#    'postoffice Total Count': 7},
#   {'Facility postoffice': 'USPS Lincoln Park Annex',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 1.2,
#    'Site Name': 'Lincoln Yards',
#    'postoffice Total Count': 7},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 2.1,
#    'Site Name': 'Lincoln Yards',
#    'postoffice Total Count': 7},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 1.9,
#    'Site Name': 'Lincoln Yards',
#    'postoffice Total Count': 7},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1.3,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1.5,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1.9,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.6,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.5,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.2,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.3,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1.4,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.1,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2.1,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1.8,
#    'Site Name': 'The River District',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.3,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.9,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2.5,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.5,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2.2,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2.3,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'Pilsen Station Chicago Post Office',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.8,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.4,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2.1,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2.1,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1.8,
#    'Site Name': 'Futton Market',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1.5,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1.9,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.5,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.2,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.3,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1.4,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.1,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.1,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1.8,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1.3,
#    'Site Name': 'City Center Campus',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1.5,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1.9,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.5,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.2,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.3,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1.4,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.1,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.1,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1.8,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1.3,
#    'Site Name': 'The Downtown District',
#    'postoffice Total Count': 10},
#   {'Facility postoffice': 'Pilsen Station Chicago Post Office',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 1.8,
#    'Site Name': 'The Illinois Medical District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 2.5,
#    'Site Name': 'The Illinois Medical District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 1.5,
#    'Site Name': 'The Illinois Medical District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'Pilsen Station Chicago Post Office',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 1.8,
#    'Site Name': 'The 78',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 2.5,
#    'Site Name': 'The 78',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 1.4,
#    'Site Name': 'Burnham Lakefront',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 1.8,
#    'Site Name': 'Research Triangle Park',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '35.85',
#    'Longitude': '-79.08',
#    'Rating': 2.8,
#    'Site Name': 'Chatham Park',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 3.7,
#    'Site Name': 'Warehouse District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 1.9,
#    'Site Name': 'Warehouse District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 2.8,
#    'Site Name': 'Warehouse District',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1.9,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1.8,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2.4,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 3,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2.8,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2.2,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1.5,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1.2,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1.8,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.1,
#    'Site Name': 'Downtown Atlanta',
#    'postoffice Total Count': 11},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 5,
#    'Site Name': 'Midtown',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 2.4,
#    'Site Name': 'Former GM plant',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 1.4,
#    'Site Name': 'Former GM plant',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 1.9,
#    'Site Name': 'The High Street Site',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 1.8,
#    'Site Name': 'The High Street Site',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 2.6,
#    'Site Name': 'American-Statesman ',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 2.9,
#    'Site Name': 'American-Statesman ',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 2.7,
#    'Site Name': 'American-Statesman ',
#    'postoffice Total Count': 3},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 1.6,
#    'Site Name': 'Former 3M site',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 1.8,
#    'Site Name': 'The Domain',
#    'postoffice Total Count': 1},
#   {'Facility postoffice': 'US Post Office',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 2.7,
#    'Site Name': 'Bardmoor Campus',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 1.8,
#    'Site Name': 'Bardmoor Campus',
#    'postoffice Total Count': 2},
#   {'Facility postoffice': 'United States Postal Service',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 1.8,
#    'Site Name': 'Robinson Ranch',
#    'postoffice Total Count': 1}]]

# %%
all_supermarket_rating_df = pd.DataFrame(all_errands_rating[0])
all_supermarket_rating_df.head()
# Out:
#   Facility supermarket Latitude Longitude Rating  \
# 0  Fresh World Herndon    38.96    -77.42    4.2
# 1        Harris Teeter    38.96    -77.42    4.4
# 2             Shoppers    38.96    -77.42    3.6
# 3     Asian Halal Meat    38.96    -77.42      4
# 4                 ALDI    38.84    -77.05    4.5
#
#                           Site Name  supermarket Total Count
# 0  Center for Innovation Technology                        4
# 1  Center for Innovation Technology                        4
# 2  Center for Innovation Technology                        4
# 3  Center for Innovation Technology                        4
# 4     Crystal City and Potomac Yard                        6

# %%
all_postoffice_rating_df = pd.DataFrame(all_errands_rating[1])
all_postoffice_rating_df.head()
# Out:
#             Facility postoffice Latitude Longitude Rating  \
# 0  United States Postal Service    38.96    -77.42    1.4
# 1  United States Postal Service    38.84    -77.05    2.3
# 2                US Post Office    38.84    -77.05      3
# 3  United States Postal Service    38.84    -77.05    2.9
# 4  US Post Office (underground)    38.84    -77.05      3
#
#                           Site Name  postoffice Total Count
# 0  Center for Innovation Technology                       1
# 1     Crystal City and Potomac Yard                       4
# 2     Crystal City and Potomac Yard                       4
# 3     Crystal City and Potomac Yard                       4
# 4     Crystal City and Potomac Yard                       4

# %%
all_supermarket_rating_df.to_csv("SuperMarket_Rating.csv")

# %%
all_postoffice_rating_df.to_csv("PostOffice_Rating.csv")

# %%
# geocoordinates
target_coordinates = '38.96,-77.42'
target_search = 'restaurant'
target_radius = 2500
target_type = 'Restaurant'
#print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
print("----------")
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()
results = response.get('results')
# Out:
# ----------

# %%
results
# Out:
# [{'geometry': {'location': {'lat': 38.9516461, 'lng': -77.40930279999999},
#    'viewport': {'northeast': {'lat': 38.95289547989272,
#      'lng': -77.40782302010727},
#     'southwest': {'lat': 38.95019582010728, 'lng': -77.41052267989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'f5474a007bbf8aeda8ff931155aa674038635790',
#   'name': "Stone's Cove Kitbar",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1229,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104624375199943783692/photos">Stone&#39;s Cove Kitbar .</a>'],
#     'photo_reference': 'CmRaAAAASGaAGJlR1NVJ0K81ZxhaLRty1CQsVIozXhxQRNkbINZgaZWOXIDz30aYel0StuD5J3N2IO57VwuHFWMO6igfZWADo4AdCm3_G2B1vyT7XrtEY4_IfykSJBz5IepkvZ8yEhBSuUUUx-bfMqC1A2MjmXxsGhTsS4Kp2gJMk3Mj-ijkmuN-gjTwcQ',
#     'width': 2048}],
#   'place_id': 'ChIJ12VH3ZZHtokR-8N2xTFZAFI',
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'CmRbAAAA48Sw_plTWYXjYqcE0js1rgCVefdryONIDkY_9TZdwu9TnfKffiv2Gt1WMuOyZYRShVFWADMMA_HmWjS2GYYKl6yH_HNHmCfTn5dMJxctdoJsUYF7ipo-4bFCKg9SKrmrEhC2x91Fh8rUFymuA9ghPcC6GhTE65FDTIftUz1Z5BIAkV2-6VPH_g',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2403 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9616858, 'lng': -77.3985107},
#    'viewport': {'northeast': {'lat': 38.96316622989272,
#      'lng': -77.39691487010728},
#     'southwest': {'lat': 38.96046657010727, 'lng': -77.39961452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'cd7eb190d01776de1bf17e500b53a982c0105dea',
#   'name': 'Grill Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104090059274588000035/photos">Royal Sedan</a>'],
#     'photo_reference': 'CmRaAAAAJQ08fwfEAk0gZlzOkVZhwFDw45pMtxs4_8ocCgRjpNe9v6xAOdqPWvBYvuINMNUDj1QpiDUKzEmLb7i5Imb2g9G_QBpNdnUs0t9wDjCNj3Obddn3XkPOt8J_JlTHDGMHEhDCk9aHkRAbGsOQAvJX0JnUGhSoWF6T1bKCIPlMLF4Zn_rXVYkK3w',
#     'width': 4128}],
#   'place_id': 'ChIJu-16iPNHtokR97zBSb2gGBQ',
#   'rating': 4,
#   'reference': 'CmRbAAAA0Yb6jMlMMNmfmdXGYhcS59l-bRsVrDtKMWs8Sxl7FQyeEsjloDWwMeR5rYYwi4vonrS0NYxb7UMc73AZA3ftm0NzbMEZOgB_5vNJaw1PiL3ro8uVpf7T-b4Y4Wg_wsq0EhD5HeBk4dkjxrYJ4kTA3PsJGhT6CrecEOJ6sM3OoeQWTv3kFdhufw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '905 Herndon Pkwy # F, Herndon'},
#  {'geometry': {'location': {'lat': 38.9637234, 'lng': -77.3971565},
#    'viewport': {'northeast': {'lat': 38.96528557989272,
#      'lng': -77.39628927010727},
#     'southwest': {'lat': 38.96258592010727, 'lng': -77.39898892989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'ef2a33d1ad4e9511c03341de5e6a1ac60bf1abe1',
#   'name': 'Amphora Diner Deluxe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104016859568650225547/photos">A Google User</a>'],
#     'photo_reference': 'CmRaAAAAlS_AgujsFSub8i7HNVQjBAgEfh9aEaNlrPhrRoAfRQ-KXJhrKlgVba-2nwYQCjTFUyuFhTk4RRw4aOrQQmoOlagbqE9dKYCL_V11YMvlwJIAPzKJGE_cs-xnXkUCwCOjEhBZL1Jt82TbBgk8b8o0DDqXGhRySlcgxdOAwucdEc5bCkOgWXysKQ',
#     'width': 2048}],
#   'place_id': 'ChIJWVcERfRHtokRW9oscZS9Hyc',
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'CmRbAAAAxKo3XdtCD3_CPQGk_9b8JRcVfc7If23tnm7Ld0v-P850m_Dv2_zSj3rb3n20wVnGX2n5WheCfqRAK_CeYMdunYMjXz8jB5NzanYCu0r3-zbNyUkgV4lyYoXDpVSEgmaVEhBQuKEengwoVQbKkAw-yyK9GhSYTFFKoJKm-lf2mflXIXFBjM2jng',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1151 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9799278, 'lng': -77.43275589999999},
#    'viewport': {'northeast': {'lat': 38.9821982, 'lng': -77.43184287010727},
#     'southwest': {'lat': 38.97917099999999, 'lng': -77.43454252989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8291f6b3bba3e38c4a922b77a06d34d0c6b7bf76',
#   'name': 'Cracker Barrel Old Country Store',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115128327407342395621/photos">Darrell Brock</a>'],
#     'photo_reference': 'CmRaAAAA6DWSWKxMtS20uxDCI1oQOHCVptR576IX6giPoH66C0HVVjrExe5cEP9LB02p9Fx0r65liX1icr5dsljTrAGTzZOZY3bprOilgFST1L81_OwC1nSn20nEXKGdDz6c39oyEhDEQa_mQNoUYqXUTrzqJykwGhQIHT7c0pQxw0lgWb4P5ILGJhIDDw',
#     'width': 3984}],
#   'place_id': 'ChIJ3SY8YY84tokRQuEPIq1BlSc',
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'CmRbAAAAcQaeS5qKBlG4XJvLT1NhfhTMJbQXSdNWJXOOkBEKyaiiIfDK9ljRCGkANCRLXZkXh1MRnA-f-f5VmdoP3mTaCJqNtLOpH37t1Rt7reZmfVrGEWhz0h7mN4SbYFV4WWlfEhCBZjX_S6328qlH8c6JZ0vGGhSLXCJKfNWLDoworgxxsIhss047QQ',
#   'scope': 'GOOGLE',
#   'types': ['store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '23030 Indian Creek Dr, Sterling'},
#  {'geometry': {'location': {'lat': 38.9586216, 'lng': -77.403313},
#    'viewport': {'northeast': {'lat': 38.95984262989271,
#      'lng': -77.40174572010727},
#     'southwest': {'lat': 38.95714297010727, 'lng': -77.40444537989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2df21a3eef33456e061a049e742db552a6a7aa22',
#   'name': "Houlihan's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117979874678644930975/photos">Jose Gonzalez</a>'],
#     'photo_reference': 'CmRaAAAAjIWMFEdNVRDv0GiDgcW5CoVgkWSRODiPHKUWhFBsbR16OZWGnXZpdIWKmHapCBLRoewn4dzaf9L4WgXmpAnNQG02loIOLCHO1sZZGLe40Ekb6vRRKx2SMjXAhGBVYsHqEhAC2gdPYHB_kMrlatM7lFv7GhSlPUZgdiWH2PpMs6O7GYWF5Hj67g',
#     'width': 3840}],
#   'place_id': 'ChIJR9j6co1HtokRMan0ua8RMAI',
#   'rating': 3.4,
#   'reference': 'CmRbAAAATZVzON7aSPeDNWy4vu8F9dsXNOfeTfoipHMMNxFcZ87ulrVHOu28JcCKpFutINECcE_l-UOJX2_hyMcej7ycM5NrSlZH8oDAvbiOk83-R10fdeMG0MU0NccP4RK3AAN6EhBC8nbmfr9_ZQzujbiqQ559GhT7C0lvKZE0GcMVo2m9uOGOIScmsA',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2200 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9609335, 'lng': -77.4232561},
#    'viewport': {'northeast': {'lat': 38.96228332989271,
#      'lng': -77.42190627010729},
#     'southwest': {'lat': 38.95958367010726, 'lng': -77.42460592989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8763954c34046f3742a948fbef22f84466a142a8',
#   'name': 'Elements On Level One',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115497934970694920599/photos">Travis Baumgart</a>'],
#     'photo_reference': 'CmRaAAAAZvZg62pc05ZPtvgwDboxhVuaFGB5kaMyPRJvgU9ikIm0oKU9XpLymCsg2dAwVPmrgklEKjrxAWU0C9O9mX_x1NRGtM9uQjGgbI6samUCZbVmBqbyFJlbz0r8n2wmzK61EhAzAfGf3vJS1HEwaPo99WrVGhTvCESAsfTh3EW-mGSWwQrBH-t7_g',
#     'width': 1836}],
#   'place_id': 'ChIJQUumvYJHtokRqccDrDqJrWw',
#   'rating': 3.2,
#   'reference': 'CmRbAAAASzY9QoL34OsE0-bMwKkwqvSGESOFXAUbdSS_wCDyx32sGT4DqIovcdFSQAVlsP-6d7m9MVo1_ne3mwaJz-zQ7T5LWV7wr8uC-aaq_JMtdI2tSFkifwnqUJCSAtxmFN2AEhCqnng9dRN4UIn4_Sx-CHSxGhSinNGlBgVeE2NKLZ4dfYtxjoJemw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2300 Dulles Corner Blvd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9485969, 'lng': -77.4484299},
#    'viewport': {'northeast': {'lat': 38.94994672989272,
#      'lng': -77.44708007010728},
#     'southwest': {'lat': 38.94724707010727, 'lng': -77.44977972989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '06a163a0056f7b4dbcc5b81ccb963cbb41094368',
#   'name': "Carrabba's Italian Grill",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105320630398470954348/photos">Jose March-Leuba</a>'],
#     'photo_reference': 'CmRaAAAAM59oXNqRDOa6-VT5zfGa8i3SFIHwv927-FsnA7VLEfOoCON-fN5AxarrKpZDfAEysQ3b8Umnk6Mbtqm5N3aXskSvjoRpf0s9qeTMUxRbZfzxEi-LrCY07kYqsFWkdEBgEhAVcuTtwEixFwrIOXm8YmgOGhRyfjPeVvsTuYwWsRzgirfPnq3enA',
#     'width': 4160}],
#   'place_id': 'ChIJk-7gGkBHtokR3NGlod2wO_0',
#   'rating': 2.2,
#   'reference': 'CmRbAAAA2rNSviQO5mj3rsATRR_hBJg-EDPX4Y-gx09gLY3XbgbNyNYO5P5Cb8EK06znn-aBCbjllBx0uCyP6MoqTzht5nFY4HuVICPG6cURuZqwWiWwxTXFPaKmjB0n4b7GMFlUEhCZB3vGSvhcDS-9Pb4nDHAPGhQMyWiy8A8vSrVIHFv-1JPaGPFGOg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Washington Dulles International Airport, Concourse B, Gate B41, 1 Saarinen Cir, Dulles'},
#  {'geometry': {'location': {'lat': 38.9454736, 'lng': -77.4448961},
#    'viewport': {'northeast': {'lat': 38.94682342989272,
#      'lng': -77.44354627010728},
#     'southwest': {'lat': 38.94412377010728, 'lng': -77.44624592989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '457d0af235f15c4cd9c9371ebb022d92156b71d5',
#   'name': 'Au Bon Pain',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114229034596052359026/photos">Nouni USALG</a>'],
#     'photo_reference': 'CmRaAAAALTyzfY_upe1gx1ezgt06MjLjZxwVkXtsBss_8a8BXWn3DOtrQXTSnE7Zhbhoc0LxMwFPzchfbDJEWvkqwWY1on7CaDy02ryid5ITHFN4L4ej4hN-BYRTeYizDR-afrMmEhCBLtXkdBdWtv_qjuiGMD9sGhTkqw6uU2pvHOdVls7jWlAY8MIKNg',
#     'width': 4032}],
#   'place_id': 'ChIJebpXGkBHtokRgVuywowH18E',
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'CmRbAAAAnpBveKu86sW60irCMAdY-rE380VAdL6NR6kQN-Mj9QVDTqEItI1vSwqI52vsIMSv85azEvcOETJg2-6OTQiKn32zYA8XCuznWPscZgfcyUvaOvyo_jAoWN2-ah93Z8FqEhCPrR7katY0jrVuM8xZuGUGGhTBT2bh9nYByJ4jV3R8iWz1tqnp4g',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1 Saarinen Circle, Sterling'},
#  {'geometry': {'location': {'lat': 38.9643913, 'lng': -77.396605},
#    'viewport': {'northeast': {'lat': 38.96574112989272,
#      'lng': -77.39525517010728},
#     'southwest': {'lat': 38.96304147010727, 'lng': -77.39795482989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '47d42fe430bd7cf2e33080fde7c228a438fee688',
#   'name': "Paisano's Pizza",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2046,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111461259370706113420/photos">Paisano&#39;s Pizza</a>'],
#     'photo_reference': 'CmRaAAAA7MaB3lFJoPJzSfZUTP-0rYm6se5e04Z_-lNjOJLGbjUPntVV6PzoWUhtQLrsVvMYiHbTzdc54miKkbInh2dlCCApeZH4x-y86dW_dROyvMaH2aj4_2MraUEYyF7LqvnvEhA-Uc7BsrUOcOvyfDh0NKCWGhSrzKlQM1YwSzETCpw2lhfdIjOVgA',
#     'width': 2048}],
#   'place_id': 'ChIJn9qyTPRHtokRfNzSHf6kY7A',
#   'price_level': 2,
#   'rating': 3.5,
#   'reference': 'CmRbAAAA0ntoEP6FzwZrUraI3QocsCvJ-TzF1RLoWJcVjT7P3tRKH-rc3V46gsDeFgvZ3fxo3UNTwpvgHYGs6S7wGwVTXUdT5HEz2EwZBcZS9-1s-6Xw7G8DT2nmCVfZ4eXlf5J8EhCnsFUfBIrg1-4EiTVVH3JyGhRg5BSKLnKuX6XcCk3TN_pLfUdhvA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1141 Elden St #105, Herndon'},
#  {'geometry': {'location': {'lat': 38.9636296, 'lng': -77.3990669},
#    'viewport': {'northeast': {'lat': 38.96489667989272,
#      'lng': -77.39753292010728},
#     'southwest': {'lat': 38.96219702010728, 'lng': -77.40023257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'fa1dff8ffdb7c12f80f1a704198e9497ca474039',
#   'name': 'Chipotle Mexican Grill',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106158804692297980523/photos">Prem Nambi</a>'],
#     'photo_reference': 'CmRaAAAANfEv9g_p4PkJpWIW6NjKBqmc4OOLUw_EceNNkrVgxJHD8y1KhybFE0v7hmw9y-h08TXzvaht_TKKT089py_285rd2q-aCn9IXcJTqHcY6KAniUDC9eDKVFRANZjyJYUIEhCiErc-YgPFuQQBDssKgCzOGhTDfqeJ89pLsieuMFQ1-cmPDNGxfA',
#     'width': 1920}],
#   'place_id': 'ChIJJbJlVPRHtokR393UAAk2O0E',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAOkrPB0Ag39E5PyVTyOGG-xclQOuSDbBXkvKtlBCgHF_tdJTUg3blpk4kdtgT0tgEiD6E-m26lPE6TDGEyxyPbYcVuAe9E2MfP71x2DPX8mcEE7tsWVsamFyORy0QYFnlEhDsllzxJoWNixrHS9pQKMrvGhQTbbsD1gYIa3_XorN0JHgiK4KvYQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1144 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9491305, 'lng': -77.3957818},
#    'viewport': {'northeast': {'lat': 38.95046712989272,
#      'lng': -77.39437207010728},
#     'southwest': {'lat': 38.94776747010728, 'lng': -77.39707172989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'd7412cc8ad2598c8366009e2124d8f7d50338a19',
#   'name': 'Pei Wei',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103921559028635582224/photos">Laura I</a>'],
#     'photo_reference': 'CmRaAAAABrBRp3AIiXCTPjgMaiWvySvGYavYmqZVd2QwusqW3rjiuq4CsvkPIjDfgbxJ_Vf-9sOA_la5fXTiIY2txnI7tt0tU29o8uHNn17EZe0jlibtsaSGcKK0nu0J0TUHgYHREhASH5QQx7395hVQmMApQjUSGhQlrKZo31CXSWnEo4aURQyRVLRArg',
#     'width': 4048}],
#   'place_id': 'ChIJuxX0YulHtokROTeCrnmDx6k',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAARfIUD65GQ6YvWsJemvaUajQPNYPUrrzyQVqTq-Ded4ZY0eweVXPg4CtPF61CHyyzCQR-a9MYPlumUpK_jFB_yOs5Sd-GYboVCHDheFs3EMOS0UFLurdTaHxST8DroD9FEhCEVns-D4AeKkQdIctG8hWcGhTMNN4OEgSv_mSkovBKOvaeoyYIKA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2338 Woodland Crossing Dr Suite A, Herndon'},
#  {'geometry': {'location': {'lat': 38.9495279, 'lng': -77.39601019999999},
#    'viewport': {'northeast': {'lat': 38.95093377989272,
#      'lng': -77.39460157010727},
#     'southwest': {'lat': 38.94823412010727, 'lng': -77.39730122989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '45ada78434650665d6b95094e440377a0376dd38',
#   'name': 'Moby Dick House of Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3192,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115484345829336444608/photos">Jay Stearns</a>'],
#     'photo_reference': 'CmRaAAAA1EYQiG7yB7roxAcB3-LbPBQMNLYkPfn6Yzx94NNyiGTMCLb7d2IpXjVF-8Ta0oQlg0lpUzrsrrk7FOOU1wBPreEeXfQsH1q9RxBnXQLHwHpBCB5H7XuCSpPq0mY1rNkKEhCfu9do4duVEgkfSYAv2ywzGhRDgruvLghh4kYyHF-yRGEm8e_Blg',
#     'width': 4788}],
#   'place_id': 'ChIJywL52OtHtokRisWGJ7-RIaA',
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'CmRbAAAAcdjypZlLSsnQNLcstz0_fEXLuIv0olltwD91X7k4YpSVECJdCAEvPjG9MZ3L69ay4zf3994VP8Wr802aeaKZfJ1Llz-0omBhQy1ogZo7FrfedsyJ9FAoTNfjSqeT8GaqEhAYQvgMjDrpoTy5XZPbwteDGhSRc6jg5AjTeRKOnTOqQskZDQkJIw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '12975-A Highland Crossing Dr, Herndon'},
#  {'geometry': {'location': {'lat': 38.950228, 'lng': -77.409966},
#    'viewport': {'northeast': {'lat': 38.95173202989272,
#      'lng': -77.40874487010727},
#     'southwest': {'lat': 38.94903237010728, 'lng': -77.41144452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'e3e52fde9110807a4e1160e820da5e22ebaae51b',
#   'name': "Chuck E. Cheese's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114812587622428408666/photos">Rajiv Desai</a>'],
#     'photo_reference': 'CmRaAAAAYkfHIQ4rWMATFJFqMlq5BoL8b_W7bjWDG35GLSgqhkSoB9uEDfWiwpoD5EdUgRRoWdkKbnvxLGU6IIQsD9Nv8zeVZh4h2CuJgPcwDAK00uDmkAHN-L_NM5CDRc_2B_UyEhAoj9zr36E3AKkgjGKuYLKtGhT-0kKg0YWdI2gPY4SsCSBrIZDPMg',
#     'width': 1920}],
#   'place_id': 'ChIJ--fmB5dHtokRGXWPheoQWFk',
#   'price_level': 2,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAW16PTCBjJwW8yAf2rFrae6jjuKiPdenbM6ZbGicvwhA1U19YSTxmuwV_ufNsTI_CpgjwlrNwMrNYh5sQcyhrk_JQgwbuoDk63nqwBkCgU6ODIsKSbEgloE6F3z4ndt9yEhBK5Igf7MO5XhqS2pNy7SybGhSnYtJ4MxWUAO2KpV87VpJ3BjzaPw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2465 Centreville, Ste. J9, Herndon'},
#  {'geometry': {'location': {'lat': 38.9503091, 'lng': -77.4101694},
#    'viewport': {'northeast': {'lat': 38.95171102989272,
#      'lng': -77.40890717010728},
#     'southwest': {'lat': 38.94901137010728, 'lng': -77.41160682989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a306deb8f4f1680369ffa0d24715cba80b5cf6fd',
#   'name': 'Tropical Smoothie Cafe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 440,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105974514124910190354/photos">A Google User</a>'],
#     'photo_reference': 'CmRZAAAA0hEVeqMt3TUfVPRRYcm1LNQQO6NJcSc4khGEDtEML2PnO7TQiaBQZ9irxnyTfuZwWrAcroCvDh1NFFCGj4rQTh5sRUFdvmBtKFVVEhrN-qzcZD9eYjZy9HfpWvp8V6RMEhDny4bhI4c6dnicYoxVwF_pGhT4kNAKYs-zCJyW3wQer1PslgtWMg',
#     'width': 550}],
#   'place_id': 'ChIJ--fmB5dHtokRMr8-G7snM38',
#   'rating': 3.8,
#   'reference': 'CmRbAAAARnEq4v-2HN_nl70HuA2YGI5SndWJCdShzJ3HIO_wFT33Akprnk2YAc0R38gN3G7uXD26g3xLgf8KdXZFxPRSnaavOMTr80LMt6RMT3r3uX6X5iR4J1xNbMTX9PkqeTmTEhBvVXbUKhMmZsgO4wmuc0GxGhTZBDYFYO0OeUKu0vkZUg1aKl7uxg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant',
#    'cafe',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2465 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9662767, 'lng': -77.3960639},
#    'viewport': {'northeast': {'lat': 38.96771142989272,
#      'lng': -77.39491507010727},
#     'southwest': {'lat': 38.96501177010727, 'lng': -77.39761472989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'bed28b48fdb509bee6668f2a6f0f816d3ba15ce9',
#   'name': 'Pizza Hut',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAA-Q1wOuMEVyFRLDnFdWxpgipJaqGyh_zVWdmvouh3aF-9-JsiQgHp_OrWzrJJp72S0NNhLVewONWg5F9u8ZUwGRLZzdC_DMbZj4XVP7QC6aX9NweRgTNP_IDC0-8rXHKNEhAyepfknz1tBipqyuNCUxvgGhTy6sV1oawpHvrUIyMLE-LlDIWv9Q',
#     'width': 4032}],
#   'place_id': 'ChIJTyaR7PVHtokRYaAjBq0B7Pg',
#   'price_level': 1,
#   'rating': 3.4,
#   'reference': 'CmRbAAAAE4tkXPC4tUluts7FjesNZNTdoYOpOKyrHnikZHnlOobuP9zbDOTGEFTPe19fvQpoJdsjH1ThndazWsYshbu1I4es9gDtbXbqV0typvIhDu4NhLDhR3YgEbK64NUq-U00EhASHWDuDQJjT3d8wQJbpr1pGhQVqYCSmPS9pjF9hucFbrLBlB_XsA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1061 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.950467, 'lng': -77.4106},
#    'viewport': {'northeast': {'lat': 38.95194962989272,
#      'lng': -77.40943492010727},
#     'southwest': {'lat': 38.94924997010727, 'lng': -77.41213457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '4e2cdc9e112c98c5ea49811a7f3ddca14680d5b8',
#   'name': "McDonald's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115377404142808458009/photos">McDonald&#39;s</a>'],
#     'photo_reference': 'CmRaAAAAT7H0l_NfczSMXBJenIhiPy7fPbnHmeYBjwcAAcC0gqFuFwJA-4bkDKyOeW64OPLVHp_rR3eEV8jxw0pelwPmS0MReMF5LQIr5dFil6hb1ZzcgSloMkKy3g5IpTiTLv_gEhCsdJixNancmdDzMeDrbWHlGhTLMoa3CFIYE3oM-hRihXI1Jtd3pA',
#     'width': 1025}],
#   'place_id': 'ChIJ1SqJ4JZHtokRk3WClJRxEHQ',
#   'price_level': 1,
#   'rating': 3,
#   'reference': 'CmRbAAAAvXSHavQCGRIEnHaYsNWkGH7JO3_y-WzCFkt35H9H_xf9RHBozM-cJeBlCuusbUQuPl9fxlVR7OuD1e5jBoN4IRl1V5dIYBafSUVVNDpc1Cc7cIohYyVUn9xqgMhOY5JkEhCb0jgp5drOjAb7k4K_-Tz4GhSWFd5QcmNFLKtOtSj3qAxEgmra0Q',
#   'scope': 'GOOGLE',
#   'types': ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2475 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9618057, 'lng': -77.4010807},
#    'viewport': {'northeast': {'lat': 38.96311137989272,
#      'lng': -77.39962217010729},
#     'southwest': {'lat': 38.96041172010727, 'lng': -77.40232182989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2d6976da3f2801d986ce885fc8956efd6b5e0f81',
#   'name': 'Chicken Rico',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 494,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106534131682755427884/photos">Chicken Rico</a>'],
#     'photo_reference': 'CmRZAAAA5Zv-_AwsPLdIvKoZcSiOyVwO2LYSj_UMA-MyUbF_-cvdONcQ3U33ze9SW4FefHPKwsi0qOPl9nYvBgdZISHxTK1lHFLQS0470JFK-ew6ighnH0KNVxK3HmIpAt3LeOSQEhBnT_1_s3PL1mlywuBMOTi5GhTrz9OEn3kC1vS-iTjuqBxYBCLb4g',
#     'width': 750}],
#   'place_id': 'ChIJfW2CRvNHtokRgnRr8cpyLQ4',
#   'rating': 4.3,
#   'reference': 'CmRbAAAAx5vSBiGzvEt62H9jhsKfZNVNNiOSml-syRWYmysGFZzrhI0ci70RP4q9QmhRup_dgUMfhCudDMFmmT_UBc3H3sRAq7TESghPvEMJxqkdExFxyFL6OY_b33xWz8bqfgcOEhAyjkevJclPh5yyplGTuR4GGhRLEL3lcPTM5EixMCyz5nk0xmC9hg',
#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1254 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9576238, 'lng': -77.40167129999999},
#    'viewport': {'northeast': {'lat': 38.95908737989272,
#      'lng': -77.40011237010728},
#     'southwest': {'lat': 38.95638772010727, 'lng': -77.40281202989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '03eb84c3a2be1142f0255ee1c5d4df5d7c36f039',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAADoU_jeR8MG8Dh9MZr9AgFiABXDHIxEZ82eyYpgGzNG-lvMlupA0kL5CvWq1ErT8znddSVgZUStzx9Ard-QzNBXtAJVz728a7J1hbtH3o8Y3aqV1GqIX27bHfgqssZfEUEhAqXRsQViQytaprAD6qVTmCGhRshgNWGul63C82rQB7UBrbx39wYg',
#     'width': 1080}],
#   'place_id': 'ChIJP1eLx_JHtokRK7t9rA12MmU',
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'CmRbAAAA3U1wX2ov_3rTOt6yen2JL2xD0UkjDh5c1NPbRhJ1Ve7VoPVtZaSUcQalH4s6yi3tKqrv48RkGV1xGcTK-s2ibUfjfsayf59cfPbEKS_SDo4s6n5FS2uBHs7nHDxJB3INEhBKwSzrN5bORhTnEx8VyWMzGhTRxxXQ6Y2YSL92gT7hwSARztNpOA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Worldgate Centre, Worldgate Dr 13053 Unit 14, Herndon'},
#  {'geometry': {'location': {'lat': 38.9783756, 'lng': -77.43503419999999},
#    'viewport': {'northeast': {'lat': 38.97979977989272,
#      'lng': -77.43367467010727},
#     'southwest': {'lat': 38.97710012010728, 'lng': -77.43637432989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '30b4adf5dd86fdf713d5787c0db6dfa27034af59',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'place_id': 'ChIJcxXv2IQ4tokRhq9cKObpksc',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAAVFjuWJCIrjHhYewUM05Exnp88sy9cBb1za3XrZhdAZEbLIWQFJAto7vda7TN_1o6GCjGeet_e9ZnfNhNdoIoGWJL-r1NsK87VPTmIH8x7JlQkhlVkRpbZensOm4FSWzGEhBZTSfU2UL4GkIzDG37MzJNGhTsfkqmzJga6DvngOh90s0HepOKuw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23050 Pacific Blvd, Sterling'},
#  {'geometry': {'location': {'lat': 38.977509, 'lng': -77.4106335},
#    'viewport': {'northeast': {'lat': 38.97895962989272,
#      'lng': -77.40947492010729},
#     'southwest': {'lat': 38.97625997010728, 'lng': -77.41217457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a6ae6e5aaeee067aa578716bc8b4556f4999e687',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116856164624339471300/photos">karthik kaaaru</a>'],
#     'photo_reference': 'CmRaAAAAmABOQ8gxyCeYgLRdLQaI5l-IMFcgK61niOuOKVdk0hUnBg5UaZK_67BGzvlNeENDmPs6SnYn_9WVtUcAmKdyeJiwTKwUo4wYQ1nEVRe_EEYChvGb_iA48bX_ek0Ekh1JEhBa2RBtVI32WeY9CwOgp3p4GhS2CgxY-UJ8G66sq_tQilLGTKs4Xg',
#     'width': 4032}],
#   'place_id': 'ChIJH5PXe11HtokRKWDX7XJORxE',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAARAER7NHufv7IcP5ViI1quRubyHrs3ip0_mu3vsQI9EjFeffYpL6nD4rMgZBOmZtRGC4nlZ7U5NdYGdLUFia65jVoy3eMXTMpSg1neexL0Z76KzeO9znW8GLnb5I2iexsEhB2S7ot-oDTiqR29RK9l5eJGhTXEclsNScgySg1W933xUeD4l2p6A',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23070 Oakgrove Rd #155, Sterling'}]
