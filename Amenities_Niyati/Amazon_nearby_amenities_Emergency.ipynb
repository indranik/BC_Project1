# %% [markdown]
# ## Search for nearby Amenities for all site locations of each city
#     List of Amenities by Categories:
#     Categories:
#     A. Emergency Facilities
#        '''How accesible are these facilities in case of mass emergency on/around
#           sites for containing the situation and resuming business asap'''
#
#        1. Hospital
#        2. Fire Station
#        3. Doctor
#
#     B. Accomodation
#        '''Many executive employees travel from outside the city for fews days a week and might need lodging
#           facility as close to the company as possible. Also lot of local/not-local employees use vehicle
#           for commute and will need parking nearby'''
#
#        1. Lodging
#        2. Parking
#
#     C. Recreation
#         '''MNC(s) often arrange for team building activities on and near site. Also employees might look for group
#            recreational activities close  to work'''
#
#        1. Movies Theatres
#        2. Parks
#        3. Malls
#        4. Amusement park
#        5. Cafe/Restaurants
#
#     D. Basic Errands/appointments
#         '''By large employees tend to take care of daily errands and appoinments in lunch breaks or before/after
#            work hours and prefer it to be as close to work as possible for obvious reasons'''
#
#        1. Super markets
#        2. Post Office
#        3. Doctor
#
#     E. Fitness
#         '''Fitness is top on priority list for a significant amount of employees now a days may be in gym or a
#            jog/walk in park.'''
#
#        1. Gym
#        2. Parks

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import time

# Google developer API key
from config import g_key

# %%
# read places 
xls = pd.ExcelFile('BC_Project1/Project1_AmazonSites.xlsx') 
places_df=xls.parse('AmazonSites', dtype=str)
places_df = places_df[['Amazon City','Site','Site Name','Latitude','Longitude']]
places_df.head()
#len(places_df)
# Out:
#               Amazon City   Site                           Site Name Latitude  \
# 0  Northern Virginia Area  Site1    Center for Innovation Technology    38.96
# 1  Northern Virginia Area  Site2       Crystal City and Potomac Yard    38.84
# 2           Washington DC  Site1  Nationals Park/ D.C United Stadium    38.86
# 3           Washington DC  Site2                       Union Station    38.89
# 4           Washington DC  Site3              Hill-East Neighborhood    38.88
#
#   Longitude
# 0    -77.42
# 1    -77.05
# 2    -77.01
# 3       -77
# 4    -76.97

# %%
emergency = {'hospital':'Hospital', 'fire_station':'Fire Station', 'doctor':'Doctor'}
all_emergency_rating = []

for key in emergency.keys():
    emergency_rating = []
    for site in places_df.values:

        # geocoordinates
        target_coordinates = str(site[3]) + ',' + str(site[4])
        target_search = emergency[key]
        target_radius = 2500
        target_type = key
        print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
        print("----------")
        # set up a parameters dictionary
        params = {
            "location": target_coordinates,
            "keyword": target_search,
            "radius": target_radius,
            "type": target_type,
            "key": g_key
        }

        # base url
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params).json()
        results = response.get('results')
        total_counts = len(results)
        print(total_counts)

        # Print the name and address of the first restaurant that appears
        for x in range(total_counts):
            if "rating" in results[x].keys():
                rating = results[x]["rating"]
            else:
                rating = 'NAN'
    
            emergency_rating.append({"Site Name":site[2],
                                       key+" Total Count":total_counts,
                                       "Latitude":site[3],
                                       "Longitude":site[4],
                                       "Facility "+key:results[x]["name"],
                                       "Rating":rating})
            
            time.sleep(2)
        time.sleep(2)
    all_emergency_rating.append(emergency_rating)
    print("ALL Done!!!!!")
#all_eatingout_rating
# Out:
# hospital For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 1
# hospital For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 1
# hospital For Washington DC: Site1, 38.86,-77.01
# ----------
# 6
# hospital For Washington DC: Site2, 38.89,-77
# ----------
# 6
# hospital For Washington DC: Site3, 38.88,-76.97
# ----------
# 5
# hospital For Washington DC: Site4, 38.91,-77.02
# ----------
# 14
# hospital For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 9
# hospital For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 5
# hospital For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 11
# hospital For Boston: Site1, 42.39,-71
# ----------
# 2
# hospital For Boston: Site2, 42.34,-71.03
# ----------
# 4
# hospital For Boston: Site3, 42.35,-71.05
# ----------
# 19
# hospital For Boston: Site4, 42.34,-71.06
# ----------
# 16
# hospital For New York: Site1, 40.75,-74
# ----------
# 18
# hospital For New York: Site2, 40.74,-73.94
# ----------
# 3
# hospital For New York: Site3, 40.7,-73.98
# ----------
# 12
# hospital For New York: Site4, 40.7,-74.01
# ----------
# 13
# hospital For Chicago: Site1, 41.91,-87.64
# ----------
# 14
# hospital For Chicago: Site2, 41.89,-87.64
# ----------
# 14
# hospital For Chicago: Site3, 41.88,-87.65
# ----------
# 16
# hospital For Chicago: Site4, 41.87,-87.63
# ----------
# 5
# hospital For Chicago: Site5, 41.87,-87.62
# ----------
# 4
# hospital For Chicago: Site6, 41.86,-87.67
# ----------
# 14
# hospital For Chicago: Site7, 41.85,-87.66
# ----------
# 11
# hospital For Chicago: Site8, 41.83,-87.6
# ----------
# 2
# hospital For Raleigh: Site1, 35.9,-78.87
# ----------
# 3
# hospital For Raleigh: Site2, 35.85,-79.08
# ----------
# 0
# hospital For Raleigh: Site3, 35.77,-78.64
# ----------
# 3
# hospital For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 15
# hospital For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 6
# hospital For Atlanta: Site3, 33.904,-84.2843
# ----------
# 5
# hospital For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 3
# hospital For Austin: Site1, 30.2586,-97.7444
# ----------
# 7
# hospital For Austin: Site2, 30.2714,-97.6647
# ----------
# 0
# hospital For Austin: Site3, 30.199,-97.8276
# ----------
# 0
# hospital For Austin: Site4, 30.4015,-97.7268
# ----------
# 4
# hospital For Austin: Site5, 30.4014,-97.7147
# ----------
# 2
# hospital For Austin: Site6, 30.4704,-97.7701
# ----------
# 1
# hospital For Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!
# fire_station For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 2
# fire_station For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 6
# fire_station For Washington DC: Site1, 38.86,-77.01
# ----------
# 7
# fire_station For Washington DC: Site2, 38.89,-77
# ----------
# 13
# fire_station For Washington DC: Site3, 38.88,-76.97
# ----------
# 7
# fire_station For Washington DC: Site4, 38.91,-77.02
# ----------
# 16
# fire_station For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 4
# fire_station For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 4
# fire_station For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 3
# fire_station For Boston: Site1, 42.39,-71
# ----------
# 4
# fire_station For Boston: Site2, 42.34,-71.03
# ----------
# 5
# fire_station For Boston: Site3, 42.35,-71.05
# ----------
# 20
# fire_station For Boston: Site4, 42.34,-71.06
# ----------
# 15
# fire_station For New York: Site1, 40.75,-74
# ----------
# 20
# fire_station For New York: Site2, 40.74,-73.94
# ----------
# 7
# fire_station For New York: Site3, 40.7,-73.98
# ----------
# 14
# fire_station For New York: Site4, 40.7,-74.01
# ----------
# 13
# fire_station For Chicago: Site1, 41.91,-87.64
# ----------
# 11
# fire_station For Chicago: Site2, 41.89,-87.64
# ----------
# 14
# fire_station For Chicago: Site3, 41.88,-87.65
# ----------
# 15
# fire_station For Chicago: Site4, 41.87,-87.63
# ----------
# 11
# fire_station For Chicago: Site5, 41.87,-87.62
# ----------
# 10
# fire_station For Chicago: Site6, 41.86,-87.67
# ----------
# 9
# fire_station For Chicago: Site7, 41.85,-87.66
# ----------
# 6
# fire_station For Chicago: Site8, 41.83,-87.6
# ----------
# 4
# fire_station For Raleigh: Site1, 35.9,-78.87
# ----------
# 2
# fire_station For Raleigh: Site2, 35.85,-79.08
# ----------
# 0
# fire_station For Raleigh: Site3, 35.77,-78.64
# ----------
# 6
# fire_station For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 6
# fire_station For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 4
# fire_station For Atlanta: Site3, 33.904,-84.2843
# ----------
# 1
# fire_station For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 3
# fire_station For Austin: Site1, 30.2586,-97.7444
# ----------
# 6
# fire_station For Austin: Site2, 30.2714,-97.6647
# ----------
# 3
# fire_station For Austin: Site3, 30.199,-97.8276
# ----------
# 2
# fire_station For Austin: Site4, 30.4015,-97.7268
# ----------
# 4
# fire_station For Austin: Site5, 30.4014,-97.7147
# ----------
# 4
# fire_station For Austin: Site6, 30.4704,-97.7701
# ----------
# 3
# fire_station For Austin: Site7, 30.1338,-97.6411
# ----------
# 1
# ALL Done!!!!!
# doctor For Northern Virginia Area: Site1, 38.96,-77.42
# ----------
# 1
# doctor For Northern Virginia Area: Site2, 38.84,-77.05
# ----------
# 0
# doctor For Washington DC: Site1, 38.86,-77.01
# ----------
# 1
# doctor For Washington DC: Site2, 38.89,-77
# ----------
# 3
# doctor For Washington DC: Site3, 38.88,-76.97
# ----------
# 2
# doctor For Washington DC: Site4, 38.91,-77.02
# ----------
# 7
# doctor For Los Angeles: Site1, 34.1802,-118.6028
# ----------
# 7
# doctor For Los Angeles: Site2, 34.4318,-118.5584
# ----------
# 0
# doctor For Los Angeles: Site3, 34.0885,-117.7702
# ----------
# 3
# doctor For Boston: Site1, 42.39,-71
# ----------
# 0
# doctor For Boston: Site2, 42.34,-71.03
# ----------
# 3
# doctor For Boston: Site3, 42.35,-71.05
# ----------
# 10
# doctor For Boston: Site4, 42.34,-71.06
# ----------
# 9
# doctor For New York: Site1, 40.75,-74
# ----------
# 10
# doctor For New York: Site2, 40.74,-73.94
# ----------
# 0
# doctor For New York: Site3, 40.7,-73.98
# ----------
# 2
# doctor For New York: Site4, 40.7,-74.01
# ----------
# 2
# doctor For Chicago: Site1, 41.91,-87.64
# ----------
# 9
# doctor For Chicago: Site2, 41.89,-87.64
# ----------
# 11
# doctor For Chicago: Site3, 41.88,-87.65
# ----------
# 10
# doctor For Chicago: Site4, 41.87,-87.63
# ----------
# 7
# doctor For Chicago: Site5, 41.87,-87.62
# ----------
# 7
# doctor For Chicago: Site6, 41.86,-87.67
# ----------
# 2
# doctor For Chicago: Site7, 41.85,-87.66
# ----------
# 1
# doctor For Chicago: Site8, 41.83,-87.6
# ----------
# 0
# doctor For Raleigh: Site1, 35.9,-78.87
# ----------
# 0
# doctor For Raleigh: Site2, 35.85,-79.08
# ----------
# 1
# doctor For Raleigh: Site3, 35.77,-78.64
# ----------
# 1
# doctor For Atlanta: Site1, 33.7615,-84.3856
# ----------
# 4
# doctor For Atlanta: Site2, 34.5129,-93.0431
# ----------
# 1
# doctor For Atlanta: Site3, 33.904,-84.2843
# ----------
# 5
# doctor For Atlanta: Site4, 33.9133,-84.3888
# ----------
# 2
# doctor For Austin: Site1, 30.2586,-97.7444
# ----------
# 4
# doctor For Austin: Site2, 30.2714,-97.6647
# ----------
# 0
# doctor For Austin: Site3, 30.199,-97.8276
# ----------
# 2
# doctor For Austin: Site4, 30.4015,-97.7268
# ----------
# 6
# doctor For Austin: Site5, 30.4014,-97.7147
# ----------
# 4
# doctor For Austin: Site6, 30.4704,-97.7701
# ----------
# 2
# doctor For Austin: Site7, 30.1338,-97.6411
# ----------
# 0
# ALL Done!!!!!

# %%
all_emergency_rating
# Out:
# [[{'Facility hospital': 'Watson Salsbury Pediatrics',
#    'Latitude': '38.96',
#    'Longitude': '-77.42',
#    'Rating': 'NAN',
#    'Site Name': 'Center for Innovation Technology',
#    'hospital Total Count': 1},
#   {'Facility hospital': 'Neighborhood Health',
#    'Latitude': '38.84',
#    'Longitude': '-77.05',
#    'Rating': 2.8,
#    'Site Name': 'Crystal City and Potomac Yard',
#    'hospital Total Count': 1},
#   {'Facility hospital': 'St. Elizabeths Hospital',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4.1,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': "Children's Health Center – Anacostia",
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 3.9,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Saint Elizabeth hospital Washington D.C.20002',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Unity Health Care',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'St. Elizabeths West Campus',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'United Medical Center',
#    'Latitude': '38.86',
#    'Longitude': '-77.01',
#    'Rating': 1.4,
#    'Site Name': 'Nationals Park/ D.C United Stadium',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'BridgePoint Hospital Capitol Hill',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.7,
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Washington DC Mental Health',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 2.6,
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Perry Family Health Center',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 4.2,
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Homeophathic Hospital',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 'NAN',
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'MedStar PromptCare Capitol Hill',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 3.1,
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'Triwest Healthcare Alliance',
#    'Latitude': '38.89',
#    'Longitude': '-77',
#    'Rating': 1,
#    'Site Name': 'Union Station',
#    'hospital Total Count': 6},
#   {'Facility hospital': 'BridgePoint Hospital Capitol Hill',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 2.7,
#    'Site Name': 'Hill-East Neighborhood',
#    'hospital Total Count': 5},
#   {'Facility hospital': "CP&A Fort Davis - Children's National Health System",
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 'NAN',
#    'Site Name': 'Hill-East Neighborhood',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Washington DC Mental Health',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 2.6,
#    'Site Name': 'Hill-East Neighborhood',
#    'hospital Total Count': 5},
#   {'Facility hospital': "Children's Health Center – Anacostia",
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.9,
#    'Site Name': 'Hill-East Neighborhood',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'MedStar PromptCare Capitol Hill',
#    'Latitude': '38.88',
#    'Longitude': '-76.97',
#    'Rating': 3.1,
#    'Site Name': 'Hill-East Neighborhood',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Howard University Hospital',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'MedStar Washington Hospital Center',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.2,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Children's National Medical Center",
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.9,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'BridgePoint Hospital Capitol Hill',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'The George Washington University Hospital',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 5,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Washington DC VA Medical Center',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.3,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'MedStar Washington Hospital Center',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'MedStar Washington Hospital Center Behavioral Health Services',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 3.7,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Children's Health Center - Shaw",
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2.6,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Med Star Health',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Physician Hospitals of America',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Homeophathic Hospital',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Student Health Center @ Howard University',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 2,
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Washington Hospital Center',
#    'Latitude': '38.91',
#    'Longitude': '-77.02',
#    'Rating': 'NAN',
#    'Site Name': 'Shaw-Howard University Area',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'West Hills Hospital & Medical Center',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3.4,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'Med Point Management',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 3,
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'west hills medical center',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'UCLA Health Woodland Hills - Family Medicine, Internal Medicine & Pediatrics',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'Kaiser hospital',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'Orhthalmology',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'West Hills medical',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'AA - Womens Group',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': 'UBS Medical Co',
#    'Latitude': '34.1802',
#    'Longitude': '-118.6028',
#    'Rating': 'NAN',
#    'Site Name': 'Warner Center West San Fernando Valley',
#    'hospital Total Count': 9},
#   {'Facility hospital': "Children's Hospital Los Angeles - Valencia Care Center",
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 5,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Providence Health & Services',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 3,
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Providence Holy Cross Health Center at Santa Clarita',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 'NAN',
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Pediatric Cardiology Medical Associates',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 'NAN',
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Kaiser MOB',
#    'Latitude': '34.4318',
#    'Longitude': '-118.5584',
#    'Rating': 'NAN',
#    'Site Name': 'New Hall Ranch Santa Clarita Valley',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Pomona Valley Hospital Medical Center',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 2.7,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Casa Colina Hospital and Centers for Healthcare',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 4.1,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Landmark Medical Center',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.8,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Pomona Pediatrics',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 3.8,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'R & B Lewis Cancer Care Center',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 5,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Pomona Valley Health Centers',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Murray company Job Site',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Pomona Pediatrics',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Delivery room',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Outpatient Surgery Pavilion',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 5,
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Clinical',
#    'Latitude': '34.0885',
#    'Longitude': '-117.7702',
#    'Rating': 'NAN',
#    'Site Name': 'Pomona Fairplex',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Chelsea Soldier Home-Quigley Memorial Hospital',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 'NAN',
#    'Site Name': 'Suffolk Downs',
#    'hospital Total Count': 2},
#   {'Facility hospital': 'CHA Revere Family Health Center',
#    'Latitude': '42.39',
#    'Longitude': '-71',
#    'Rating': 4.2,
#    'Site Name': 'Suffolk Downs',
#    'hospital Total Count': 2},
#   {'Facility hospital': 'MGH Downtown Primary Care',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 5,
#    'Site Name': 'South Boston Waterfront',
#    'hospital Total Count': 4},
#   {'Facility hospital': "Women's Heart Health Program at the Massachusetts General Hospital Corrigan Minehan Heart Center",
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 'NAN',
#    'Site Name': 'South Boston Waterfront',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'Psychology Assessment Center | MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 'NAN',
#    'Site Name': 'South Boston Waterfront',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'Spring Compassionate Hospital',
#    'Latitude': '42.34',
#    'Longitude': '-71.03',
#    'Rating': 'NAN',
#    'Site Name': 'South Boston Waterfront',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'Massachusetts General Hospital Plastic & Reconstructive Surgery',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.2,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Floating Hospital for Children at Tufts Medical Center',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.5,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Shriners Hospitals for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 4.9,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Sports Concussion Clinic | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': "Children's Hospital",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'MGH Downtown Primary Care',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 5,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Mass General Division of Trauma, Emergency Surgery & Surgical Critical Care',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Mass General',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': "Brigham & Women's Development Office",
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Veterans Administration: Zimelman Abraham MD',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Boston Medical Center',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 3,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Endocrinology & Diabetes | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Blake building at Massachusetts general hospital, Boston',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 1,
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Dermatology Program MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Harvard PMR',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Otolaryngology | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Pulmonary Medicine | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Hepatobiliary & Pancreatic Disease | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Pediatric Ophthalmology & Strabismus | MassGeneral Hospital for Children',
#    'Latitude': '42.35',
#    'Longitude': '-71.05',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown',
#    'hospital Total Count': 19},
#   {'Facility hospital': 'Floating Hospital for Children at Tufts Medical Center',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 4.5,
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Sports Concussion Clinic | MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': "Children's Hospital",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'MGH Downtown Primary Care',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 5,
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Wing Memorial Hospital & Med Center',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Mass General',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Shriners Hosp for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': "Brigham & Women's Development Office",
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Boston Medical Center',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 3,
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Pediatric Endocrinology & Diabetes | MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Massachusetts General Hospital',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Pediatric Dermatology Program MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Pediatric Otolaryngology | MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Pediatric Feeding Program, MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Harvard PMR',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Pediatric Ophthalmology & Strabismus | MassGeneral Hospital for Children',
#    'Latitude': '42.34',
#    'Longitude': '-71.06',
#    'Rating': 'NAN',
#    'Site Name': 'South End',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Bellevue Hospital Center',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.6,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Greater New York Hospital Association',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'NYU Medical Center, Tisch Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'NewYork Presbyterian Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.1,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': "St Vincent's Hospital NY",
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'MedStar Union Memorial Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'NewYork-Presbyterian Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 1,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Lenox Hill Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'National Jewish Medical-Research',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'The Mount Sinai Comprehensive Health',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'NYP',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.5,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'American Friends-Laniado Hospital',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Mount Sinai Beth Israel',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.6,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'VA NY Harbor Healthcare System',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.6,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Columbia University Medical Center',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.7,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Center for Children',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.9,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'St Vincents Hospital & Med CTR-NY',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 'NAN',
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'Hospital for Joint Disease Diabetic Foot & Ankle Center, Wound Healing Center, & Ambulatory Care Clinics',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3,
#    'Site Name': 'Hudson Yards',
#    'hospital Total Count': 18},
#   {'Facility hospital': 'The Floating Hospital',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4.3,
#    'Site Name': 'Long Island City',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'Floating Hospital Inc',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 3,
#    'Site Name': 'Long Island City',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'Rockefeller University Hospital',
#    'Latitude': '40.74',
#    'Longitude': '-73.94',
#    'Rating': 4,
#    'Site Name': 'Long Island City',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'NewYork-Presbyterian/Lower Manhattan Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3.7,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'The Brooklyn Hospital Center',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'New York Methodist Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 3,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'NYC Health + Hospitals',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 1,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'Mount Sinai Eye And Ear',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'Blue Pearl Veterinary',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'Bayonne Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'NewYork-Presbyterian Pediatrics',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'NYU Langone Medical Associates',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': "Cohen Children's Northwell Health Physician Partners Pediatric Specialists at Williamsburg",
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 'NAN',
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'Premier Pediatrics',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.6,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'NYU Langone Medical Center Business Office',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'hospital Total Count': 12},
#   {'Facility hospital': 'NewYork-Presbyterian/Lower Manhattan Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3.7,
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'New York Methodist Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3,
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Floating Hospital Inc',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Mount Sinai St. Luke’s Hospital Breast Center',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'NYC Health + Hospitals',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 1,
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Mount Sinai Medical Center',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Blue Pearl Veterinary',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Weill Cornell Medicine Primary Care - Tribeca',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'NYU Langone Medical Center Business Office',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4,
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Bayonne Hospital',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'NewYork-Presbyterian Pediatrics',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'NYU Langone Medical Associates',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 'NAN',
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'The Brooklyn Hospital Center',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 3,
#    'Site Name': 'Financial District',
#    'hospital Total Count': 13},
#   {'Facility hospital': 'Northwestern Memorial Hospital',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.5,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Ann & Robert H. Lurie Children's Hospital of Chicago",
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Ann & Robert H. Lurie Children's Hospital of Chicago Outpatient Center in Lincoln Park",
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.2,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Chicago Lakeshore Hospital - Lakeshore Center for Behavioral Health',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 2,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Sarah L. Stanos, DO',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Advocate Health Care',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Advocate Health Center',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Columbus Hospital',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'University Of Chicago Medicine',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Davita Dialysis',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Northwestern Memorial Hospital',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Stone Institute of Psychiatry',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Presence Medical Group',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Gi Lab of St Joseph Hospital',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.3,
#    'Site Name': 'Lincoln Yards',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Northwestern Memorial Hospital',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.5,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'University of Illinois Hospital & Health Sciences System',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.2,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Ann & Robert H. Lurie Children's Hospital of Chicago",
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Chicago Lakeshore Hospital - Lakeshore Center for Behavioral Health',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 2,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Rush University Medical Center',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.8,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Rush University Children's Hospital",
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.9,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Advocate Health Care',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Dr. Dean A. Raffaelli, DO',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 1,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'University Of Chicago Medicine',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Rush Tower',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Davita Dialysis',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': "lurie's children",
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Northwestern Memorial Hospital',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Stone Institute of Psychiatry',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'John H. Stroger, Jr. Hospital of Cook County',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.2,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Northwestern Memorial Hospital',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.5,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'University of Illinois Hospital & Health Sciences System',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.2,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': "Ann & Robert H. Lurie Children's Hospital of Chicago",
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.3,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Cook County Hospital',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.1,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Jesse Brown V. A. Hospital',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.2,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Chicago Lakeshore Hospital - Lakeshore Center for Behavioral Health',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Rush University Medical Center',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.8,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'University Of Illinois Medical Center - Obstetrics And Gynecology',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 5,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': "Rush University Children's Hospital",
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.9,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Dr. Dean A. Raffaelli, DO',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 1,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'University Of Chicago Medicine',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Rush Tower',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.7,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'John Stroger Hospital: Oncology Department',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 3.8,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': "lurie's children",
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Taylor Pavilion - Jesse Brown VA Medical Center',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 2,
#    'Site Name': 'Futton Market',
#    'hospital Total Count': 16},
#   {'Facility hospital': 'Mercy Medical in Chinatown',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.5,
#    'Site Name': 'City Center Campus',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Dr. Dean A. Raffaelli, DO',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 1,
#    'Site Name': 'City Center Campus',
#    'hospital Total Count': 5},
#   {'Facility hospital': "lurie's children",
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Mercy Hospital & Medical Center',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 2.6,
#    'Site Name': 'City Center Campus',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Stone Institute of Psychiatry',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'hospital Total Count': 5},
#   {'Facility hospital': 'Dr. Dean A. Raffaelli, DO',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 1,
#    'Site Name': 'The Downtown District',
#    'hospital Total Count': 4},
#   {'Facility hospital': "lurie's children",
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'Mercy Hospital & Medical Center',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 2.6,
#    'Site Name': 'The Downtown District',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'Stone Institute of Psychiatry',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'hospital Total Count': 4},
#   {'Facility hospital': 'John H. Stroger, Jr. Hospital of Cook County',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.2,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'University of Illinois Hospital & Health Sciences System',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.2,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Mount Sinai Hospital',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 2.5,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Cook County Hospital',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.1,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Saint Anthony Hospital',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.1,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Schwab Rehabilitation Hospital',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.3,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Jesse Brown V. A. Hospital',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 4.2,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Rush University Medical Center',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.8,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Rush University Children's Hospital",
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.9,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'University Of Illinois Medical Center - Obstetrics And Gynecology',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 5,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Mt Sinai Hospital Crisis Residence',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 5,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': "Sinai Children's Hospital Neo",
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.7,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'John Stroger Hospital: Oncology Department',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 3.8,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'Taylor Pavilion - Jesse Brown VA Medical Center',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 2,
#    'Site Name': 'The Illinois Medical District',
#    'hospital Total Count': 14},
#   {'Facility hospital': 'John H. Stroger, Jr. Hospital of Cook County',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.2,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'University of Illinois Hospital & Health Sciences System',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.2,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Jesse Brown V. A. Hospital',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 4.2,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'University Of Illinois Medical Center - Obstetrics And Gynecology',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 5,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Mt Sinai Hospital Crisis Residence',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 5,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Mercy Medical in Chinatown',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 2.5,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'John Stroger Hospital: Oncology Department',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.8,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Taylor Pavilion - Jesse Brown VA Medical Center',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 2,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Dr. Dean A. Raffaelli, DO',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 1,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Mercy Medical In Bridgeport',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Cook County Hospital',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 3.1,
#    'Site Name': 'The 78',
#    'hospital Total Count': 11},
#   {'Facility hospital': 'Mercy Hospital & Medical Center',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 2.6,
#    'Site Name': 'Burnham Lakefront',
#    'hospital Total Count': 2},
#   {'Facility hospital': 'Mercy Family Health Center',
#    'Latitude': '41.83',
#    'Longitude': '-87.6',
#    'Rating': 3.4,
#    'Site Name': 'Burnham Lakefront',
#    'hospital Total Count': 2},
#   {'Facility hospital': 'Hospital Physician Partners',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 'NAN',
#    'Site Name': 'Research Triangle Park',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'Duke Medical Plaza Page Road',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 3.2,
#    'Site Name': 'Research Triangle Park',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'duke regional hospital',
#    'Latitude': '35.9',
#    'Longitude': '-78.87',
#    'Rating': 'NAN',
#    'Site Name': 'Research Triangle Park',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'Capital Psychiatric Services',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 'NAN',
#    'Site Name': 'Warehouse District',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'TissuGlu',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 'NAN',
#    'Site Name': 'Warehouse District',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'DSR',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 'NAN',
#    'Site Name': 'Warehouse District',
#    'hospital Total Count': 3},
#   {'Facility hospital': 'Grady Memorial Hospital',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2.9,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Hughes Spalding hospital',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 'NAN',
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Emory University Hospital Midtown',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 3.4,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Northside Hospital',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 3.7,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Select Specialty Hospital - Midtown Atlanta',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 3.3,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': "Children's Healthcare of Atlanta at Hughes Spalding - Emergency Department",
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 3.8,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'WellStar Atlanta Medical Center',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 2.6,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Grady Health System',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.5,
#    'Site Name': 'Downtown Atlanta',
#    'hospital Total Count': 15},
#   {'Facility hospital': 'Grady Hospital IT Department',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.5,
#    'Site Name': 'Downtown Atlanta',
# ...
#    'Rating': 4.9,
#    'Site Name': 'Hudson Yards',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Filiaci Carlo MD',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 4.8,
#    'Site Name': 'Hudson Yards',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Laser Surgery Care: Goldstone Stephen MD',
#    'Latitude': '40.75',
#    'Longitude': '-74',
#    'Rating': 3.8,
#    'Site Name': 'Hudson Yards',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Workers Compensation Doctor - Dr. Jeff Mollins, D.C.',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.8,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Deutsch James A MD',
#    'Latitude': '40.7',
#    'Longitude': '-73.98',
#    'Rating': 4.3,
#    'Site Name': 'Brooklyn Tech Triangle',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Workers Compensation Doctor - Dr. Jeff Mollins, D.C.',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.8,
#    'Site Name': 'Financial District',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Deutsch James A MD',
#    'Latitude': '40.7',
#    'Longitude': '-74.01',
#    'Rating': 4.3,
#    'Site Name': 'Financial District',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. Steven H. Dayan, MD',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.6,
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Dr. Irvin M. Wiesman',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Dr. Rodrigo Endara',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 3.7,
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Dr. Douglas M. Sidle, MD',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Chicago Institute-Neurosurgery: Gleiber Michael MD',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Chicago Dizziness & Hearing',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Gina T. Consolino-Barsotti, APN',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Klein & Slotten Medical Associates',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 4,
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Dr. Jane Bang M.D.',
#    'Latitude': '41.91',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'Lincoln Yards',
#    'doctor Total Count': 9},
#   {'Facility doctor': 'Dr. Leilah Backhus, MD',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Richard M. Aronwald, MD',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Steven H. Dayan, MD',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.6,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Irvin M. Wiesman',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.3,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Rodrigo Endara',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 3.7,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Chicago Express Doctors',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4.7,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Douglas M. Sidle, MD',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Yates Diane M',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Chicago Institute-Neurosurgery',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 'NAN',
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Chicago Dizziness & Hearing',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 5,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Klein & Slotten Medical Associates',
#    'Latitude': '41.89',
#    'Longitude': '-87.64',
#    'Rating': 4,
#    'Site Name': 'The River District',
#    'doctor Total Count': 11},
#   {'Facility doctor': 'Dr. Leilah Backhus, MD',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Dr. Richard M. Aronwald, MD',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Dr. Irvin M. Wiesman',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.3,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Dr. Joshua R. Merok, MD',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 5,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Chicago Express Doctors',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.7,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Yates Diane M',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Chicago Institute-Neurosurgery',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 'NAN',
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Chicago Dizziness & Hearing',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 5,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Dr. Carlos Sandoval-Herrera, MD FACOG SOEMIG MSMIG',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 5,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Ahmed Safia MD',
#    'Latitude': '41.88',
#    'Longitude': '-87.65',
#    'Rating': 4.2,
#    'Site Name': 'Futton Market',
#    'doctor Total Count': 10},
#   {'Facility doctor': 'Dr. Leilah Backhus, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Richard M. Aronwald, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Chicago Express Doctors',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 4.7,
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'St Mary & Elizabeth Med Center: Herrada Baudelio MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Ameer Gomberawalla, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 'NAN',
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Carlos Sandoval-Herrera, MD FACOG SOEMIG MSMIG',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 5,
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Chicago Dizziness & Hearing',
#    'Latitude': '41.87',
#    'Longitude': '-87.63',
#    'Rating': 5,
#    'Site Name': 'City Center Campus',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Leilah Backhus, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Richard M. Aronwald, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Joshua R. Merok, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 5,
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Chicago Express Doctors',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 4.7,
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'St Mary & Elizabeth Med Center: Herrada Baudelio MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Ameer Gomberawalla, MD',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 'NAN',
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Chicago Dizziness & Hearing',
#    'Latitude': '41.87',
#    'Longitude': '-87.62',
#    'Rating': 5,
#    'Site Name': 'The Downtown District',
#    'doctor Total Count': 7},
#   {'Facility doctor': 'Dr. Richard M. Aronwald, MD',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 'NAN',
#    'Site Name': 'The Illinois Medical District',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. Carlos Sandoval-Herrera, MD FACOG SOEMIG MSMIG',
#    'Latitude': '41.86',
#    'Longitude': '-87.67',
#    'Rating': 5,
#    'Site Name': 'The Illinois Medical District',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. Carlos Sandoval-Herrera, MD FACOG SOEMIG MSMIG',
#    'Latitude': '41.85',
#    'Longitude': '-87.66',
#    'Rating': 5,
#    'Site Name': 'The 78',
#    'doctor Total Count': 1},
#   {'Facility doctor': 'Plum Spring Clinic Holistic Wellness Center',
#    'Latitude': '35.85',
#    'Longitude': '-79.08',
#    'Rating': 5,
#    'Site Name': 'Chatham Park',
#    'doctor Total Count': 1},
#   {'Facility doctor': 'Parsons James S MD',
#    'Latitude': '35.77',
#    'Longitude': '-78.64',
#    'Rating': 4.3,
#    'Site Name': 'Warehouse District',
#    'doctor Total Count': 1},
#   {'Facility doctor': 'Inn House Doctor',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 1,
#    'Site Name': 'Downtown Atlanta',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Frank M. Lockwood, MD',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.1,
#    'Site Name': 'Downtown Atlanta',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Bragg Julian A MD',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 5,
#    'Site Name': 'Downtown Atlanta',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Nicholas Beaulieu, MD',
#    'Latitude': '33.7615',
#    'Longitude': '-84.3856',
#    'Rating': 4.2,
#    'Site Name': 'Downtown Atlanta',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. James E. Griffin, MD',
#    'Latitude': '34.5129',
#    'Longitude': '-93.0431',
#    'Rating': 'NAN',
#    'Site Name': 'Midtown',
#    'doctor Total Count': 1},
#   {'Facility doctor': "Doctor Li's Family Care",
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 'NAN',
#    'Site Name': 'Former GM plant',
#    'doctor Total Count': 5},
#   {'Facility doctor': 'Daniel S Goodman, MD',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.6,
#    'Site Name': 'Former GM plant',
#    'doctor Total Count': 5},
#   {'Facility doctor': 'Dr. Sudha Challa, MD',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.3,
#    'Site Name': 'Former GM plant',
#    'doctor Total Count': 5},
#   {'Facility doctor': 'Miranda Medical Clinic',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4,
#    'Site Name': 'Former GM plant',
#    'doctor Total Count': 5},
#   {'Facility doctor': 'Dr. Suneel B. Katragadda, MD',
#    'Latitude': '33.904',
#    'Longitude': '-84.2843',
#    'Rating': 4.6,
#    'Site Name': 'Former GM plant',
#    'doctor Total Count': 5},
#   {'Facility doctor': 'Dr. Thomas Chacko, MD',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.8,
#    'Site Name': 'The High Street Site',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Atlanta Hearing Doctor',
#    'Latitude': '33.9133',
#    'Longitude': '-84.3888',
#    'Rating': 4.8,
#    'Site Name': 'The High Street Site',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Downtown Doctor',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.2,
#    'Site Name': 'American-Statesman ',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Jeffrey E. Hagen, MD',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 2.1,
#    'Site Name': 'American-Statesman ',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Georgeanne Freeman, DO',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 3.5,
#    'Site Name': 'American-Statesman ',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Santiago Zamora MD',
#    'Latitude': '30.2586',
#    'Longitude': '-97.7444',
#    'Rating': 4.8,
#    'Site Name': 'American-Statesman ',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Pain Doctor; South Austin, TX',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 2.5,
#    'Site Name': 'Former 3M site',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. Harold D. Lewis, DO',
#    'Latitude': '30.199',
#    'Longitude': '-97.8276',
#    'Rating': 2.5,
#    'Site Name': 'Former 3M site',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. David N. Tobey, MD',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.6,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Stephens Kevin MD',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.7,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Dr. Kimberly L. Warfield, MD',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.2,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Dr. Kevin D. Fite, MD',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.6,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Nandini Kohli, MD',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 3.4,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Asim Aijaz, MD - Pain Doctor, North Austin',
#    'Latitude': '30.4015',
#    'Longitude': '-97.7268',
#    'Rating': 4.2,
#    'Site Name': 'The Domain',
#    'doctor Total Count': 6},
#   {'Facility doctor': 'Stephens Kevin MD',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.7,
#    'Site Name': 'Bardmoor Campus',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Kevin D. Fite, MD',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.6,
#    'Site Name': 'Bardmoor Campus',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Nandini Kohli, MD',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 3.4,
#    'Site Name': 'Bardmoor Campus',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Asim Aijaz, MD - Pain Doctor, North Austin',
#    'Latitude': '30.4014',
#    'Longitude': '-97.7147',
#    'Rating': 4.2,
#    'Site Name': 'Bardmoor Campus',
#    'doctor Total Count': 4},
#   {'Facility doctor': 'Dr. Scott Jurica MS, DC, PAK, ACN',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 5,
#    'Site Name': 'Robinson Ranch',
#    'doctor Total Count': 2},
#   {'Facility doctor': 'Dr. Valerie M. Chavez, MD',
#    'Latitude': '30.4704',
#    'Longitude': '-97.7701',
#    'Rating': 5,
#    'Site Name': 'Robinson Ranch',
#    'doctor Total Count': 2}]]

# %%
all_hosp_rating_df = pd.DataFrame(all_emergency_rating[0])
all_hosp_rating_df.head()
# Out:
#                                Facility hospital Latitude Longitude Rating  \
# 0                     Watson Salsbury Pediatrics    38.96    -77.42    NAN
# 1                            Neighborhood Health    38.84    -77.05    2.8
# 2                        St. Elizabeths Hospital    38.86    -77.01    4.1
# 3           Children's Health Center – Anacostia    38.86    -77.01    3.9
# 4  Saint Elizabeth hospital Washington D.C.20002    38.86    -77.01      4
#
#                             Site Name  hospital Total Count
# 0    Center for Innovation Technology                     1
# 1       Crystal City and Potomac Yard                     1
# 2  Nationals Park/ D.C United Stadium                     6
# 3  Nationals Park/ D.C United Stadium                     6
# 4  Nationals Park/ D.C United Stadium                     6

# %%
all_firestation_rating_df = pd.DataFrame(all_emergency_rating[1])
all_firestation_rating_df.head()
# Out:
#                                Facility fire_station Latitude Longitude  \
# 0  Metropolitan Washington Airports Authority Fir...    38.96    -77.42
# 1                       Frying Pan Fire Station # 36    38.96    -77.42
# 2                    Arlington County Fire Station 5    38.84    -77.05
# 3                                   Fire Station 209    38.84    -77.05
# 4                            Alexandria Fire Station    38.84    -77.05
#
#   Rating                         Site Name  fire_station Total Count
# 0    NAN  Center for Innovation Technology                         2
# 1    4.6  Center for Innovation Technology                         2
# 2      5     Crystal City and Potomac Yard                         6
# 3    NAN     Crystal City and Potomac Yard                         6
# 4      5     Crystal City and Potomac Yard                         6

# %%
all_doctor_rating_df = pd.DataFrame(all_emergency_rating[2])
all_doctor_rating_df.head()
# Out:
#                       Facility doctor Latitude Longitude Rating  \
# 0                 Dr. Ravi Iyer, M.D.    38.96    -77.42      5
# 1                Anderson Ronald L MD    38.86    -77.01    3.6
# 2           Dr. Zeba Shaheen Geloo MD    38.89       -77      1
# 3  Washington Primary Care Physicians    38.89       -77      2
# 4                Anderson Ronald L MD    38.89       -77    3.6
#
#                             Site Name  doctor Total Count
# 0    Center for Innovation Technology                   1
# 1  Nationals Park/ D.C United Stadium                   1
# 2                       Union Station                   3
# 3                       Union Station                   3
# 4                       Union Station                   3

# %%
all_hosp_rating_df.to_csv("Hospital_Rating.csv")

# %%
all_firestation_rating_df.to_csv("FireStation_Rating.csv")

# %%
all_doctor_rating_df.to_csv("Doctor_Rating.csv")

# %%
# geocoordinates
target_coordinates = '38.96,-77.42'
target_search = 'restaurant'
target_radius = 2500
target_type = 'Restaurant'
#print("{} For {}: {}, {}".format(key, site[0], site[1], target_coordinates))
print("----------")
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()
results = response.get('results')
# Out:
# ----------

# %%
results
# Out:
# [{'geometry': {'location': {'lat': 38.9516461, 'lng': -77.40930279999999},
#    'viewport': {'northeast': {'lat': 38.95289547989272,
#      'lng': -77.40782302010727},
#     'southwest': {'lat': 38.95019582010728, 'lng': -77.41052267989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'f5474a007bbf8aeda8ff931155aa674038635790',
#   'name': "Stone's Cove Kitbar",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1229,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104624375199943783692/photos">Stone&#39;s Cove Kitbar .</a>'],
#     'photo_reference': 'CmRaAAAASGaAGJlR1NVJ0K81ZxhaLRty1CQsVIozXhxQRNkbINZgaZWOXIDz30aYel0StuD5J3N2IO57VwuHFWMO6igfZWADo4AdCm3_G2B1vyT7XrtEY4_IfykSJBz5IepkvZ8yEhBSuUUUx-bfMqC1A2MjmXxsGhTsS4Kp2gJMk3Mj-ijkmuN-gjTwcQ',
#     'width': 2048}],
#   'place_id': 'ChIJ12VH3ZZHtokR-8N2xTFZAFI',
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'CmRbAAAA48Sw_plTWYXjYqcE0js1rgCVefdryONIDkY_9TZdwu9TnfKffiv2Gt1WMuOyZYRShVFWADMMA_HmWjS2GYYKl6yH_HNHmCfTn5dMJxctdoJsUYF7ipo-4bFCKg9SKrmrEhC2x91Fh8rUFymuA9ghPcC6GhTE65FDTIftUz1Z5BIAkV2-6VPH_g',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2403 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9616858, 'lng': -77.3985107},
#    'viewport': {'northeast': {'lat': 38.96316622989272,
#      'lng': -77.39691487010728},
#     'southwest': {'lat': 38.96046657010727, 'lng': -77.39961452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'cd7eb190d01776de1bf17e500b53a982c0105dea',
#   'name': 'Grill Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104090059274588000035/photos">Royal Sedan</a>'],
#     'photo_reference': 'CmRaAAAAJQ08fwfEAk0gZlzOkVZhwFDw45pMtxs4_8ocCgRjpNe9v6xAOdqPWvBYvuINMNUDj1QpiDUKzEmLb7i5Imb2g9G_QBpNdnUs0t9wDjCNj3Obddn3XkPOt8J_JlTHDGMHEhDCk9aHkRAbGsOQAvJX0JnUGhSoWF6T1bKCIPlMLF4Zn_rXVYkK3w',
#     'width': 4128}],
#   'place_id': 'ChIJu-16iPNHtokR97zBSb2gGBQ',
#   'rating': 4,
#   'reference': 'CmRbAAAA0Yb6jMlMMNmfmdXGYhcS59l-bRsVrDtKMWs8Sxl7FQyeEsjloDWwMeR5rYYwi4vonrS0NYxb7UMc73AZA3ftm0NzbMEZOgB_5vNJaw1PiL3ro8uVpf7T-b4Y4Wg_wsq0EhD5HeBk4dkjxrYJ4kTA3PsJGhT6CrecEOJ6sM3OoeQWTv3kFdhufw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '905 Herndon Pkwy # F, Herndon'},
#  {'geometry': {'location': {'lat': 38.9637234, 'lng': -77.3971565},
#    'viewport': {'northeast': {'lat': 38.96528557989272,
#      'lng': -77.39628927010727},
#     'southwest': {'lat': 38.96258592010727, 'lng': -77.39898892989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'ef2a33d1ad4e9511c03341de5e6a1ac60bf1abe1',
#   'name': 'Amphora Diner Deluxe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104016859568650225547/photos">A Google User</a>'],
#     'photo_reference': 'CmRaAAAAlS_AgujsFSub8i7HNVQjBAgEfh9aEaNlrPhrRoAfRQ-KXJhrKlgVba-2nwYQCjTFUyuFhTk4RRw4aOrQQmoOlagbqE9dKYCL_V11YMvlwJIAPzKJGE_cs-xnXkUCwCOjEhBZL1Jt82TbBgk8b8o0DDqXGhRySlcgxdOAwucdEc5bCkOgWXysKQ',
#     'width': 2048}],
#   'place_id': 'ChIJWVcERfRHtokRW9oscZS9Hyc',
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'CmRbAAAAxKo3XdtCD3_CPQGk_9b8JRcVfc7If23tnm7Ld0v-P850m_Dv2_zSj3rb3n20wVnGX2n5WheCfqRAK_CeYMdunYMjXz8jB5NzanYCu0r3-zbNyUkgV4lyYoXDpVSEgmaVEhBQuKEengwoVQbKkAw-yyK9GhSYTFFKoJKm-lf2mflXIXFBjM2jng',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1151 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9799278, 'lng': -77.43275589999999},
#    'viewport': {'northeast': {'lat': 38.9821982, 'lng': -77.43184287010727},
#     'southwest': {'lat': 38.97917099999999, 'lng': -77.43454252989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8291f6b3bba3e38c4a922b77a06d34d0c6b7bf76',
#   'name': 'Cracker Barrel Old Country Store',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115128327407342395621/photos">Darrell Brock</a>'],
#     'photo_reference': 'CmRaAAAA6DWSWKxMtS20uxDCI1oQOHCVptR576IX6giPoH66C0HVVjrExe5cEP9LB02p9Fx0r65liX1icr5dsljTrAGTzZOZY3bprOilgFST1L81_OwC1nSn20nEXKGdDz6c39oyEhDEQa_mQNoUYqXUTrzqJykwGhQIHT7c0pQxw0lgWb4P5ILGJhIDDw',
#     'width': 3984}],
#   'place_id': 'ChIJ3SY8YY84tokRQuEPIq1BlSc',
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'CmRbAAAAcQaeS5qKBlG4XJvLT1NhfhTMJbQXSdNWJXOOkBEKyaiiIfDK9ljRCGkANCRLXZkXh1MRnA-f-f5VmdoP3mTaCJqNtLOpH37t1Rt7reZmfVrGEWhz0h7mN4SbYFV4WWlfEhCBZjX_S6328qlH8c6JZ0vGGhSLXCJKfNWLDoworgxxsIhss047QQ',
#   'scope': 'GOOGLE',
#   'types': ['store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '23030 Indian Creek Dr, Sterling'},
#  {'geometry': {'location': {'lat': 38.9586216, 'lng': -77.403313},
#    'viewport': {'northeast': {'lat': 38.95984262989271,
#      'lng': -77.40174572010727},
#     'southwest': {'lat': 38.95714297010727, 'lng': -77.40444537989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2df21a3eef33456e061a049e742db552a6a7aa22',
#   'name': "Houlihan's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117979874678644930975/photos">Jose Gonzalez</a>'],
#     'photo_reference': 'CmRaAAAAjIWMFEdNVRDv0GiDgcW5CoVgkWSRODiPHKUWhFBsbR16OZWGnXZpdIWKmHapCBLRoewn4dzaf9L4WgXmpAnNQG02loIOLCHO1sZZGLe40Ekb6vRRKx2SMjXAhGBVYsHqEhAC2gdPYHB_kMrlatM7lFv7GhSlPUZgdiWH2PpMs6O7GYWF5Hj67g',
#     'width': 3840}],
#   'place_id': 'ChIJR9j6co1HtokRMan0ua8RMAI',
#   'rating': 3.4,
#   'reference': 'CmRbAAAATZVzON7aSPeDNWy4vu8F9dsXNOfeTfoipHMMNxFcZ87ulrVHOu28JcCKpFutINECcE_l-UOJX2_hyMcej7ycM5NrSlZH8oDAvbiOk83-R10fdeMG0MU0NccP4RK3AAN6EhBC8nbmfr9_ZQzujbiqQ559GhT7C0lvKZE0GcMVo2m9uOGOIScmsA',
#   'scope': 'GOOGLE',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2200 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9609335, 'lng': -77.4232561},
#    'viewport': {'northeast': {'lat': 38.96228332989271,
#      'lng': -77.42190627010729},
#     'southwest': {'lat': 38.95958367010726, 'lng': -77.42460592989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '8763954c34046f3742a948fbef22f84466a142a8',
#   'name': 'Elements On Level One',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115497934970694920599/photos">Travis Baumgart</a>'],
#     'photo_reference': 'CmRaAAAAZvZg62pc05ZPtvgwDboxhVuaFGB5kaMyPRJvgU9ikIm0oKU9XpLymCsg2dAwVPmrgklEKjrxAWU0C9O9mX_x1NRGtM9uQjGgbI6samUCZbVmBqbyFJlbz0r8n2wmzK61EhAzAfGf3vJS1HEwaPo99WrVGhTvCESAsfTh3EW-mGSWwQrBH-t7_g',
#     'width': 1836}],
#   'place_id': 'ChIJQUumvYJHtokRqccDrDqJrWw',
#   'rating': 3.2,
#   'reference': 'CmRbAAAASzY9QoL34OsE0-bMwKkwqvSGESOFXAUbdSS_wCDyx32sGT4DqIovcdFSQAVlsP-6d7m9MVo1_ne3mwaJz-zQ7T5LWV7wr8uC-aaq_JMtdI2tSFkifwnqUJCSAtxmFN2AEhCqnng9dRN4UIn4_Sx-CHSxGhSinNGlBgVeE2NKLZ4dfYtxjoJemw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2300 Dulles Corner Blvd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9485969, 'lng': -77.4484299},
#    'viewport': {'northeast': {'lat': 38.94994672989272,
#      'lng': -77.44708007010728},
#     'southwest': {'lat': 38.94724707010727, 'lng': -77.44977972989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '06a163a0056f7b4dbcc5b81ccb963cbb41094368',
#   'name': "Carrabba's Italian Grill",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105320630398470954348/photos">Jose March-Leuba</a>'],
#     'photo_reference': 'CmRaAAAAM59oXNqRDOa6-VT5zfGa8i3SFIHwv927-FsnA7VLEfOoCON-fN5AxarrKpZDfAEysQ3b8Umnk6Mbtqm5N3aXskSvjoRpf0s9qeTMUxRbZfzxEi-LrCY07kYqsFWkdEBgEhAVcuTtwEixFwrIOXm8YmgOGhRyfjPeVvsTuYwWsRzgirfPnq3enA',
#     'width': 4160}],
#   'place_id': 'ChIJk-7gGkBHtokR3NGlod2wO_0',
#   'rating': 2.2,
#   'reference': 'CmRbAAAA2rNSviQO5mj3rsATRR_hBJg-EDPX4Y-gx09gLY3XbgbNyNYO5P5Cb8EK06znn-aBCbjllBx0uCyP6MoqTzht5nFY4HuVICPG6cURuZqwWiWwxTXFPaKmjB0n4b7GMFlUEhCZB3vGSvhcDS-9Pb4nDHAPGhQMyWiy8A8vSrVIHFv-1JPaGPFGOg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Washington Dulles International Airport, Concourse B, Gate B41, 1 Saarinen Cir, Dulles'},
#  {'geometry': {'location': {'lat': 38.9454736, 'lng': -77.4448961},
#    'viewport': {'northeast': {'lat': 38.94682342989272,
#      'lng': -77.44354627010728},
#     'southwest': {'lat': 38.94412377010728, 'lng': -77.44624592989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '457d0af235f15c4cd9c9371ebb022d92156b71d5',
#   'name': 'Au Bon Pain',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114229034596052359026/photos">Nouni USALG</a>'],
#     'photo_reference': 'CmRaAAAALTyzfY_upe1gx1ezgt06MjLjZxwVkXtsBss_8a8BXWn3DOtrQXTSnE7Zhbhoc0LxMwFPzchfbDJEWvkqwWY1on7CaDy02ryid5ITHFN4L4ej4hN-BYRTeYizDR-afrMmEhCBLtXkdBdWtv_qjuiGMD9sGhTkqw6uU2pvHOdVls7jWlAY8MIKNg',
#     'width': 4032}],
#   'place_id': 'ChIJebpXGkBHtokRgVuywowH18E',
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'CmRbAAAAnpBveKu86sW60irCMAdY-rE380VAdL6NR6kQN-Mj9QVDTqEItI1vSwqI52vsIMSv85azEvcOETJg2-6OTQiKn32zYA8XCuznWPscZgfcyUvaOvyo_jAoWN2-ah93Z8FqEhCPrR7katY0jrVuM8xZuGUGGhTBT2bh9nYByJ4jV3R8iWz1tqnp4g',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1 Saarinen Circle, Sterling'},
#  {'geometry': {'location': {'lat': 38.9643913, 'lng': -77.396605},
#    'viewport': {'northeast': {'lat': 38.96574112989272,
#      'lng': -77.39525517010728},
#     'southwest': {'lat': 38.96304147010727, 'lng': -77.39795482989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '47d42fe430bd7cf2e33080fde7c228a438fee688',
#   'name': "Paisano's Pizza",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 2046,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111461259370706113420/photos">Paisano&#39;s Pizza</a>'],
#     'photo_reference': 'CmRaAAAA7MaB3lFJoPJzSfZUTP-0rYm6se5e04Z_-lNjOJLGbjUPntVV6PzoWUhtQLrsVvMYiHbTzdc54miKkbInh2dlCCApeZH4x-y86dW_dROyvMaH2aj4_2MraUEYyF7LqvnvEhA-Uc7BsrUOcOvyfDh0NKCWGhSrzKlQM1YwSzETCpw2lhfdIjOVgA',
#     'width': 2048}],
#   'place_id': 'ChIJn9qyTPRHtokRfNzSHf6kY7A',
#   'price_level': 2,
#   'rating': 3.5,
#   'reference': 'CmRbAAAA0ntoEP6FzwZrUraI3QocsCvJ-TzF1RLoWJcVjT7P3tRKH-rc3V46gsDeFgvZ3fxo3UNTwpvgHYGs6S7wGwVTXUdT5HEz2EwZBcZS9-1s-6Xw7G8DT2nmCVfZ4eXlf5J8EhCnsFUfBIrg1-4EiTVVH3JyGhRg5BSKLnKuX6XcCk3TN_pLfUdhvA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1141 Elden St #105, Herndon'},
#  {'geometry': {'location': {'lat': 38.9636296, 'lng': -77.3990669},
#    'viewport': {'northeast': {'lat': 38.96489667989272,
#      'lng': -77.39753292010728},
#     'southwest': {'lat': 38.96219702010728, 'lng': -77.40023257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'fa1dff8ffdb7c12f80f1a704198e9497ca474039',
#   'name': 'Chipotle Mexican Grill',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106158804692297980523/photos">Prem Nambi</a>'],
#     'photo_reference': 'CmRaAAAANfEv9g_p4PkJpWIW6NjKBqmc4OOLUw_EceNNkrVgxJHD8y1KhybFE0v7hmw9y-h08TXzvaht_TKKT089py_285rd2q-aCn9IXcJTqHcY6KAniUDC9eDKVFRANZjyJYUIEhCiErc-YgPFuQQBDssKgCzOGhTDfqeJ89pLsieuMFQ1-cmPDNGxfA',
#     'width': 1920}],
#   'place_id': 'ChIJJbJlVPRHtokR393UAAk2O0E',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAOkrPB0Ag39E5PyVTyOGG-xclQOuSDbBXkvKtlBCgHF_tdJTUg3blpk4kdtgT0tgEiD6E-m26lPE6TDGEyxyPbYcVuAe9E2MfP71x2DPX8mcEE7tsWVsamFyORy0QYFnlEhDsllzxJoWNixrHS9pQKMrvGhQTbbsD1gYIa3_XorN0JHgiK4KvYQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1144 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9491305, 'lng': -77.3957818},
#    'viewport': {'northeast': {'lat': 38.95046712989272,
#      'lng': -77.39437207010728},
#     'southwest': {'lat': 38.94776747010728, 'lng': -77.39707172989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'd7412cc8ad2598c8366009e2124d8f7d50338a19',
#   'name': 'Pei Wei',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103921559028635582224/photos">Laura I</a>'],
#     'photo_reference': 'CmRaAAAABrBRp3AIiXCTPjgMaiWvySvGYavYmqZVd2QwusqW3rjiuq4CsvkPIjDfgbxJ_Vf-9sOA_la5fXTiIY2txnI7tt0tU29o8uHNn17EZe0jlibtsaSGcKK0nu0J0TUHgYHREhASH5QQx7395hVQmMApQjUSGhQlrKZo31CXSWnEo4aURQyRVLRArg',
#     'width': 4048}],
#   'place_id': 'ChIJuxX0YulHtokROTeCrnmDx6k',
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'CmRbAAAARfIUD65GQ6YvWsJemvaUajQPNYPUrrzyQVqTq-Ded4ZY0eweVXPg4CtPF61CHyyzCQR-a9MYPlumUpK_jFB_yOs5Sd-GYboVCHDheFs3EMOS0UFLurdTaHxST8DroD9FEhCEVns-D4AeKkQdIctG8hWcGhTMNN4OEgSv_mSkovBKOvaeoyYIKA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2338 Woodland Crossing Dr Suite A, Herndon'},
#  {'geometry': {'location': {'lat': 38.9495279, 'lng': -77.39601019999999},
#    'viewport': {'northeast': {'lat': 38.95093377989272,
#      'lng': -77.39460157010727},
#     'southwest': {'lat': 38.94823412010727, 'lng': -77.39730122989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '45ada78434650665d6b95094e440377a0376dd38',
#   'name': 'Moby Dick House of Kabob',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3192,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115484345829336444608/photos">Jay Stearns</a>'],
#     'photo_reference': 'CmRaAAAA1EYQiG7yB7roxAcB3-LbPBQMNLYkPfn6Yzx94NNyiGTMCLb7d2IpXjVF-8Ta0oQlg0lpUzrsrrk7FOOU1wBPreEeXfQsH1q9RxBnXQLHwHpBCB5H7XuCSpPq0mY1rNkKEhCfu9do4duVEgkfSYAv2ywzGhRDgruvLghh4kYyHF-yRGEm8e_Blg',
#     'width': 4788}],
#   'place_id': 'ChIJywL52OtHtokRisWGJ7-RIaA',
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'CmRbAAAAcdjypZlLSsnQNLcstz0_fEXLuIv0olltwD91X7k4YpSVECJdCAEvPjG9MZ3L69ay4zf3994VP8Wr802aeaKZfJ1Llz-0omBhQy1ogZo7FrfedsyJ9FAoTNfjSqeT8GaqEhAYQvgMjDrpoTy5XZPbwteDGhSRc6jg5AjTeRKOnTOqQskZDQkJIw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '12975-A Highland Crossing Dr, Herndon'},
#  {'geometry': {'location': {'lat': 38.950228, 'lng': -77.409966},
#    'viewport': {'northeast': {'lat': 38.95173202989272,
#      'lng': -77.40874487010727},
#     'southwest': {'lat': 38.94903237010728, 'lng': -77.41144452989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'e3e52fde9110807a4e1160e820da5e22ebaae51b',
#   'name': "Chuck E. Cheese's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114812587622428408666/photos">Rajiv Desai</a>'],
#     'photo_reference': 'CmRaAAAAYkfHIQ4rWMATFJFqMlq5BoL8b_W7bjWDG35GLSgqhkSoB9uEDfWiwpoD5EdUgRRoWdkKbnvxLGU6IIQsD9Nv8zeVZh4h2CuJgPcwDAK00uDmkAHN-L_NM5CDRc_2B_UyEhAoj9zr36E3AKkgjGKuYLKtGhT-0kKg0YWdI2gPY4SsCSBrIZDPMg',
#     'width': 1920}],
#   'place_id': 'ChIJ--fmB5dHtokRGXWPheoQWFk',
#   'price_level': 2,
#   'rating': 3.8,
#   'reference': 'CmRbAAAAW16PTCBjJwW8yAf2rFrae6jjuKiPdenbM6ZbGicvwhA1U19YSTxmuwV_ufNsTI_CpgjwlrNwMrNYh5sQcyhrk_JQgwbuoDk63nqwBkCgU6ODIsKSbEgloE6F3z4ndt9yEhBK5Igf7MO5XhqS2pNy7SybGhSnYtJ4MxWUAO2KpV87VpJ3BjzaPw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '2465 Centreville, Ste. J9, Herndon'},
#  {'geometry': {'location': {'lat': 38.9503091, 'lng': -77.4101694},
#    'viewport': {'northeast': {'lat': 38.95171102989272,
#      'lng': -77.40890717010728},
#     'southwest': {'lat': 38.94901137010728, 'lng': -77.41160682989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a306deb8f4f1680369ffa0d24715cba80b5cf6fd',
#   'name': 'Tropical Smoothie Cafe',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 440,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105974514124910190354/photos">A Google User</a>'],
#     'photo_reference': 'CmRZAAAA0hEVeqMt3TUfVPRRYcm1LNQQO6NJcSc4khGEDtEML2PnO7TQiaBQZ9irxnyTfuZwWrAcroCvDh1NFFCGj4rQTh5sRUFdvmBtKFVVEhrN-qzcZD9eYjZy9HfpWvp8V6RMEhDny4bhI4c6dnicYoxVwF_pGhT4kNAKYs-zCJyW3wQer1PslgtWMg',
#     'width': 550}],
#   'place_id': 'ChIJ--fmB5dHtokRMr8-G7snM38',
#   'rating': 3.8,
#   'reference': 'CmRbAAAARnEq4v-2HN_nl70HuA2YGI5SndWJCdShzJ3HIO_wFT33Akprnk2YAc0R38gN3G7uXD26g3xLgf8KdXZFxPRSnaavOMTr80LMt6RMT3r3uX6X5iR4J1xNbMTX9PkqeTmTEhBvVXbUKhMmZsgO4wmuc0GxGhTZBDYFYO0OeUKu0vkZUg1aKl7uxg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant',
#    'cafe',
#    'meal_takeaway',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2465 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9662767, 'lng': -77.3960639},
#    'viewport': {'northeast': {'lat': 38.96771142989272,
#      'lng': -77.39491507010727},
#     'southwest': {'lat': 38.96501177010727, 'lng': -77.39761472989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'bed28b48fdb509bee6668f2a6f0f816d3ba15ce9',
#   'name': 'Pizza Hut',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAA-Q1wOuMEVyFRLDnFdWxpgipJaqGyh_zVWdmvouh3aF-9-JsiQgHp_OrWzrJJp72S0NNhLVewONWg5F9u8ZUwGRLZzdC_DMbZj4XVP7QC6aX9NweRgTNP_IDC0-8rXHKNEhAyepfknz1tBipqyuNCUxvgGhTy6sV1oawpHvrUIyMLE-LlDIWv9Q',
#     'width': 4032}],
#   'place_id': 'ChIJTyaR7PVHtokRYaAjBq0B7Pg',
#   'price_level': 1,
#   'rating': 3.4,
#   'reference': 'CmRbAAAAE4tkXPC4tUluts7FjesNZNTdoYOpOKyrHnikZHnlOobuP9zbDOTGEFTPe19fvQpoJdsjH1ThndazWsYshbu1I4es9gDtbXbqV0typvIhDu4NhLDhR3YgEbK64NUq-U00EhASHWDuDQJjT3d8wQJbpr1pGhQVqYCSmPS9pjF9hucFbrLBlB_XsA',
#   'scope': 'GOOGLE',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1061 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.950467, 'lng': -77.4106},
#    'viewport': {'northeast': {'lat': 38.95194962989272,
#      'lng': -77.40943492010727},
#     'southwest': {'lat': 38.94924997010727, 'lng': -77.41213457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '4e2cdc9e112c98c5ea49811a7f3ddca14680d5b8',
#   'name': "McDonald's",
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115377404142808458009/photos">McDonald&#39;s</a>'],
#     'photo_reference': 'CmRaAAAAT7H0l_NfczSMXBJenIhiPy7fPbnHmeYBjwcAAcC0gqFuFwJA-4bkDKyOeW64OPLVHp_rR3eEV8jxw0pelwPmS0MReMF5LQIr5dFil6hb1ZzcgSloMkKy3g5IpTiTLv_gEhCsdJixNancmdDzMeDrbWHlGhTLMoa3CFIYE3oM-hRihXI1Jtd3pA',
#     'width': 1025}],
#   'place_id': 'ChIJ1SqJ4JZHtokRk3WClJRxEHQ',
#   'price_level': 1,
#   'rating': 3,
#   'reference': 'CmRbAAAAvXSHavQCGRIEnHaYsNWkGH7JO3_y-WzCFkt35H9H_xf9RHBozM-cJeBlCuusbUQuPl9fxlVR7OuD1e5jBoN4IRl1V5dIYBafSUVVNDpc1Cc7cIohYyVUn9xqgMhOY5JkEhCb0jgp5drOjAb7k4K_-Tz4GhSWFd5QcmNFLKtOtSj3qAxEgmra0Q',
#   'scope': 'GOOGLE',
#   'types': ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '2475 Centreville Rd, Herndon'},
#  {'geometry': {'location': {'lat': 38.9618057, 'lng': -77.4010807},
#    'viewport': {'northeast': {'lat': 38.96311137989272,
#      'lng': -77.39962217010729},
#     'southwest': {'lat': 38.96041172010727, 'lng': -77.40232182989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2d6976da3f2801d986ce885fc8956efd6b5e0f81',
#   'name': 'Chicken Rico',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 494,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106534131682755427884/photos">Chicken Rico</a>'],
#     'photo_reference': 'CmRZAAAA5Zv-_AwsPLdIvKoZcSiOyVwO2LYSj_UMA-MyUbF_-cvdONcQ3U33ze9SW4FefHPKwsi0qOPl9nYvBgdZISHxTK1lHFLQS0470JFK-ew6ighnH0KNVxK3HmIpAt3LeOSQEhBnT_1_s3PL1mlywuBMOTi5GhTrz9OEn3kC1vS-iTjuqBxYBCLb4g',
#     'width': 750}],
#   'place_id': 'ChIJfW2CRvNHtokRgnRr8cpyLQ4',
#   'rating': 4.3,
#   'reference': 'CmRbAAAAx5vSBiGzvEt62H9jhsKfZNVNNiOSml-syRWYmysGFZzrhI0ci70RP4q9QmhRup_dgUMfhCudDMFmmT_UBc3H3sRAq7TESghPvEMJxqkdExFxyFL6OY_b33xWz8bqfgcOEhAyjkevJclPh5yyplGTuR4GGhRLEL3lcPTM5EixMCyz5nk0xmC9hg',
#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'vicinity': '1254 Elden St, Herndon'},
#  {'geometry': {'location': {'lat': 38.9576238, 'lng': -77.40167129999999},
#    'viewport': {'northeast': {'lat': 38.95908737989272,
#      'lng': -77.40011237010728},
#     'southwest': {'lat': 38.95638772010727, 'lng': -77.40281202989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '03eb84c3a2be1142f0255ee1c5d4df5d7c36f039',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101616574793385234828/photos">Sujan Manandhar</a>'],
#     'photo_reference': 'CmRaAAAADoU_jeR8MG8Dh9MZr9AgFiABXDHIxEZ82eyYpgGzNG-lvMlupA0kL5CvWq1ErT8znddSVgZUStzx9Ard-QzNBXtAJVz728a7J1hbtH3o8Y3aqV1GqIX27bHfgqssZfEUEhAqXRsQViQytaprAD6qVTmCGhRshgNWGul63C82rQB7UBrbx39wYg',
#     'width': 1080}],
#   'place_id': 'ChIJP1eLx_JHtokRK7t9rA12MmU',
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'CmRbAAAA3U1wX2ov_3rTOt6yen2JL2xD0UkjDh5c1NPbRhJ1Ve7VoPVtZaSUcQalH4s6yi3tKqrv48RkGV1xGcTK-s2ibUfjfsayf59cfPbEKS_SDo4s6n5FS2uBHs7nHDxJB3INEhBKwSzrN5bORhTnEx8VyWMzGhTRxxXQ6Y2YSL92gT7hwSARztNpOA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': 'Worldgate Centre, Worldgate Dr 13053 Unit 14, Herndon'},
#  {'geometry': {'location': {'lat': 38.9783756, 'lng': -77.43503419999999},
#    'viewport': {'northeast': {'lat': 38.97979977989272,
#      'lng': -77.43367467010727},
#     'southwest': {'lat': 38.97710012010728, 'lng': -77.43637432989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '30b4adf5dd86fdf713d5787c0db6dfa27034af59',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'place_id': 'ChIJcxXv2IQ4tokRhq9cKObpksc',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAAVFjuWJCIrjHhYewUM05Exnp88sy9cBb1za3XrZhdAZEbLIWQFJAto7vda7TN_1o6GCjGeet_e9ZnfNhNdoIoGWJL-r1NsK87VPTmIH8x7JlQkhlVkRpbZensOm4FSWzGEhBZTSfU2UL4GkIzDG37MzJNGhTsfkqmzJga6DvngOh90s0HepOKuw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23050 Pacific Blvd, Sterling'},
#  {'geometry': {'location': {'lat': 38.977509, 'lng': -77.4106335},
#    'viewport': {'northeast': {'lat': 38.97895962989272,
#      'lng': -77.40947492010729},
#     'southwest': {'lat': 38.97625997010728, 'lng': -77.41217457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'a6ae6e5aaeee067aa578716bc8b4556f4999e687',
#   'name': 'SUBWAY®Restaurants',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116856164624339471300/photos">karthik kaaaru</a>'],
#     'photo_reference': 'CmRaAAAAmABOQ8gxyCeYgLRdLQaI5l-IMFcgK61niOuOKVdk0hUnBg5UaZK_67BGzvlNeENDmPs6SnYn_9WVtUcAmKdyeJiwTKwUo4wYQ1nEVRe_EEYChvGb_iA48bX_ek0Ekh1JEhBa2RBtVI32WeY9CwOgp3p4GhS2CgxY-UJ8G66sq_tQilLGTKs4Xg',
#     'width': 4032}],
#   'place_id': 'ChIJH5PXe11HtokRKWDX7XJORxE',
#   'price_level': 1,
#   'rating': 3.7,
#   'reference': 'CmRbAAAARAER7NHufv7IcP5ViI1quRubyHrs3ip0_mu3vsQI9EjFeffYpL6nD4rMgZBOmZtRGC4nlZ7U5NdYGdLUFia65jVoy3eMXTMpSg1neexL0Z76KzeO9znW8GLnb5I2iexsEhB2S7ot-oDTiqR29RK9l5eJGhTXEclsNScgySg1W933xUeD4l2p6A',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '23070 Oakgrove Rd #155, Sterling'}]
