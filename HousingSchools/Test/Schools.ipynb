# %%
import requests as req
import pandas as pd
# Google developer API key
from config_local import gkey

# %%
# read sites 
xls = pd.ExcelFile('Project1_AmazonSites.xlsx') 
sites_df=xls.parse('AmazonSites', dtype=str)

# %%
components= sites_df[['Site Name','State','Zip Code','Amazon City','Latitude','Longitude']]
components.head()
# Out:
#                             Site Name State Zip Code             Amazon City  \
# 0    Center for Innovation Technology    VA    20170  Northern Virginia Area
# 1       Crystal City and Potomac Yard    VA    22202  Northern Virginia Area
# 2  Nationals Park/ D.C United Stadium    DC    20024           Washington DC
# 3                       Union Station    DC    20002           Washington DC
# 4              Hill-East Neighborhood    DC    20003           Washington DC
#
#   Latitude Longitude
# 0    38.96    -77.42
# 1    38.84    -77.05
# 2    38.86    -77.01
# 3    38.89       -77
# 4    38.88    -76.97

# %%
# Use google search to get nearby schools and their ratings

# %%
# geocoordinates
target_coordinates = ''
target_search = "School"
target_radius = 8000
target_type = "School"
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
schools =[]

for index, row in components.iterrows():
    lat = row['Latitude']
    lng = row['Longitude']
    site = row['Site Name']
    coordinates = str(lat)+','+ str(lng)
    params['location'] = coordinates
    # run a request using our params dictionary
    response = req.get(base_url, params=params)
    print(response.url)
    # convert response to json
    school_data = response.json()
    number_schools = len(school_data["results"])
    print(number_schools)
    # Print the name and address of the first restaurant that appears
    for x in range(number_schools):
        if "rating" in school_data["results"][x].keys():
            rating = school_data["results"][x]["rating"]
        else:
            rating = 'NAN'
        schools.append({"Site Name":site,
                        "Number of schools":number_schools,
                        "Latitude":lat,
                       "Longitude":lng,
                       "Schools":school_data["results"][x]["name"],
                        "Rating":rating})
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.96%2C-77.42&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.84%2C-77.05&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.86%2C-77.01&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.89%2C-77&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.88%2C-76.97&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.91%2C-77.02&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.1802%2C-118.6028&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.4318%2C-118.5584&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.0885%2C-117.7702&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.39%2C-71&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.34%2C-71.03&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.35%2C-71.05&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=42.34%2C-71.06&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.75%2C-74&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.74%2C-73.94&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7%2C-73.98&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7%2C-74.01&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.91%2C-87.64&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.89%2C-87.64&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.88%2C-87.65&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.87%2C-87.63&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.87%2C-87.62&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.86%2C-87.67&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.85%2C-87.66&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.83%2C-87.6&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.9%2C-78.87&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.85%2C-79.08&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=35.77%2C-78.64&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7615%2C-84.3856&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.5129%2C-93.0431&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.904%2C-84.2843&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.9133%2C-84.3888&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.2586%2C-97.7444&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.2714%2C-97.6647&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.199%2C-97.8276&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4015%2C-97.7268&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4014%2C-97.7147&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.4704%2C-97.7701&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 20
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.1338%2C-97.6411&keyword=School&radius=8000&type=School&key=AIzaSyAiDzvT41q8MFWgLqU7ETTAf1wvBQO-TXE
# 18

# %%
schools_df = pd.DataFrame(schools)
schools_df.to_csv("Schools.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# num_colleges= schools_df.groupby('Site Name')['Schools'].count()
# nc= pd.DataFrame(num_colleges)
# nc = nc.reset_index()
# nc = nc.sort_values('Schools')
# plt.figure(figsize=(5,10))
# sns.barplot(x='Schools',y='Site Name',data=nc)
# plt.title("Number of nearby schools")
# plt.show()

# %%
schools_df['Rating'] = schools_df['Rating'].astype(float)
avg_rating = pd.DataFrame(schools_df.groupby('Site Name')['Rating'].mean())
avg_rating = avg_rating.reset_index()
avg_rating = avg_rating.sort_values('Rating', ascending=False)
plt.figure(figsize=(5,10))
sns.barplot(x='Rating',y='Site Name',data=avg_rating)
plt.title("Average rating of nearby schools")
plt.show()

# %%
#reduce to cities
cities = sites_df[['Amazon City', 'Site Name']]
cities = cities.merge(avg_rating)
cities = cities.sort_values('Rating', ascending=False)
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.boxplot(x='Rating',y='Amazon City',data=cities)
plt.title("Average rating of nearby schools by City")
plt.show()

# %%
# NEED API from greatschools
# yourAPIKey=''
# query='https://api.greatschools.org/schools/nearby?key='+yourAPIKey+'&state=CA&zip=94105'
# response = req.get(query)
# schools = response.json()
# schools
# census data for schools
# baseurl ='https://api.greatschools.org/school/census/'
# state = 
# parameters ='?'
