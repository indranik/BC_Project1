# %%
import requests
import json
import numpy as np
import pandas as pd

# %%
from config import walkscore_api_key

# %%
base_url = "http://api.walkscore.com/score?"
lat = "34.0885"
lon ="-117.7702"
address = "1101 McKinley Avenue Pomona CA 91768"
address_decoded = address.replace(" ","%20")
params = f"format=json&address={address_decoded}&lat={lat}&lon={lon}&transit=1&bike=1&wsapikey={walkscore_api_key}"
full_url = base_url + params
walkscore_response = requests.get(full_url)
walkscore_json = walkscore_response.json()
walkscore_json
# Out:
# {'description': 'Car-Dependent',
#  'help_link': 'https://www.redfin.com/how-walk-score-works',
#  'logo_url': 'https://cdn.walk.sc/images/api-logo.png',
#  'more_info_icon': 'https://cdn.walk.sc/images/api-more-info.gif',
#  'more_info_link': 'https://www.redfin.com/how-walk-score-works',
#  'snapped_lat': 34.089,
#  'snapped_lon': -117.7695,
#  'status': 1,
#  'transit': {'description': 'Some Transit',
#   'score': 25,
#   'summary': '3 nearby routes: 2 bus, 1 rail, 0 other'},
#  'updated': '2017-11-11 04:27:14.817250',
#  'walkscore': 17,
#  'ws_link': 'https://www.walkscore.com/score/1101-McKinley-Avenue-Pomona-CA-91768/lat=34.0885/lng=-117.7702/?utm_source=gmail.com&utm_medium=ws_api&utm_campaign=ws_api'}

# %%
city_dict = {
            "Los Angeles":
                 {
                  "site1":
                     {"lat":"34.0885","lon":"-117.7702","address":"1101 McKinley Avenue Pomona CA 91768"},
                  "site2":
                     {"lat":"34.1802","lon":"-118.6028","address":"21801 Oxnard Street Woodland Hills CA 91367"},
                  "site3":
                     {"lat":"34.4318","lon":"-118.5584","address":"24155 Newhall Ranch Road Santa Clarita CA 91355"}
                 },    
             "Austin":
                 {
                  "site1":
                     {"lat":"30.2586","lon":"-97.7444","address":"305 South Congress Avenue Austin TX 78704"},
                  "site2":
                     {"lat":"30.4704","lon":"-97.7701","address":"Robinson Ranch Austin TX 78729"},
                  "site3":
                     {"lat":"30.2714","lon":"-97.6647","address":"3501 Ed Bluestein Boulevard Austin TX 78721"},
                  "site4":
                     {"lat":"30.2721","lon":"-97.6782","address":"1117 Delano Street Austin TX 78721"},
                  "site5":
                     {"lat":"30.4014","lon":"-97.7147","address":"11501 Burnet Road Austin TX 78758"}
                 }
            }
city_dict["Los Angeles"]["site1"]["address"]
# Out:
# '1101 McKinley Avenue Pomona CA 91768'

# %%
base_url = "http://api.walkscore.com/score?"
lat = city_dict["Austin"]["lat"]
lon = city_dict["Austin"]["lon"]
address = city_dict["Austin"]["address"]
address_decoded = address.replace(" ","%20")
walkscore_api_key = "ffd1c56f9abcf84872116b4cc2dfcf31"
params = f"format=json&address={address_decoded}&lat={lat}&lon={lon}&transit=1&bike=1&wsapikey={walkscore_api_key}"
full_url = base_url + params
walkscore_response = requests.get(full_url)
walkscore_json = walkscore_response.json()
walkscore_json
# Out:
# {'bike': {'description': 'Somewhat Bikeable', 'score': 31},
#  'description': 'Car-Dependent',
#  'help_link': 'https://www.redfin.com/how-walk-score-works',
#  'logo_url': 'https://cdn.walk.sc/images/api-logo.png',
#  'more_info_icon': 'https://cdn.walk.sc/images/api-more-info.gif',
#  'more_info_link': 'https://www.redfin.com/how-walk-score-works',
#  'snapped_lat': 30.2715,
#  'snapped_lon': -97.665,
#  'status': 1,
#  'transit': {'description': 'Minimal Transit',
#   'score': 19,
#   'summary': '1 nearby routes: 1 bus, 0 rail, 0 other'},
#  'updated': '2017-11-11 11:41:38.158170',
#  'walkscore': 13,
#  'ws_link': 'https://www.walkscore.com/score/3501-Ed-Bluestein-Boulevard-Austin-TX-78721/lat=30.2714/lng=-97.6647/?utm_source=gmail.com&utm_medium=ws_api&utm_campaign=ws_api'}

# %% [markdown]
# https://www.walkscore.com/professional/api.php documentation

# %%
## Airports
# geocoordinates
lat = city_dict["Los Angeles"]["site1"]["lat"]
lon = city_dict["Los Angeles"]["site1"]["lon"]
target_coordinates = f"{lat}, {lon}"
#radius of within 31 miles or 50000 meters
target_radius = 50000
target_type = "airport"
gkey = "AIzaSyD147ThKlyPZsE9IGB5pptQi24HGdxAWjg"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
airport_data = response.json()
print(json.dumps(airport_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.0559781,
#                     "lng": -117.598057
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.06449915,
#                         "lng": -117.5968376
#                     },
#                     "southwest": {
#                         "lat": 34.05313775,
#                         "lng": -117.6017152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "ec4d4162373ff66e9c6628eec8b410c40019d703",
#             "name": "LA/Ontario International Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
# ...

# %% [markdown]
# #percentage of workers who commute by walk or bicycle
# https://www.census.gov/library/publications/2014/acs/acs-25.html
# https://www.census.gov/topics/employment/commuting.html
